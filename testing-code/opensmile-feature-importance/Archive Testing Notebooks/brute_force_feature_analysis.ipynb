# %%
import opensmile 
import pandas as pd
import numpy as np
import os
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, RandomizedSearchCV
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import random
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.manifold import TSNE
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns
from sklearn import svm
base_path = "/home/ubuntu/"

# %% [markdown]
# ## Read saved dataframes to generate features and labels

# %%
data_path_lj = base_path + 'testing-code/opensmile-feature-importance/smile_dfs/LJ_sample_11200.csv'
df = pd.read_csv(data_path_lj)

# %%
df.shape
# Out:
# (11200, 6378)

# %% [markdown]
# ## Brute Force Code

# %%
archs = list(df.type.unique())[7:]

# %%
def get_single_arch_data(df, arch):
    
    df1 = df[df.type=='Original for '+arch]
    df2 = df[df.type==arch]
    
    df_ = pd.concat([df1, df2])
    df_ = df_.drop(columns=['file', 'type', 'start', 'end'])
    
    y = df_['label'].copy()
    X = df_.drop(columns=['label']).copy()
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
    
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    return X_train_scaled, X_test_scaled, y_train, y_test

# %%
def run_lr_model(X_train_scaled, X_test_scaled, y_train, y_test, features):
    
    accuracies = []
    
    for i in range(len(features)):
        model_lr = LogisticRegression(solver='liblinear')
        model_lr.fit(X_train_scaled[:,i].reshape(-1, 1), y_train)
        yhat = model_lr.predict(X_test_scaled[:,i].reshape(-1, 1))
        accuracy = accuracy_score(y_test, yhat)
        accuracies.append(accuracy)
        
    return accuracies

# %%
features = df.drop(columns=['file', 'type', 'start', 'end', 'label']).columns.to_list()
nbf_df = pd.DataFrame(features, columns=['features'])

for arch in archs:
    
    X_train_scaled, X_test_scaled, y_train, y_test = get_single_arch_data(df, arch)
    
    nbf_df[arch] = run_lr_model(X_train_scaled, X_test_scaled, y_train, y_test, features)

# %%
#all features
#standard scaling of input data

y = df['label'].copy()
X = df.drop(columns=['file', 'type', 'start', 'end','label']).copy()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

accuracies = []

for i in range(len(features)):
    model_lr = LogisticRegression(solver='liblinear')
    model_lr.fit(X_train_scaled[:,i].reshape(-1, 1), y_train)
    yhat = model_lr.predict(X_test_scaled[:,i].reshape(-1, 1))
    accuracy = accuracy_score(y_test, yhat)
    accuracies.append(accuracy)

nbf_df['all_archs'] = accuracies

# %%
nbf_df[(nbf_df.iloc[:,1:] > 0.5).all(1)]
# Out:
#                                                features  \
# 5                    audspec_lengthL1norm_sma_quartile3
# 65                          pcm_RMSenergy_sma_quartile1
# 1247                 pcm_fftMag_spectralFlux_sma_iqr2-3
# 1312      pcm_fftMag_spectralEntropy_sma_percentile99.0
# 1436        pcm_fftMag_spectralSlope_sma_percentile99.0
# 1671                                   mfcc_sma[5]_lpc2
# 1702                                   mfcc_sma[6]_lpc2
# 1733                                   mfcc_sma[7]_lpc2
# 1792                                 mfcc_sma[9]_lpgain
# 1860                                 mfcc_sma[12]_range
# 1932                        mfcc_sma[14]_percentile99.0
# 1959                     audSpec_Rfilt_sma_de[0]_iqr1-2
# 2950           pcm_fftMag_spectralFlux_sma_de_quartile3
# 2952              pcm_fftMag_spectralFlux_sma_de_iqr2-3
# 2953              pcm_fftMag_spectralFlux_sma_de_iqr1-3
# 3285                                mfcc_sma_de[2]_lpc4
# 3311                              mfcc_sma_de[3]_lpgain
# 3315                                mfcc_sma_de[3]_lpc3
# 3373                              mfcc_sma_de[5]_lpgain
# 3408                                mfcc_sma_de[6]_lpc3
# 3497                              mfcc_sma_de[9]_lpgain
# 3576                       mfcc_sma_de[12]_pctlrange0-1
# 3712                voicingFinalUnclipped_sma_quartile1
# 3714                voicingFinalUnclipped_sma_quartile3
# 3717                   voicingFinalUnclipped_sma_iqr1-3
# 3719           voicingFinalUnclipped_sma_percentile99.0
# 3737                           jitterLocal_sma_flatness
# 3751                          jitterLocal_sma_quartile1
# 3757                      jitterLocal_sma_percentile1.0
# 3776                             jitterDDP_sma_flatness
# 3790                            jitterDDP_sma_quartile1
# 3796                        jitterDDP_sma_percentile1.0
# 3814                             shimmerLocal_sma_amean
# 3816                          shimmerLocal_sma_posamean
# 3822                          shimmerLocal_sma_linregc2
# 3829                         shimmerLocal_sma_quartile1
# 3830                         shimmerLocal_sma_quartile2
# 3839                          shimmerLocal_sma_skewness
# 3841                     shimmerLocal_sma_upleveltime25
# 3857                                   logHNR_sma_range
# 3870                               logHNR_sma_quartile3
# 3875                          logHNR_sma_percentile99.0
# 3876                            logHNR_sma_pctlrange0-1
# 4131                     audspec_lengthL1norm_sma_amean
# 4133                    audspec_lengthL1norm_sma_rqmean
# 4177                            pcm_RMSenergy_sma_amean
# 4975               pcm_fftMag_spectralFlux_sma_linregc2
# 4980               pcm_fftMag_spectralFlux_sma_qregerrQ
# 5007              pcm_fftMag_spectralEntropy_sma_rqmean
# 5102          pcm_fftMag_spectralSlope_sma_peakRangeAbs
# 5104           pcm_fftMag_spectralSlope_sma_peakMeanAbs
# 5107           pcm_fftMag_spectralSlope_sma_minRangeRel
# 5361                        mfcc_sma[9]_meanRisingSlope
# 5377                        mfcc_sma[10]_peakDistStddev
# 5431                     mfcc_sma[12]_stddevRisingSlope
# 5479                    mfcc_sma[14]_stddevFallingSlope
# 6033        pcm_fftMag_spectralFlux_sma_de_peakRangeAbs
# 6039     pcm_fftMag_spectralFlux_sma_de_meanRisingSlope
# 6041    pcm_fftMag_spectralFlux_sma_de_meanFallingSlope
# 6042  pcm_fftMag_spectralFlux_sma_de_stddevFallingSlope
#
#       ljspeech_full_band_melgan  ljspeech_melgan  ljspeech_melgan_large  \
# 5                       0.53750          0.51875                0.51875
# 65                      0.55625          0.51250                0.60000
# 1247                    0.54375          0.56875                0.55625
# 1312                    0.55000          0.73750                0.83125
# 1436                    0.55000          0.58125                0.59375
# 1671                    0.55000          0.86875                0.86875
# 1702                    0.51875          0.88750                0.90625
# 1733                    0.50625          0.86250                0.78750
# 1792                    0.58125          0.81875                0.88750
# 1860                    0.53750          0.51250                0.56250
# 1932                    0.51875          0.50625                0.50625
# 1959                    0.58750          0.56250                0.56250
# 2950                    0.55625          0.55000                0.56875
# 2952                    0.53750          0.55625                0.57500
# 2953                    0.54375          0.55000                0.55625
# 3285                    0.53750          0.77500                0.74375
# 3311                    0.51875          0.78125                0.83750
# 3315                    0.51875          0.86250                0.83125
# 3373                    0.53125          0.81875                0.90000
# 3408                    0.58750          0.90000                0.91250
# 3497                    0.56250          0.85625                0.92500
# 3576                    0.50625          0.51875                0.51250
# 3712                    0.55000          0.53750                0.61875
# 3714                    0.54375          0.58750                0.51250
# 3717                    0.51875          0.52500                0.64375
# 3719                    0.53125          0.60625                0.50625
# 3737                    0.51250          0.61875                0.54375
# 3751                    0.60625          0.70625                0.51250
# 3757                    0.63750          0.81250                0.61875
# 3776                    0.60000          0.72500                0.67500
# 3790                    0.72500          0.83750                0.58125
# 3796                    0.67500          0.87500                0.71250
# 3814                    0.57500          0.58750                0.52500
# 3816                    0.57500          0.58750                0.52500
# 3822                    0.53125          0.58750                0.51250
# 3829                    0.50625          0.70000                0.52500
# 3830                    0.55625          0.61875                0.54375
# 3839                    0.53125          0.63125                0.53125
# 3841                    0.56250          0.62500                0.52500
# 3857                    0.53750          0.68125                0.54375
# 3870                    0.53125          0.71875                0.56250
# 3875                    0.53125          0.68750                0.52500
# 3876                    0.53125          0.68750                0.52500
# 4131                    0.51250          0.55000                0.60625
# 4133                    0.51250          0.51250                0.58125
# 4177                    0.59375          0.55000                0.58750
# 4975                    0.51250          0.56875                0.50625
# 4980                    0.50625          0.53125                0.53750
# 5007                    0.54375          0.53125                0.59375
# 5102                    0.57500          0.59375                0.56875
# 5104                    0.55000          0.56875                0.53125
# 5107                    0.56250          0.60625                0.55625
# 5361                    0.54375          0.53125                0.70000
# 5377                    0.51250          0.51875                0.58750
# 5431                    0.52500          0.53125                0.56875
# 5479                    0.55000          0.51875                0.62500
# 6033                    0.50625          0.56250                0.53750
# 6039                    0.51250          0.52500                0.58750
# 6041                    0.55000          0.55625                0.57500
# 6042                    0.53750          0.52500                0.54375
#
#       ljspeech_multi_band_melgan  ljspeech_parallel_wavegan  \
# 5                        0.63125                    0.69375
# 65                       0.53750                    0.60000
# 1247                     0.60000                    0.63125
# 1312                     0.50625                    0.58750
# 1436                     0.57500                    0.67500
# 1671                     0.58125                    0.52500
# 1702                     0.61875                    0.57500
# 1733                     0.55000                    0.53750
# 1792                     0.64375                    0.53750
# 1860                     0.60000                    0.63125
# 1932                     0.59375                    0.63125
# 1959                     0.52500                    0.58750
# 2950                     0.58125                    0.61250
# 2952                     0.58750                    0.60625
# 2953                     0.58750                    0.63125
# 3285                     0.51875                    0.58750
# 3311                     0.56250                    0.60625
# 3315                     0.55000                    0.55000
# 3373                     0.56250                    0.56250
# 3408                     0.55625                    0.51250
# 3497                     0.59375                    0.56250
# 3576                     0.57500                    0.55625
# 3712                     0.59375                    0.58125
# 3714                     0.60625                    0.63125
# 3717                     0.57500                    0.56875
# 3719                     0.57500                    0.53125
# 3737                     0.66250                    0.63125
# 3751                     0.69375                    0.64375
# 3757                     0.88125                    0.71875
# 3776                     0.76875                    0.67500
# 3790                     0.90000                    0.83750
# 3796                     0.88125                    0.72500
# 3814                     0.61875                    0.68750
# 3816                     0.61875                    0.68750
# 3822                     0.55625                    0.52500
# 3829                     0.67500                    0.65625
# 3830                     0.60000                    0.60000
# 3839                     0.53125                    0.64375
# 3841                     0.56875                    0.61250
# 3857                     0.59375                    0.63750
# 3870                     0.61875                    0.61875
# 3875                     0.63125                    0.60000
# 3876                     0.63125                    0.60000
# 4131                     0.66250                    0.65625
# 4133                     0.62500                    0.64375
# 4177                     0.69375                    0.63750
# 4975                     0.58750                    0.52500
# 4980                     0.50625                    0.53125
# 5007                     0.61250                    0.54375
# 5102                     0.61250                    0.55625
# 5104                     0.53125                    0.60000
# 5107                     0.51250                    0.56875
# 5361                     0.53750                    0.51250
# 5377                     0.51250                    0.57500
# 5431                     0.57500                    0.53750
# 5479                     0.50625                    0.58750
# 6033                     0.62500                    0.56250
# 6039                     0.63125                    0.60000
# 6041                     0.67500                    0.67500
# 6042                     0.60625                    0.56875
#
#       ljspeech_waveglow  ljspeech_hifiGAN  all_archs
# 5               0.51250           0.61250   0.561607
# 65              0.51250           0.53750   0.544643
# 1247            0.53125           0.58125   0.576786
# 1312            0.58125           0.51250   0.611607
# 1436            0.52500           0.50625   0.560714
# 1671            0.51250           0.50625   0.618750
# 1702            0.60000           0.52500   0.602679
# 1733            0.58125           0.57500   0.611607
# 1792            0.58125           0.54375   0.616964
# 1860            0.62500           0.55000   0.576786
# 1932            0.58125           0.55625   0.550000
# 1959            0.54375           0.51250   0.550893
# 2950            0.53125           0.55000   0.562500
# 2952            0.51875           0.55000   0.571429
# 2953            0.52500           0.58125   0.569643
# 3285            0.56250           0.61875   0.592857
# 3311            0.61250           0.56875   0.600893
# 3315            0.55000           0.51250   0.626786
# 3373            0.58125           0.51875   0.634821
# 3408            0.50625           0.56875   0.636607
# 3497            0.56875           0.53750   0.606250
# 3576            0.61875           0.53125   0.565179
# 3712            0.51875           0.51250   0.563393
# 3714            0.60625           0.52500   0.569643
# 3717            0.52500           0.51875   0.538393
# 3719            0.60625           0.58125   0.543750
# 3737            0.65000           0.66250   0.622321
# 3751            0.70000           0.65625   0.651786
# 3757            0.78750           0.70000   0.711607
# 3776            0.70000           0.75625   0.716964
# 3790            0.88125           0.81875   0.783929
# 3796            0.81875           0.77500   0.762500
# 3814            0.67500           0.52500   0.563393
# 3816            0.67500           0.52500   0.563393
# 3822            0.55625           0.54375   0.566964
# 3829            0.78750           0.68750   0.632143
# 3830            0.64375           0.55000   0.551786
# 3839            0.55625           0.50625   0.568750
# 3841            0.61875           0.55000   0.579464
# 3857            0.68750           0.56875   0.602679
# 3870            0.61250           0.61250   0.595536
# 3875            0.61875           0.60625   0.608036
# 3876            0.61875           0.60625   0.608036
# 4131            0.55000           0.60000   0.569643
# 4133            0.55000           0.61875   0.559821
# 4177            0.51250           0.59375   0.565179
# 4975            0.50625           0.57500   0.556250
# 4980            0.50625           0.51875   0.517857
# 5007            0.50625           0.53125   0.543750
# 5102            0.51250           0.54375   0.546429
# 5104            0.50625           0.56875   0.556250
# 5107            0.52500           0.51875   0.546429
# 5361            0.55625           0.51875   0.518750
# 5377            0.63750           0.53750   0.541071
# 5431            0.60000           0.55000   0.551786
# 5479            0.54375           0.53125   0.550000
# 6033            0.55000           0.56250   0.561607
# 6039            0.55625           0.58125   0.572321
# 6041            0.53125           0.56250   0.600893
# 6042            0.52500           0.57500   0.586607

# %%
selected_feats = nbf_df[(nbf_df.iloc[:,1:] > 0.5).all(1)]

# %%
selected_feats.shape
# Out:
# (60, 9)

# %%
sorted(selected_feats.features.to_list())
# Out:
# ['audSpec_Rfilt_sma_de[0]_iqr1-2',
#  'audspec_lengthL1norm_sma_amean',
#  'audspec_lengthL1norm_sma_quartile3',
#  'audspec_lengthL1norm_sma_rqmean',
#  'jitterDDP_sma_flatness',
#  'jitterDDP_sma_percentile1.0',
#  'jitterDDP_sma_quartile1',
#  'jitterLocal_sma_flatness',
#  'jitterLocal_sma_percentile1.0',
#  'jitterLocal_sma_quartile1',
#  'logHNR_sma_pctlrange0-1',
#  'logHNR_sma_percentile99.0',
#  'logHNR_sma_quartile3',
#  'logHNR_sma_range',
#  'mfcc_sma[10]_peakDistStddev',
#  'mfcc_sma[12]_range',
#  'mfcc_sma[12]_stddevRisingSlope',
#  'mfcc_sma[14]_percentile99.0',
#  'mfcc_sma[14]_stddevFallingSlope',
#  'mfcc_sma[5]_lpc2',
#  'mfcc_sma[6]_lpc2',
#  'mfcc_sma[7]_lpc2',
#  'mfcc_sma[9]_lpgain',
#  'mfcc_sma[9]_meanRisingSlope',
#  'mfcc_sma_de[12]_pctlrange0-1',
#  'mfcc_sma_de[2]_lpc4',
#  'mfcc_sma_de[3]_lpc3',
#  'mfcc_sma_de[3]_lpgain',
#  'mfcc_sma_de[5]_lpgain',
#  'mfcc_sma_de[6]_lpc3',
#  'mfcc_sma_de[9]_lpgain',
#  'pcm_RMSenergy_sma_amean',
#  'pcm_RMSenergy_sma_quartile1',
#  'pcm_fftMag_spectralEntropy_sma_percentile99.0',
#  'pcm_fftMag_spectralEntropy_sma_rqmean',
#  'pcm_fftMag_spectralFlux_sma_de_iqr1-3',
#  'pcm_fftMag_spectralFlux_sma_de_iqr2-3',
#  'pcm_fftMag_spectralFlux_sma_de_meanFallingSlope',
#  'pcm_fftMag_spectralFlux_sma_de_meanRisingSlope',
#  'pcm_fftMag_spectralFlux_sma_de_peakRangeAbs',
#  'pcm_fftMag_spectralFlux_sma_de_quartile3',
#  'pcm_fftMag_spectralFlux_sma_de_stddevFallingSlope',
#  'pcm_fftMag_spectralFlux_sma_iqr2-3',
#  'pcm_fftMag_spectralFlux_sma_linregc2',
#  'pcm_fftMag_spectralFlux_sma_qregerrQ',
#  'pcm_fftMag_spectralSlope_sma_minRangeRel',
#  'pcm_fftMag_spectralSlope_sma_peakMeanAbs',
#  'pcm_fftMag_spectralSlope_sma_peakRangeAbs',
#  'pcm_fftMag_spectralSlope_sma_percentile99.0',
#  'shimmerLocal_sma_amean',
#  'shimmerLocal_sma_linregc2',
#  'shimmerLocal_sma_posamean',
#  'shimmerLocal_sma_quartile1',
#  'shimmerLocal_sma_quartile2',
#  'shimmerLocal_sma_skewness',
#  'shimmerLocal_sma_upleveltime25',
#  'voicingFinalUnclipped_sma_iqr1-3',
#  'voicingFinalUnclipped_sma_percentile99.0',
#  'voicingFinalUnclipped_sma_quartile1',
#  'voicingFinalUnclipped_sma_quartile3']

# %%
features = df.drop(columns=['file', 'type', 'start', 'end', 'label']).columns.to_list()

# %%
[feat for feat in features if 'mfcc_sma_' in feat]
# Out:
# ['mfcc_sma_de[1]_range',
#  'mfcc_sma_de[1]_maxPos',
#  'mfcc_sma_de[1]_minPos',
#  'mfcc_sma_de[1]_quartile1',
#  'mfcc_sma_de[1]_quartile2',
#  'mfcc_sma_de[1]_quartile3',
#  'mfcc_sma_de[1]_iqr1-2',
#  'mfcc_sma_de[1]_iqr2-3',
#  'mfcc_sma_de[1]_iqr1-3',
#  'mfcc_sma_de[1]_percentile1.0',
#  'mfcc_sma_de[1]_percentile99.0',
#  'mfcc_sma_de[1]_pctlrange0-1',
#  'mfcc_sma_de[1]_stddev',
#  'mfcc_sma_de[1]_skewness',
#  'mfcc_sma_de[1]_kurtosis',
#  'mfcc_sma_de[1]_meanSegLen',
#  'mfcc_sma_de[1]_maxSegLen',
#  'mfcc_sma_de[1]_minSegLen',
#  'mfcc_sma_de[1]_segLenStddev',
#  'mfcc_sma_de[1]_upleveltime25',
#  'mfcc_sma_de[1]_upleveltime50',
#  'mfcc_sma_de[1]_upleveltime75',
#  'mfcc_sma_de[1]_upleveltime90',
#  'mfcc_sma_de[1]_risetime',
#  'mfcc_sma_de[1]_leftctime',
#  'mfcc_sma_de[1]_lpgain',
#  'mfcc_sma_de[1]_lpc0',
#  'mfcc_sma_de[1]_lpc1',
#  'mfcc_sma_de[1]_lpc2',
#  'mfcc_sma_de[1]_lpc3',
#  'mfcc_sma_de[1]_lpc4',
#  'mfcc_sma_de[2]_range',
#  'mfcc_sma_de[2]_maxPos',
#  'mfcc_sma_de[2]_minPos',
#  'mfcc_sma_de[2]_quartile1',
#  'mfcc_sma_de[2]_quartile2',
#  'mfcc_sma_de[2]_quartile3',
#  'mfcc_sma_de[2]_iqr1-2',
#  'mfcc_sma_de[2]_iqr2-3',
#  'mfcc_sma_de[2]_iqr1-3',
#  'mfcc_sma_de[2]_percentile1.0',
#  'mfcc_sma_de[2]_percentile99.0',
#  'mfcc_sma_de[2]_pctlrange0-1',
#  'mfcc_sma_de[2]_stddev',
#  'mfcc_sma_de[2]_skewness',
#  'mfcc_sma_de[2]_kurtosis',
#  'mfcc_sma_de[2]_meanSegLen',
#  'mfcc_sma_de[2]_maxSegLen',
#  'mfcc_sma_de[2]_minSegLen',
#  'mfcc_sma_de[2]_segLenStddev',
#  'mfcc_sma_de[2]_upleveltime25',
#  'mfcc_sma_de[2]_upleveltime50',
#  'mfcc_sma_de[2]_upleveltime75',
#  'mfcc_sma_de[2]_upleveltime90',
#  'mfcc_sma_de[2]_risetime',
#  'mfcc_sma_de[2]_leftctime',
#  'mfcc_sma_de[2]_lpgain',
#  'mfcc_sma_de[2]_lpc0',
#  'mfcc_sma_de[2]_lpc1',
#  'mfcc_sma_de[2]_lpc2',
#  'mfcc_sma_de[2]_lpc3',
#  'mfcc_sma_de[2]_lpc4',
#  'mfcc_sma_de[3]_range',
#  'mfcc_sma_de[3]_maxPos',
#  'mfcc_sma_de[3]_minPos',
#  'mfcc_sma_de[3]_quartile1',
#  'mfcc_sma_de[3]_quartile2',
#  'mfcc_sma_de[3]_quartile3',
#  'mfcc_sma_de[3]_iqr1-2',
#  'mfcc_sma_de[3]_iqr2-3',
#  'mfcc_sma_de[3]_iqr1-3',
#  'mfcc_sma_de[3]_percentile1.0',
#  'mfcc_sma_de[3]_percentile99.0',
#  'mfcc_sma_de[3]_pctlrange0-1',
#  'mfcc_sma_de[3]_stddev',
#  'mfcc_sma_de[3]_skewness',
#  'mfcc_sma_de[3]_kurtosis',
#  'mfcc_sma_de[3]_meanSegLen',
#  'mfcc_sma_de[3]_maxSegLen',
#  'mfcc_sma_de[3]_minSegLen',
#  'mfcc_sma_de[3]_segLenStddev',
#  'mfcc_sma_de[3]_upleveltime25',
#  'mfcc_sma_de[3]_upleveltime50',
#  'mfcc_sma_de[3]_upleveltime75',
#  'mfcc_sma_de[3]_upleveltime90',
#  'mfcc_sma_de[3]_risetime',
#  'mfcc_sma_de[3]_leftctime',
#  'mfcc_sma_de[3]_lpgain',
#  'mfcc_sma_de[3]_lpc0',
#  'mfcc_sma_de[3]_lpc1',
#  'mfcc_sma_de[3]_lpc2',
#  'mfcc_sma_de[3]_lpc3',
#  'mfcc_sma_de[3]_lpc4',
#  'mfcc_sma_de[4]_range',
#  'mfcc_sma_de[4]_maxPos',
#  'mfcc_sma_de[4]_minPos',
#  'mfcc_sma_de[4]_quartile1',
#  'mfcc_sma_de[4]_quartile2',
#  'mfcc_sma_de[4]_quartile3',
#  'mfcc_sma_de[4]_iqr1-2',
#  'mfcc_sma_de[4]_iqr2-3',
#  'mfcc_sma_de[4]_iqr1-3',
#  'mfcc_sma_de[4]_percentile1.0',
#  'mfcc_sma_de[4]_percentile99.0',
#  'mfcc_sma_de[4]_pctlrange0-1',
#  'mfcc_sma_de[4]_stddev',
#  'mfcc_sma_de[4]_skewness',
#  'mfcc_sma_de[4]_kurtosis',
#  'mfcc_sma_de[4]_meanSegLen',
#  'mfcc_sma_de[4]_maxSegLen',
#  'mfcc_sma_de[4]_minSegLen',
#  'mfcc_sma_de[4]_segLenStddev',
#  'mfcc_sma_de[4]_upleveltime25',
#  'mfcc_sma_de[4]_upleveltime50',
#  'mfcc_sma_de[4]_upleveltime75',
#  'mfcc_sma_de[4]_upleveltime90',
#  'mfcc_sma_de[4]_risetime',
#  'mfcc_sma_de[4]_leftctime',
#  'mfcc_sma_de[4]_lpgain',
#  'mfcc_sma_de[4]_lpc0',
#  'mfcc_sma_de[4]_lpc1',
#  'mfcc_sma_de[4]_lpc2',
#  'mfcc_sma_de[4]_lpc3',
#  'mfcc_sma_de[4]_lpc4',
#  'mfcc_sma_de[5]_range',
#  'mfcc_sma_de[5]_maxPos',
#  'mfcc_sma_de[5]_minPos',
#  'mfcc_sma_de[5]_quartile1',
#  'mfcc_sma_de[5]_quartile2',
#  'mfcc_sma_de[5]_quartile3',
#  'mfcc_sma_de[5]_iqr1-2',
#  'mfcc_sma_de[5]_iqr2-3',
#  'mfcc_sma_de[5]_iqr1-3',
#  'mfcc_sma_de[5]_percentile1.0',
#  'mfcc_sma_de[5]_percentile99.0',
#  'mfcc_sma_de[5]_pctlrange0-1',
#  'mfcc_sma_de[5]_stddev',
#  'mfcc_sma_de[5]_skewness',
#  'mfcc_sma_de[5]_kurtosis',
#  'mfcc_sma_de[5]_meanSegLen',
#  'mfcc_sma_de[5]_maxSegLen',
#  'mfcc_sma_de[5]_minSegLen',
#  'mfcc_sma_de[5]_segLenStddev',
#  'mfcc_sma_de[5]_upleveltime25',
#  'mfcc_sma_de[5]_upleveltime50',
#  'mfcc_sma_de[5]_upleveltime75',
#  'mfcc_sma_de[5]_upleveltime90',
#  'mfcc_sma_de[5]_risetime',
#  'mfcc_sma_de[5]_leftctime',
#  'mfcc_sma_de[5]_lpgain',
#  'mfcc_sma_de[5]_lpc0',
#  'mfcc_sma_de[5]_lpc1',
#  'mfcc_sma_de[5]_lpc2',
#  'mfcc_sma_de[5]_lpc3',
#  'mfcc_sma_de[5]_lpc4',
#  'mfcc_sma_de[6]_range',
#  'mfcc_sma_de[6]_maxPos',
#  'mfcc_sma_de[6]_minPos',
#  'mfcc_sma_de[6]_quartile1',
#  'mfcc_sma_de[6]_quartile2',
#  'mfcc_sma_de[6]_quartile3',
#  'mfcc_sma_de[6]_iqr1-2',
#  'mfcc_sma_de[6]_iqr2-3',
#  'mfcc_sma_de[6]_iqr1-3',
#  'mfcc_sma_de[6]_percentile1.0',
#  'mfcc_sma_de[6]_percentile99.0',
#  'mfcc_sma_de[6]_pctlrange0-1',
#  'mfcc_sma_de[6]_stddev',
#  'mfcc_sma_de[6]_skewness',
#  'mfcc_sma_de[6]_kurtosis',
#  'mfcc_sma_de[6]_meanSegLen',
#  'mfcc_sma_de[6]_maxSegLen',
#  'mfcc_sma_de[6]_minSegLen',
#  'mfcc_sma_de[6]_segLenStddev',
#  'mfcc_sma_de[6]_upleveltime25',
#  'mfcc_sma_de[6]_upleveltime50',
#  'mfcc_sma_de[6]_upleveltime75',
#  'mfcc_sma_de[6]_upleveltime90',
#  'mfcc_sma_de[6]_risetime',
#  'mfcc_sma_de[6]_leftctime',
#  'mfcc_sma_de[6]_lpgain',
#  'mfcc_sma_de[6]_lpc0',
#  'mfcc_sma_de[6]_lpc1',
#  'mfcc_sma_de[6]_lpc2',
#  'mfcc_sma_de[6]_lpc3',
#  'mfcc_sma_de[6]_lpc4',
#  'mfcc_sma_de[7]_range',
#  'mfcc_sma_de[7]_maxPos',
#  'mfcc_sma_de[7]_minPos',
#  'mfcc_sma_de[7]_quartile1',
#  'mfcc_sma_de[7]_quartile2',
#  'mfcc_sma_de[7]_quartile3',
#  'mfcc_sma_de[7]_iqr1-2',
#  'mfcc_sma_de[7]_iqr2-3',
#  'mfcc_sma_de[7]_iqr1-3',
#  'mfcc_sma_de[7]_percentile1.0',
#  'mfcc_sma_de[7]_percentile99.0',
#  'mfcc_sma_de[7]_pctlrange0-1',
#  'mfcc_sma_de[7]_stddev',
#  'mfcc_sma_de[7]_skewness',
#  'mfcc_sma_de[7]_kurtosis',
#  'mfcc_sma_de[7]_meanSegLen',
#  'mfcc_sma_de[7]_maxSegLen',
#  'mfcc_sma_de[7]_minSegLen',
#  'mfcc_sma_de[7]_segLenStddev',
#  'mfcc_sma_de[7]_upleveltime25',
#  'mfcc_sma_de[7]_upleveltime50',
#  'mfcc_sma_de[7]_upleveltime75',
#  'mfcc_sma_de[7]_upleveltime90',
#  'mfcc_sma_de[7]_risetime',
#  'mfcc_sma_de[7]_leftctime',
#  'mfcc_sma_de[7]_lpgain',
#  'mfcc_sma_de[7]_lpc0',
#  'mfcc_sma_de[7]_lpc1',
#  'mfcc_sma_de[7]_lpc2',
#  'mfcc_sma_de[7]_lpc3',
#  'mfcc_sma_de[7]_lpc4',
#  'mfcc_sma_de[8]_range',
#  'mfcc_sma_de[8]_maxPos',
#  'mfcc_sma_de[8]_minPos',
#  'mfcc_sma_de[8]_quartile1',
#  'mfcc_sma_de[8]_quartile2',
#  'mfcc_sma_de[8]_quartile3',
#  'mfcc_sma_de[8]_iqr1-2',
#  'mfcc_sma_de[8]_iqr2-3',
#  'mfcc_sma_de[8]_iqr1-3',
#  'mfcc_sma_de[8]_percentile1.0',
#  'mfcc_sma_de[8]_percentile99.0',
#  'mfcc_sma_de[8]_pctlrange0-1',
#  'mfcc_sma_de[8]_stddev',
#  'mfcc_sma_de[8]_skewness',
#  'mfcc_sma_de[8]_kurtosis',
#  'mfcc_sma_de[8]_meanSegLen',
#  'mfcc_sma_de[8]_maxSegLen',
#  'mfcc_sma_de[8]_minSegLen',
#  'mfcc_sma_de[8]_segLenStddev',
#  'mfcc_sma_de[8]_upleveltime25',
#  'mfcc_sma_de[8]_upleveltime50',
#  'mfcc_sma_de[8]_upleveltime75',
#  'mfcc_sma_de[8]_upleveltime90',
#  'mfcc_sma_de[8]_risetime',
#  'mfcc_sma_de[8]_leftctime',
#  'mfcc_sma_de[8]_lpgain',
#  'mfcc_sma_de[8]_lpc0',
#  'mfcc_sma_de[8]_lpc1',
#  'mfcc_sma_de[8]_lpc2',
#  'mfcc_sma_de[8]_lpc3',
#  'mfcc_sma_de[8]_lpc4',
#  'mfcc_sma_de[9]_range',
#  'mfcc_sma_de[9]_maxPos',
#  'mfcc_sma_de[9]_minPos',
#  'mfcc_sma_de[9]_quartile1',
#  'mfcc_sma_de[9]_quartile2',
#  'mfcc_sma_de[9]_quartile3',
#  'mfcc_sma_de[9]_iqr1-2',
#  'mfcc_sma_de[9]_iqr2-3',
#  'mfcc_sma_de[9]_iqr1-3',
#  'mfcc_sma_de[9]_percentile1.0',
#  'mfcc_sma_de[9]_percentile99.0',
#  'mfcc_sma_de[9]_pctlrange0-1',
#  'mfcc_sma_de[9]_stddev',
#  'mfcc_sma_de[9]_skewness',
#  'mfcc_sma_de[9]_kurtosis',
#  'mfcc_sma_de[9]_meanSegLen',
#  'mfcc_sma_de[9]_maxSegLen',
#  'mfcc_sma_de[9]_minSegLen',
#  'mfcc_sma_de[9]_segLenStddev',
#  'mfcc_sma_de[9]_upleveltime25',
#  'mfcc_sma_de[9]_upleveltime50',
#  'mfcc_sma_de[9]_upleveltime75',
#  'mfcc_sma_de[9]_upleveltime90',
#  'mfcc_sma_de[9]_risetime',
#  'mfcc_sma_de[9]_leftctime',
#  'mfcc_sma_de[9]_lpgain',
#  'mfcc_sma_de[9]_lpc0',
#  'mfcc_sma_de[9]_lpc1',
#  'mfcc_sma_de[9]_lpc2',
#  'mfcc_sma_de[9]_lpc3',
#  'mfcc_sma_de[9]_lpc4',
#  'mfcc_sma_de[10]_range',
#  'mfcc_sma_de[10]_maxPos',
#  'mfcc_sma_de[10]_minPos',
#  'mfcc_sma_de[10]_quartile1',
#  'mfcc_sma_de[10]_quartile2',
#  'mfcc_sma_de[10]_quartile3',
#  'mfcc_sma_de[10]_iqr1-2',
#  'mfcc_sma_de[10]_iqr2-3',
#  'mfcc_sma_de[10]_iqr1-3',
#  'mfcc_sma_de[10]_percentile1.0',
#  'mfcc_sma_de[10]_percentile99.0',
#  'mfcc_sma_de[10]_pctlrange0-1',
#  'mfcc_sma_de[10]_stddev',
#  'mfcc_sma_de[10]_skewness',
#  'mfcc_sma_de[10]_kurtosis',
#  'mfcc_sma_de[10]_meanSegLen',
#  'mfcc_sma_de[10]_maxSegLen',
#  'mfcc_sma_de[10]_minSegLen',
#  'mfcc_sma_de[10]_segLenStddev',
#  'mfcc_sma_de[10]_upleveltime25',
#  'mfcc_sma_de[10]_upleveltime50',
#  'mfcc_sma_de[10]_upleveltime75',
#  'mfcc_sma_de[10]_upleveltime90',
#  'mfcc_sma_de[10]_risetime',
#  'mfcc_sma_de[10]_leftctime',
#  'mfcc_sma_de[10]_lpgain',
#  'mfcc_sma_de[10]_lpc0',
#  'mfcc_sma_de[10]_lpc1',
#  'mfcc_sma_de[10]_lpc2',
#  'mfcc_sma_de[10]_lpc3',
#  'mfcc_sma_de[10]_lpc4',
#  'mfcc_sma_de[11]_range',
#  'mfcc_sma_de[11]_maxPos',
#  'mfcc_sma_de[11]_minPos',
#  'mfcc_sma_de[11]_quartile1',
#  'mfcc_sma_de[11]_quartile2',
#  'mfcc_sma_de[11]_quartile3',
#  'mfcc_sma_de[11]_iqr1-2',
#  'mfcc_sma_de[11]_iqr2-3',
#  'mfcc_sma_de[11]_iqr1-3',
#  'mfcc_sma_de[11]_percentile1.0',
#  'mfcc_sma_de[11]_percentile99.0',
#  'mfcc_sma_de[11]_pctlrange0-1',
#  'mfcc_sma_de[11]_stddev',
#  'mfcc_sma_de[11]_skewness',
#  'mfcc_sma_de[11]_kurtosis',
#  'mfcc_sma_de[11]_meanSegLen',
#  'mfcc_sma_de[11]_maxSegLen',
#  'mfcc_sma_de[11]_minSegLen',
#  'mfcc_sma_de[11]_segLenStddev',
#  'mfcc_sma_de[11]_upleveltime25',
#  'mfcc_sma_de[11]_upleveltime50',
#  'mfcc_sma_de[11]_upleveltime75',
#  'mfcc_sma_de[11]_upleveltime90',
#  'mfcc_sma_de[11]_risetime',
#  'mfcc_sma_de[11]_leftctime',
#  'mfcc_sma_de[11]_lpgain',
#  'mfcc_sma_de[11]_lpc0',
#  'mfcc_sma_de[11]_lpc1',
#  'mfcc_sma_de[11]_lpc2',
#  'mfcc_sma_de[11]_lpc3',
#  'mfcc_sma_de[11]_lpc4',
#  'mfcc_sma_de[12]_range',
#  'mfcc_sma_de[12]_maxPos',
#  'mfcc_sma_de[12]_minPos',
#  'mfcc_sma_de[12]_quartile1',
#  'mfcc_sma_de[12]_quartile2',
#  'mfcc_sma_de[12]_quartile3',
#  'mfcc_sma_de[12]_iqr1-2',
#  'mfcc_sma_de[12]_iqr2-3',
#  'mfcc_sma_de[12]_iqr1-3',
#  'mfcc_sma_de[12]_percentile1.0',
#  'mfcc_sma_de[12]_percentile99.0',
#  'mfcc_sma_de[12]_pctlrange0-1',
#  'mfcc_sma_de[12]_stddev',
#  'mfcc_sma_de[12]_skewness',
#  'mfcc_sma_de[12]_kurtosis',
#  'mfcc_sma_de[12]_meanSegLen',
#  'mfcc_sma_de[12]_maxSegLen',
#  'mfcc_sma_de[12]_minSegLen',
#  'mfcc_sma_de[12]_segLenStddev',
#  'mfcc_sma_de[12]_upleveltime25',
#  'mfcc_sma_de[12]_upleveltime50',
#  'mfcc_sma_de[12]_upleveltime75',
#  'mfcc_sma_de[12]_upleveltime90',
#  'mfcc_sma_de[12]_risetime',
#  'mfcc_sma_de[12]_leftctime',
#  'mfcc_sma_de[12]_lpgain',
#  'mfcc_sma_de[12]_lpc0',
#  'mfcc_sma_de[12]_lpc1',
#  'mfcc_sma_de[12]_lpc2',
#  'mfcc_sma_de[12]_lpc3',
#  'mfcc_sma_de[12]_lpc4',
#  'mfcc_sma_de[13]_range',
#  'mfcc_sma_de[13]_maxPos',
#  'mfcc_sma_de[13]_minPos',
#  'mfcc_sma_de[13]_quartile1',
#  'mfcc_sma_de[13]_quartile2',
#  'mfcc_sma_de[13]_quartile3',
#  'mfcc_sma_de[13]_iqr1-2',
#  'mfcc_sma_de[13]_iqr2-3',
#  'mfcc_sma_de[13]_iqr1-3',
#  'mfcc_sma_de[13]_percentile1.0',
#  'mfcc_sma_de[13]_percentile99.0',
#  'mfcc_sma_de[13]_pctlrange0-1',
#  'mfcc_sma_de[13]_stddev',
#  'mfcc_sma_de[13]_skewness',
#  'mfcc_sma_de[13]_kurtosis',
#  'mfcc_sma_de[13]_meanSegLen',
#  'mfcc_sma_de[13]_maxSegLen',
#  'mfcc_sma_de[13]_minSegLen',
#  'mfcc_sma_de[13]_segLenStddev',
#  'mfcc_sma_de[13]_upleveltime25',
#  'mfcc_sma_de[13]_upleveltime50',
#  'mfcc_sma_de[13]_upleveltime75',
#  'mfcc_sma_de[13]_upleveltime90',
#  'mfcc_sma_de[13]_risetime',
#  'mfcc_sma_de[13]_leftctime',
#  'mfcc_sma_de[13]_lpgain',
#  'mfcc_sma_de[13]_lpc0',
#  'mfcc_sma_de[13]_lpc1',
#  'mfcc_sma_de[13]_lpc2',
#  'mfcc_sma_de[13]_lpc3',
#  'mfcc_sma_de[13]_lpc4',
#  'mfcc_sma_de[14]_range',
#  'mfcc_sma_de[14]_maxPos',
#  'mfcc_sma_de[14]_minPos',
#  'mfcc_sma_de[14]_quartile1',
#  'mfcc_sma_de[14]_quartile2',
#  'mfcc_sma_de[14]_quartile3',
#  'mfcc_sma_de[14]_iqr1-2',
#  'mfcc_sma_de[14]_iqr2-3',
#  'mfcc_sma_de[14]_iqr1-3',
#  'mfcc_sma_de[14]_percentile1.0',
#  'mfcc_sma_de[14]_percentile99.0',
#  'mfcc_sma_de[14]_pctlrange0-1',
#  'mfcc_sma_de[14]_stddev',
#  'mfcc_sma_de[14]_skewness',
#  'mfcc_sma_de[14]_kurtosis',
#  'mfcc_sma_de[14]_meanSegLen',
#  'mfcc_sma_de[14]_maxSegLen',
#  'mfcc_sma_de[14]_minSegLen',
#  'mfcc_sma_de[14]_segLenStddev',
#  'mfcc_sma_de[14]_upleveltime25',
#  'mfcc_sma_de[14]_upleveltime50',
#  'mfcc_sma_de[14]_upleveltime75',
#  'mfcc_sma_de[14]_upleveltime90',
#  'mfcc_sma_de[14]_risetime',
#  'mfcc_sma_de[14]_leftctime',
#  'mfcc_sma_de[14]_lpgain',
#  'mfcc_sma_de[14]_lpc0',
#  'mfcc_sma_de[14]_lpc1',
#  'mfcc_sma_de[14]_lpc2',
#  'mfcc_sma_de[14]_lpc3',
#  'mfcc_sma_de[14]_lpc4',
#  'mfcc_sma_de[1]_flatness',
#  'mfcc_sma_de[1]_posamean',
#  'mfcc_sma_de[1]_rqmean',
#  'mfcc_sma_de[1]_meanPeakDist',
#  'mfcc_sma_de[1]_peakDistStddev',
#  'mfcc_sma_de[1]_peakRangeAbs',
#  'mfcc_sma_de[1]_peakRangeRel',
#  'mfcc_sma_de[1]_peakMeanAbs',
#  'mfcc_sma_de[1]_peakMeanMeanDist',
#  'mfcc_sma_de[1]_peakMeanRel',
#  'mfcc_sma_de[1]_minRangeRel',
#  'mfcc_sma_de[1]_meanRisingSlope',
#  'mfcc_sma_de[1]_stddevRisingSlope',
#  'mfcc_sma_de[1]_meanFallingSlope',
#  'mfcc_sma_de[1]_stddevFallingSlope',
#  'mfcc_sma_de[2]_flatness',
#  'mfcc_sma_de[2]_posamean',
#  'mfcc_sma_de[2]_rqmean',
#  'mfcc_sma_de[2]_meanPeakDist',
#  'mfcc_sma_de[2]_peakDistStddev',
#  'mfcc_sma_de[2]_peakRangeAbs',
#  'mfcc_sma_de[2]_peakRangeRel',
#  'mfcc_sma_de[2]_peakMeanAbs',
#  'mfcc_sma_de[2]_peakMeanMeanDist',
#  'mfcc_sma_de[2]_peakMeanRel',
#  'mfcc_sma_de[2]_minRangeRel',
#  'mfcc_sma_de[2]_meanRisingSlope',
#  'mfcc_sma_de[2]_stddevRisingSlope',
#  'mfcc_sma_de[2]_meanFallingSlope',
#  'mfcc_sma_de[2]_stddevFallingSlope',
#  'mfcc_sma_de[3]_flatness',
#  'mfcc_sma_de[3]_posamean',
#  'mfcc_sma_de[3]_rqmean',
#  'mfcc_sma_de[3]_meanPeakDist',
#  'mfcc_sma_de[3]_peakDistStddev',
#  'mfcc_sma_de[3]_peakRangeAbs',
#  'mfcc_sma_de[3]_peakRangeRel',
#  'mfcc_sma_de[3]_peakMeanAbs',
#  'mfcc_sma_de[3]_peakMeanMeanDist',
#  'mfcc_sma_de[3]_peakMeanRel',
#  'mfcc_sma_de[3]_minRangeRel',
#  'mfcc_sma_de[3]_meanRisingSlope',
#  'mfcc_sma_de[3]_stddevRisingSlope',
#  'mfcc_sma_de[3]_meanFallingSlope',
#  'mfcc_sma_de[3]_stddevFallingSlope',
#  'mfcc_sma_de[4]_flatness',
#  'mfcc_sma_de[4]_posamean',
#  'mfcc_sma_de[4]_rqmean',
#  'mfcc_sma_de[4]_meanPeakDist',
#  'mfcc_sma_de[4]_peakDistStddev',
#  'mfcc_sma_de[4]_peakRangeAbs',
#  'mfcc_sma_de[4]_peakRangeRel',
#  'mfcc_sma_de[4]_peakMeanAbs',
#  'mfcc_sma_de[4]_peakMeanMeanDist',
#  'mfcc_sma_de[4]_peakMeanRel',
#  'mfcc_sma_de[4]_minRangeRel',
#  'mfcc_sma_de[4]_meanRisingSlope',
#  'mfcc_sma_de[4]_stddevRisingSlope',
#  'mfcc_sma_de[4]_meanFallingSlope',
#  'mfcc_sma_de[4]_stddevFallingSlope',
#  'mfcc_sma_de[5]_flatness',
#  'mfcc_sma_de[5]_posamean',
#  'mfcc_sma_de[5]_rqmean',
#  'mfcc_sma_de[5]_meanPeakDist',
#  'mfcc_sma_de[5]_peakDistStddev',
#  'mfcc_sma_de[5]_peakRangeAbs',
#  'mfcc_sma_de[5]_peakRangeRel',
#  'mfcc_sma_de[5]_peakMeanAbs',
#  'mfcc_sma_de[5]_peakMeanMeanDist',
#  'mfcc_sma_de[5]_peakMeanRel',
#  'mfcc_sma_de[5]_minRangeRel',
#  'mfcc_sma_de[5]_meanRisingSlope',
#  'mfcc_sma_de[5]_stddevRisingSlope',
#  'mfcc_sma_de[5]_meanFallingSlope',
#  'mfcc_sma_de[5]_stddevFallingSlope',
#  'mfcc_sma_de[6]_flatness',
#  'mfcc_sma_de[6]_posamean',
#  'mfcc_sma_de[6]_rqmean',
#  'mfcc_sma_de[6]_meanPeakDist',
#  'mfcc_sma_de[6]_peakDistStddev',
#  'mfcc_sma_de[6]_peakRangeAbs',
#  'mfcc_sma_de[6]_peakRangeRel',
#  'mfcc_sma_de[6]_peakMeanAbs',
#  'mfcc_sma_de[6]_peakMeanMeanDist',
#  'mfcc_sma_de[6]_peakMeanRel',
#  'mfcc_sma_de[6]_minRangeRel',
#  'mfcc_sma_de[6]_meanRisingSlope',
#  'mfcc_sma_de[6]_stddevRisingSlope',
#  'mfcc_sma_de[6]_meanFallingSlope',
#  'mfcc_sma_de[6]_stddevFallingSlope',
#  'mfcc_sma_de[7]_flatness',
#  'mfcc_sma_de[7]_posamean',
#  'mfcc_sma_de[7]_rqmean',
#  'mfcc_sma_de[7]_meanPeakDist',
#  'mfcc_sma_de[7]_peakDistStddev',
#  'mfcc_sma_de[7]_peakRangeAbs',
#  'mfcc_sma_de[7]_peakRangeRel',
#  'mfcc_sma_de[7]_peakMeanAbs',
#  'mfcc_sma_de[7]_peakMeanMeanDist',
#  'mfcc_sma_de[7]_peakMeanRel',
#  'mfcc_sma_de[7]_minRangeRel',
#  'mfcc_sma_de[7]_meanRisingSlope',
#  'mfcc_sma_de[7]_stddevRisingSlope',
#  'mfcc_sma_de[7]_meanFallingSlope',
#  'mfcc_sma_de[7]_stddevFallingSlope',
#  'mfcc_sma_de[8]_flatness',
#  'mfcc_sma_de[8]_posamean',
#  'mfcc_sma_de[8]_rqmean',
#  'mfcc_sma_de[8]_meanPeakDist',
#  'mfcc_sma_de[8]_peakDistStddev',
#  'mfcc_sma_de[8]_peakRangeAbs',
#  'mfcc_sma_de[8]_peakRangeRel',
#  'mfcc_sma_de[8]_peakMeanAbs',
#  'mfcc_sma_de[8]_peakMeanMeanDist',
#  'mfcc_sma_de[8]_peakMeanRel',
#  'mfcc_sma_de[8]_minRangeRel',
#  'mfcc_sma_de[8]_meanRisingSlope',
#  'mfcc_sma_de[8]_stddevRisingSlope',
#  'mfcc_sma_de[8]_meanFallingSlope',
#  'mfcc_sma_de[8]_stddevFallingSlope',
#  'mfcc_sma_de[9]_flatness',
#  'mfcc_sma_de[9]_posamean',
#  'mfcc_sma_de[9]_rqmean',
#  'mfcc_sma_de[9]_meanPeakDist',
#  'mfcc_sma_de[9]_peakDistStddev',
#  'mfcc_sma_de[9]_peakRangeAbs',
#  'mfcc_sma_de[9]_peakRangeRel',
#  'mfcc_sma_de[9]_peakMeanAbs',
#  'mfcc_sma_de[9]_peakMeanMeanDist',
#  'mfcc_sma_de[9]_peakMeanRel',
#  'mfcc_sma_de[9]_minRangeRel',
#  'mfcc_sma_de[9]_meanRisingSlope',
#  'mfcc_sma_de[9]_stddevRisingSlope',
#  'mfcc_sma_de[9]_meanFallingSlope',
#  'mfcc_sma_de[9]_stddevFallingSlope',
#  'mfcc_sma_de[10]_flatness',
#  'mfcc_sma_de[10]_posamean',
#  'mfcc_sma_de[10]_rqmean',
#  'mfcc_sma_de[10]_meanPeakDist',
#  'mfcc_sma_de[10]_peakDistStddev',
#  'mfcc_sma_de[10]_peakRangeAbs',
#  'mfcc_sma_de[10]_peakRangeRel',
#  'mfcc_sma_de[10]_peakMeanAbs',
#  'mfcc_sma_de[10]_peakMeanMeanDist',
#  'mfcc_sma_de[10]_peakMeanRel',
#  'mfcc_sma_de[10]_minRangeRel',
#  'mfcc_sma_de[10]_meanRisingSlope',
#  'mfcc_sma_de[10]_stddevRisingSlope',
#  'mfcc_sma_de[10]_meanFallingSlope',
#  'mfcc_sma_de[10]_stddevFallingSlope',
#  'mfcc_sma_de[11]_flatness',
#  'mfcc_sma_de[11]_posamean',
#  'mfcc_sma_de[11]_rqmean',
#  'mfcc_sma_de[11]_meanPeakDist',
#  'mfcc_sma_de[11]_peakDistStddev',
#  'mfcc_sma_de[11]_peakRangeAbs',
#  'mfcc_sma_de[11]_peakRangeRel',
#  'mfcc_sma_de[11]_peakMeanAbs',
#  'mfcc_sma_de[11]_peakMeanMeanDist',
#  'mfcc_sma_de[11]_peakMeanRel',
#  'mfcc_sma_de[11]_minRangeRel',
#  'mfcc_sma_de[11]_meanRisingSlope',
#  'mfcc_sma_de[11]_stddevRisingSlope',
#  'mfcc_sma_de[11]_meanFallingSlope',
#  'mfcc_sma_de[11]_stddevFallingSlope',
#  'mfcc_sma_de[12]_flatness',
#  'mfcc_sma_de[12]_posamean',
#  'mfcc_sma_de[12]_rqmean',
#  'mfcc_sma_de[12]_meanPeakDist',
#  'mfcc_sma_de[12]_peakDistStddev',
#  'mfcc_sma_de[12]_peakRangeAbs',
#  'mfcc_sma_de[12]_peakRangeRel',
#  'mfcc_sma_de[12]_peakMeanAbs',
#  'mfcc_sma_de[12]_peakMeanMeanDist',
#  'mfcc_sma_de[12]_peakMeanRel',
#  'mfcc_sma_de[12]_minRangeRel',
#  'mfcc_sma_de[12]_meanRisingSlope',
#  'mfcc_sma_de[12]_stddevRisingSlope',
#  'mfcc_sma_de[12]_meanFallingSlope',
#  'mfcc_sma_de[12]_stddevFallingSlope',
#  'mfcc_sma_de[13]_flatness',
#  'mfcc_sma_de[13]_posamean',
#  'mfcc_sma_de[13]_rqmean',
#  'mfcc_sma_de[13]_meanPeakDist',
#  'mfcc_sma_de[13]_peakDistStddev',
#  'mfcc_sma_de[13]_peakRangeAbs',
#  'mfcc_sma_de[13]_peakRangeRel',
#  'mfcc_sma_de[13]_peakMeanAbs',
#  'mfcc_sma_de[13]_peakMeanMeanDist',
#  'mfcc_sma_de[13]_peakMeanRel',
#  'mfcc_sma_de[13]_minRangeRel',
#  'mfcc_sma_de[13]_meanRisingSlope',
#  'mfcc_sma_de[13]_stddevRisingSlope',
#  'mfcc_sma_de[13]_meanFallingSlope',
#  'mfcc_sma_de[13]_stddevFallingSlope',
#  'mfcc_sma_de[14]_flatness',
#  'mfcc_sma_de[14]_posamean',
#  'mfcc_sma_de[14]_rqmean',
#  'mfcc_sma_de[14]_meanPeakDist',
#  'mfcc_sma_de[14]_peakDistStddev',
#  'mfcc_sma_de[14]_peakRangeAbs',
#  'mfcc_sma_de[14]_peakRangeRel',
#  'mfcc_sma_de[14]_peakMeanAbs',
#  'mfcc_sma_de[14]_peakMeanMeanDist',
#  'mfcc_sma_de[14]_peakMeanRel',
#  'mfcc_sma_de[14]_minRangeRel',
#  'mfcc_sma_de[14]_meanRisingSlope',
#  'mfcc_sma_de[14]_stddevRisingSlope',
#  'mfcc_sma_de[14]_meanFallingSlope',
#  'mfcc_sma_de[14]_stddevFallingSlope']

# %%
y = df['label'].copy()
X = df.drop(columns=['file', 'type', 'start', 'end','label']).copy()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
