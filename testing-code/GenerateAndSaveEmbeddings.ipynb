# %%
import sys
sys.path.append("/home/ubuntu/MultiModalDeepFake")

# %%
from packages.AudioEmbeddingsManager import generateTitaNetEmbeddings

import nemo.collections.asr as nemo_asr 
import pandas as pd
speaker_model = nemo_asr.models.EncDecSpeakerLabelModel.from_pretrained(model_name='titanet_large')
# Out:
# /home/ubuntu/.local/lib/python3.8/site-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.24.3) or chardet (5.1.0) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# 2023-05-02 21:47:41.318682: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-02 21:47:41.425011: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-05-02 21:47:41.989320: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-05-02 21:47:41.989383: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-05-02 21:47:41.989388: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# [NeMo W 2023-05-02 21:47:42 optimizers:55] Apex was not found. Using the lamb or fused_adam optimizer will error out.
# [NeMo W 2023-05-02 21:47:42 experimental:27] Module <class 'nemo.collections.asr.models.audio_to_audio_model.AudioToAudioModel'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-05-02 21:47:43 experimental:27] Module <class 'nemo.collections.asr.modules.audio_modules.SpectrogramToMultichannelFeatures'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-05-02 21:47:43 nemo_logging:349] /home/ubuntu/miniconda3/envs/nemo/lib/python3.8/site-packages/torch/jit/annotations.py:309: UserWarning: TorchScript will treat type annotations of Tensor dtype-specific subtypes as if they are normal Tensors. dtype constraints are not enforced in compilation either.
#       warnings.warn("TorchScript will treat type annotations of Tensor "
#
# [NeMo W 2023-05-02 21:47:44 experimental:27] Module <class 'nemo.collections.asr.data.audio_to_audio.BaseAudioDataset'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-05-02 21:47:44 experimental:27] Module <class 'nemo.collections.asr.data.audio_to_audio.AudioToTargetDataset'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-05-02 21:47:44 experimental:27] Module <class 'nemo.collections.asr.data.audio_to_audio.AudioToTargetWithReferenceDataset'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-05-02 21:47:44 experimental:27] Module <class 'nemo.collections.asr.data.audio_to_audio.AudioToTargetWithEmbeddingDataset'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2023-05-02 21:47:44 experimental:27] Module <class 'nemo.collections.asr.models.enhancement_models.EncMaskDecAudioToAudioModel'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo I 2023-05-02 21:47:44 cloud:56] Found existing object /home/ubuntu/.cache/torch/NeMo/NeMo_1.15.0/titanet-l/492c0ab8416139171dc18c21879a9e45/titanet-l.nemo.
# [NeMo I 2023-05-02 21:47:44 cloud:62] Re-using file from: /home/ubuntu/.cache/torch/NeMo/NeMo_1.15.0/titanet-l/492c0ab8416139171dc18c21879a9e45/titanet-l.nemo
# [NeMo I 2023-05-02 21:47:44 common:913] Instantiating model from pre-trained checkpoint
# [NeMo W 2023-05-02 21:47:44 modelPT:156] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: /manifests/combined_fisher_swbd_voxceleb12_librispeech/train.json
#     sample_rate: 16000
#     labels: null
#     batch_size: 64
#     shuffle: true
#     time_length: 3
#     is_tarred: false
#     tarred_audio_filepaths: null
#     tarred_shard_strategy: scatter
#     augmentor:
#       noise:
#         manifest_path: /manifests/noise/rir_noise_manifest.json
#         prob: 0.5
#         min_snr_db: 0
#         max_snr_db: 15
#       speed:
#         prob: 0.5
#         sr: 16000
#         resample_type: kaiser_fast
#         min_speed_rate: 0.95
#         max_speed_rate: 1.05
#     num_workers: 15
#     pin_memory: true
#
# [NeMo W 2023-05-02 21:47:44 modelPT:163] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: /manifests/combined_fisher_swbd_voxceleb12_librispeech/dev.json
#     sample_rate: 16000
#     labels: null
#     batch_size: 128
#     shuffle: false
#     time_length: 3
#     num_workers: 15
#     pin_memory: true
# [NeMo I 2023-05-02 21:47:44 label_models:126] Setting angular: true/false in decoder is deprecated and will be removed in 1.13 version, use specific loss with _target_
# [NeMo I 2023-05-02 21:47:44 features:267] PADDING: 16
# [NeMo I 2023-05-02 21:47:45 save_restore_connector:243] Model EncDecSpeakerLabelModel was successfully restored from /home/ubuntu/.cache/torch/NeMo/NeMo_1.15.0/titanet-l/492c0ab8416139171dc18c21879a9e45/titanet-l.nemo.

# %%
metadata = pd.read_csv('/home/ubuntu/data/wavefake_data/LJ_metadata_16KHz_Laundered.csv')

# %%
metadata.head()
# Out:
#    Unnamed: 0          id Main_ID  Secondary_ID  \
# 0           0  LJ001-0001   LJ001             1
# 1           1  LJ001-0002   LJ001             2
# 2           2  LJ001-0003   LJ001             3
# 3           3  LJ001-0004   LJ001             4
# 4           4  LJ001-0005   LJ001             5
#
#                                                 Real  \
# 0  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 1  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 2  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 3  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 4  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
#
#                                     Full_Band_MelGan  \
# 0  /home/ubuntu/data/wavefake_data/generated_audi...
# 1  /home/ubuntu/data/wavefake_data/generated_audi...
# 2  /home/ubuntu/data/wavefake_data/generated_audi...
# 3  /home/ubuntu/data/wavefake_data/generated_audi...
# 4  /home/ubuntu/data/wavefake_data/generated_audi...
#
#                                              HifiGan  \
# 0  /home/ubuntu/data/wavefake_data/generated_audi...
# 1  /home/ubuntu/data/wavefake_data/generated_audi...
# 2  /home/ubuntu/data/wavefake_data/generated_audi...
# 3  /home/ubuntu/data/wavefake_data/generated_audi...
# 4  /home/ubuntu/data/wavefake_data/generated_audi...
#
#                                               MelGan  \
# 0  /home/ubuntu/data/wavefake_data/generated_audi...
# 1  /home/ubuntu/data/wavefake_data/generated_audi...
# 2  /home/ubuntu/data/wavefake_data/generated_audi...
# 3  /home/ubuntu/data/wavefake_data/generated_audi...
# 4  /home/ubuntu/data/wavefake_data/generated_audi...
#
#                                          MelGanLarge  \
# 0  /home/ubuntu/data/wavefake_data/generated_audi...
# 1  /home/ubuntu/data/wavefake_data/generated_audi...
# 2  /home/ubuntu/data/wavefake_data/generated_audi...
# 3  /home/ubuntu/data/wavefake_data/generated_audi...
# 4  /home/ubuntu/data/wavefake_data/generated_audi...
#
#                                    Multi_Band_MelGan  \
# 0  /home/ubuntu/data/wavefake_data/generated_audi...
# 1  /home/ubuntu/data/wavefake_data/generated_audi...
# 2  /home/ubuntu/data/wavefake_data/generated_audi...
# 3  /home/ubuntu/data/wavefake_data/generated_audi...
# 4  /home/ubuntu/data/wavefake_data/generated_audi...
#
#                                     Parallel_WaveGan  \
# 0  /home/ubuntu/data/wavefake_data/generated_audi...
# 1  /home/ubuntu/data/wavefake_data/generated_audi...
# 2  /home/ubuntu/data/wavefake_data/generated_audi...
# 3  /home/ubuntu/data/wavefake_data/generated_audi...
# 4  /home/ubuntu/data/wavefake_data/generated_audi...
#
#                                             Waveglow  \
# 0  /home/ubuntu/data/wavefake_data/generated_audi...
# 1  /home/ubuntu/data/wavefake_data/generated_audi...
# 2  /home/ubuntu/data/wavefake_data/generated_audi...
# 3  /home/ubuntu/data/wavefake_data/generated_audi...
# 4  /home/ubuntu/data/wavefake_data/generated_audi...
#
#                                           ElevenLabs  \
# 0  /home/ubuntu/data/wavefake_data/generated_audi...
# 1  /home/ubuntu/data/wavefake_data/generated_audi...
# 2  /home/ubuntu/data/wavefake_data/generated_audi...
# 3  /home/ubuntu/data/wavefake_data/generated_audi...
# 4  /home/ubuntu/data/wavefake_data/generated_audi...
#
#                                             UberDuck  \
# 0  /home/ubuntu/data/wavefake_data/generated_audi...
# 1  /home/ubuntu/data/wavefake_data/generated_audi...
# 2  /home/ubuntu/data/wavefake_data/generated_audi...
# 3  /home/ubuntu/data/wavefake_data/generated_audi...
# 4  /home/ubuntu/data/wavefake_data/generated_audi...
#
#                                         transcript_1  \
# 0  Printing, in the only sense with which we are ...
# 1                     in being comparatively modern.
# 2  For although the Chinese took impressions from...
# 3  produced the block books, which were the immed...
# 4  the invention of movable metal letters in the ...
#
#                                         transcript_2
# 0  Printing, in the only sense with which we are ...
# 1                     in being comparatively modern.
# 2  For although the Chinese took impressions from...
# 3  produced the block books, which were the immed...
# 4  the invention of movable metal letters in the ...

# %%
archs = ['Full_Band_MelGan', 'HifiGan', 'MelGan', 'MelGanLarge', 'Multi_Band_MelGan', 'Parallel_WaveGan', 'Waveglow', 'ElevenLabs', 'UberDuck', 'Real']

# %%
for arch in archs:
    print(f'Currently Generating Embeddings for {arch}')
    paths = list(metadata.loc[~metadata[arch].isna(), arch])
    embeddings = generateTitaNetEmbeddings(speaker_model, paths, False)
    embeddings_df = pd.DataFrame(embeddings)
    embeddings_df['path'] = paths
    embeddings_df.to_csv(f'/home/ubuntu/data/wavefake_data/Embeddings/16KHz_Laundered/{arch}.csv', index=False)
    
    #paths = metadata.sample(5).copy()
    #paths = paths.loc[~paths[arch].isna(), arch].reset_index()[arch]
    #new_series = pd.Series(['/home/ubuntu/data/wavefake_data/generated_audio/ljspeech_elevenlabs/16KHz_Laundered/LJ030-0029.wav']) 
    #paths = pd.concat((paths, new_series))
    #embeddings = generateTitaNetEmbeddings(speaker_model, paths, False)
    #embeddings_df = pd.DataFrame(embeddings)
    #embeddings_df['path'] = list(paths)
# Out:
# Currently Generating Embeddings for Full_Band_MelGan
# [NeMo W 2023-05-02 21:47:46 nemo_logging:349] /home/ubuntu/miniconda3/envs/nemo/lib/python3.8/site-packages/nemo/collections/asr/models/label_models.py:437: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1670525491394/work/torch/csrc/utils/tensor_new.cpp:230.)
#       torch.tensor([audio], device=device),
# Currently Generating Embeddings for HifiGan
# Currently Generating Embeddings for MelGan
# Currently Generating Embeddings for MelGanLarge
# Currently Generating Embeddings for Multi_Band_MelGan
# Currently Generating Embeddings for Parallel_WaveGan
# Currently Generating Embeddings for Waveglow
# Currently Generating Embeddings for ElevenLabs
# Currently Generating Embeddings for UberDuck
# Currently Generating Embeddings for Real

# %%
metadata = pd.read_csv('/home/ubuntu/data/wavefake_data/LJ_metadata_16000KHz.csv')

# %%
metadata[metadata['ElevenLabs'].isna()]
# Out:
#       Unnamed: 0          id Main_ID  Secondary_ID  \
# 2965        2965  LJ011-0058   LJ011            58
# 3405        3405  LJ012-0205   LJ012           205
# 4246        4246  LJ015-0146   LJ015           146
# 4670        4670  LJ016-0257   LJ016           257
# 4684        4684  LJ016-0273   LJ016           273
# 4699        4699  LJ016-0288   LJ016           288
# 4706        4706  LJ016-0295   LJ016           295
# 4713        4713  LJ016-0302   LJ016           302
# 5163        5163  LJ018-0027   LJ018            27
# 5164        5164  LJ018-0028   LJ018            28
# 5165        5165  LJ018-0029   LJ018            29
# 5166        5166  LJ018-0030   LJ018            30
# 5167        5167  LJ018-0031   LJ018            31
# 5169        5169  LJ018-0033   LJ018            33
# 5172        5172  LJ018-0036   LJ018            36
# 5174        5174  LJ018-0038   LJ018            38
# 5182        5182  LJ018-0046   LJ018            46
# 5185        5185  LJ018-0049   LJ018            49
# 5532        5532  LJ018-0396   LJ018           396
# 5935        5935  LJ020-0002   LJ020             2
# 5964        5964  LJ020-0031   LJ020            31
# 5974        5974  LJ020-0041   LJ020            41
# 6039        6039  LJ020-0106   LJ020           106
#
#                                                    Real  \
# 2965  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 3405  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 4246  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 4670  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 4684  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 4699  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 4706  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 4713  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 5163  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 5164  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 5165  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 5166  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 5167  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 5169  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 5172  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 5174  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 5182  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 5185  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 5532  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 5935  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 5964  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 5974  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 6039  /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
#
#                                        Full_Band_MelGan  \
# 2965  /home/ubuntu/data/wavefake_data/generated_audi...
# 3405  /home/ubuntu/data/wavefake_data/generated_audi...
# 4246  /home/ubuntu/data/wavefake_data/generated_audi...
# 4670  /home/ubuntu/data/wavefake_data/generated_audi...
# 4684  /home/ubuntu/data/wavefake_data/generated_audi...
# 4699  /home/ubuntu/data/wavefake_data/generated_audi...
# 4706  /home/ubuntu/data/wavefake_data/generated_audi...
# 4713  /home/ubuntu/data/wavefake_data/generated_audi...
# 5163  /home/ubuntu/data/wavefake_data/generated_audi...
# 5164  /home/ubuntu/data/wavefake_data/generated_audi...
# 5165  /home/ubuntu/data/wavefake_data/generated_audi...
# 5166  /home/ubuntu/data/wavefake_data/generated_audi...
# 5167  /home/ubuntu/data/wavefake_data/generated_audi...
# 5169  /home/ubuntu/data/wavefake_data/generated_audi...
# 5172  /home/ubuntu/data/wavefake_data/generated_audi...
# 5174  /home/ubuntu/data/wavefake_data/generated_audi...
# 5182  /home/ubuntu/data/wavefake_data/generated_audi...
# 5185  /home/ubuntu/data/wavefake_data/generated_audi...
# 5532  /home/ubuntu/data/wavefake_data/generated_audi...
# 5935  /home/ubuntu/data/wavefake_data/generated_audi...
# 5964  /home/ubuntu/data/wavefake_data/generated_audi...
# 5974  /home/ubuntu/data/wavefake_data/generated_audi...
# 6039  /home/ubuntu/data/wavefake_data/generated_audi...
#
#                                                 HifiGan  \
# 2965  /home/ubuntu/data/wavefake_data/generated_audi...
# 3405  /home/ubuntu/data/wavefake_data/generated_audi...
# 4246  /home/ubuntu/data/wavefake_data/generated_audi...
# 4670  /home/ubuntu/data/wavefake_data/generated_audi...
# 4684  /home/ubuntu/data/wavefake_data/generated_audi...
# 4699  /home/ubuntu/data/wavefake_data/generated_audi...
# 4706  /home/ubuntu/data/wavefake_data/generated_audi...
# 4713  /home/ubuntu/data/wavefake_data/generated_audi...
# 5163  /home/ubuntu/data/wavefake_data/generated_audi...
# 5164  /home/ubuntu/data/wavefake_data/generated_audi...
# 5165  /home/ubuntu/data/wavefake_data/generated_audi...
# 5166  /home/ubuntu/data/wavefake_data/generated_audi...
# 5167  /home/ubuntu/data/wavefake_data/generated_audi...
# 5169  /home/ubuntu/data/wavefake_data/generated_audi...
# 5172  /home/ubuntu/data/wavefake_data/generated_audi...
# 5174  /home/ubuntu/data/wavefake_data/generated_audi...
# 5182  /home/ubuntu/data/wavefake_data/generated_audi...
# 5185  /home/ubuntu/data/wavefake_data/generated_audi...
# 5532  /home/ubuntu/data/wavefake_data/generated_audi...
# 5935  /home/ubuntu/data/wavefake_data/generated_audi...
# 5964  /home/ubuntu/data/wavefake_data/generated_audi...
# 5974  /home/ubuntu/data/wavefake_data/generated_audi...
# 6039  /home/ubuntu/data/wavefake_data/generated_audi...
#
#                                                  MelGan  \
# 2965  /home/ubuntu/data/wavefake_data/generated_audi...
# 3405  /home/ubuntu/data/wavefake_data/generated_audi...
# 4246  /home/ubuntu/data/wavefake_data/generated_audi...
# 4670  /home/ubuntu/data/wavefake_data/generated_audi...
# 4684  /home/ubuntu/data/wavefake_data/generated_audi...
# 4699  /home/ubuntu/data/wavefake_data/generated_audi...
# 4706  /home/ubuntu/data/wavefake_data/generated_audi...
# 4713  /home/ubuntu/data/wavefake_data/generated_audi...
# 5163  /home/ubuntu/data/wavefake_data/generated_audi...
# 5164  /home/ubuntu/data/wavefake_data/generated_audi...
# 5165  /home/ubuntu/data/wavefake_data/generated_audi...
# 5166  /home/ubuntu/data/wavefake_data/generated_audi...
# 5167  /home/ubuntu/data/wavefake_data/generated_audi...
# 5169  /home/ubuntu/data/wavefake_data/generated_audi...
# 5172  /home/ubuntu/data/wavefake_data/generated_audi...
# 5174  /home/ubuntu/data/wavefake_data/generated_audi...
# 5182  /home/ubuntu/data/wavefake_data/generated_audi...
# 5185  /home/ubuntu/data/wavefake_data/generated_audi...
# 5532  /home/ubuntu/data/wavefake_data/generated_audi...
# 5935  /home/ubuntu/data/wavefake_data/generated_audi...
# 5964  /home/ubuntu/data/wavefake_data/generated_audi...
# 5974  /home/ubuntu/data/wavefake_data/generated_audi...
# 6039  /home/ubuntu/data/wavefake_data/generated_audi...
#
#                                             MelGanLarge  \
# 2965  /home/ubuntu/data/wavefake_data/generated_audi...
# 3405  /home/ubuntu/data/wavefake_data/generated_audi...
# 4246  /home/ubuntu/data/wavefake_data/generated_audi...
# 4670  /home/ubuntu/data/wavefake_data/generated_audi...
# 4684  /home/ubuntu/data/wavefake_data/generated_audi...
# 4699  /home/ubuntu/data/wavefake_data/generated_audi...
# 4706  /home/ubuntu/data/wavefake_data/generated_audi...
# 4713  /home/ubuntu/data/wavefake_data/generated_audi...
# 5163  /home/ubuntu/data/wavefake_data/generated_audi...
# 5164  /home/ubuntu/data/wavefake_data/generated_audi...
# 5165  /home/ubuntu/data/wavefake_data/generated_audi...
# 5166  /home/ubuntu/data/wavefake_data/generated_audi...
# 5167  /home/ubuntu/data/wavefake_data/generated_audi...
# 5169  /home/ubuntu/data/wavefake_data/generated_audi...
# 5172  /home/ubuntu/data/wavefake_data/generated_audi...
# 5174  /home/ubuntu/data/wavefake_data/generated_audi...
# 5182  /home/ubuntu/data/wavefake_data/generated_audi...
# 5185  /home/ubuntu/data/wavefake_data/generated_audi...
# 5532  /home/ubuntu/data/wavefake_data/generated_audi...
# 5935  /home/ubuntu/data/wavefake_data/generated_audi...
# 5964  /home/ubuntu/data/wavefake_data/generated_audi...
# 5974  /home/ubuntu/data/wavefake_data/generated_audi...
# 6039  /home/ubuntu/data/wavefake_data/generated_audi...
#
#                                       Multi_Band_MelGan  \
# 2965  /home/ubuntu/data/wavefake_data/generated_audi...
# 3405  /home/ubuntu/data/wavefake_data/generated_audi...
# 4246  /home/ubuntu/data/wavefake_data/generated_audi...
# 4670  /home/ubuntu/data/wavefake_data/generated_audi...
# 4684  /home/ubuntu/data/wavefake_data/generated_audi...
# 4699  /home/ubuntu/data/wavefake_data/generated_audi...
# 4706  /home/ubuntu/data/wavefake_data/generated_audi...
# 4713  /home/ubuntu/data/wavefake_data/generated_audi...
# 5163  /home/ubuntu/data/wavefake_data/generated_audi...
# 5164  /home/ubuntu/data/wavefake_data/generated_audi...
# 5165  /home/ubuntu/data/wavefake_data/generated_audi...
# 5166  /home/ubuntu/data/wavefake_data/generated_audi...
# 5167  /home/ubuntu/data/wavefake_data/generated_audi...
# 5169  /home/ubuntu/data/wavefake_data/generated_audi...
# 5172  /home/ubuntu/data/wavefake_data/generated_audi...
# 5174  /home/ubuntu/data/wavefake_data/generated_audi...
# 5182  /home/ubuntu/data/wavefake_data/generated_audi...
# 5185  /home/ubuntu/data/wavefake_data/generated_audi...
# 5532  /home/ubuntu/data/wavefake_data/generated_audi...
# 5935  /home/ubuntu/data/wavefake_data/generated_audi...
# 5964  /home/ubuntu/data/wavefake_data/generated_audi...
# 5974  /home/ubuntu/data/wavefake_data/generated_audi...
# 6039  /home/ubuntu/data/wavefake_data/generated_audi...
#
#                                        Parallel_WaveGan  \
# 2965  /home/ubuntu/data/wavefake_data/generated_audi...
# 3405  /home/ubuntu/data/wavefake_data/generated_audi...
# 4246  /home/ubuntu/data/wavefake_data/generated_audi...
# 4670  /home/ubuntu/data/wavefake_data/generated_audi...
# 4684  /home/ubuntu/data/wavefake_data/generated_audi...
# 4699  /home/ubuntu/data/wavefake_data/generated_audi...
# 4706  /home/ubuntu/data/wavefake_data/generated_audi...
# 4713  /home/ubuntu/data/wavefake_data/generated_audi...
# 5163  /home/ubuntu/data/wavefake_data/generated_audi...
# 5164  /home/ubuntu/data/wavefake_data/generated_audi...
# 5165  /home/ubuntu/data/wavefake_data/generated_audi...
# 5166  /home/ubuntu/data/wavefake_data/generated_audi...
# 5167  /home/ubuntu/data/wavefake_data/generated_audi...
# 5169  /home/ubuntu/data/wavefake_data/generated_audi...
# 5172  /home/ubuntu/data/wavefake_data/generated_audi...
# 5174  /home/ubuntu/data/wavefake_data/generated_audi...
# 5182  /home/ubuntu/data/wavefake_data/generated_audi...
# 5185  /home/ubuntu/data/wavefake_data/generated_audi...
# 5532  /home/ubuntu/data/wavefake_data/generated_audi...
# 5935  /home/ubuntu/data/wavefake_data/generated_audi...
# 5964  /home/ubuntu/data/wavefake_data/generated_audi...
# 5974  /home/ubuntu/data/wavefake_data/generated_audi...
# 6039  /home/ubuntu/data/wavefake_data/generated_audi...
#
#                                                Waveglow ElevenLabs  \
# 2965  /home/ubuntu/data/wavefake_data/generated_audi...        NaN
# 3405  /home/ubuntu/data/wavefake_data/generated_audi...        NaN
# 4246  /home/ubuntu/data/wavefake_data/generated_audi...        NaN
# 4670  /home/ubuntu/data/wavefake_data/generated_audi...        NaN
# 4684  /home/ubuntu/data/wavefake_data/generated_audi...        NaN
# 4699  /home/ubuntu/data/wavefake_data/generated_audi...        NaN
# 4706  /home/ubuntu/data/wavefake_data/generated_audi...        NaN
# 4713  /home/ubuntu/data/wavefake_data/generated_audi...        NaN
# 5163  /home/ubuntu/data/wavefake_data/generated_audi...        NaN
# 5164  /home/ubuntu/data/wavefake_data/generated_audi...        NaN
# 5165  /home/ubuntu/data/wavefake_data/generated_audi...        NaN
# 5166  /home/ubuntu/data/wavefake_data/generated_audi...        NaN
# 5167  /home/ubuntu/data/wavefake_data/generated_audi...        NaN
# 5169  /home/ubuntu/data/wavefake_data/generated_audi...        NaN
# 5172  /home/ubuntu/data/wavefake_data/generated_audi...        NaN
# 5174  /home/ubuntu/data/wavefake_data/generated_audi...        NaN
# 5182  /home/ubuntu/data/wavefake_data/generated_audi...        NaN
# 5185  /home/ubuntu/data/wavefake_data/generated_audi...        NaN
# 5532  /home/ubuntu/data/wavefake_data/generated_audi...        NaN
# 5935  /home/ubuntu/data/wavefake_data/generated_audi...        NaN
# 5964  /home/ubuntu/data/wavefake_data/generated_audi...        NaN
# 5974  /home/ubuntu/data/wavefake_data/generated_audi...        NaN
# 6039  /home/ubuntu/data/wavefake_data/generated_audi...        NaN
#
#                                                UberDuck  \
# 2965  /home/ubuntu/data/wavefake_data/generated_audi...
# 3405  /home/ubuntu/data/wavefake_data/generated_audi...
# 4246  /home/ubuntu/data/wavefake_data/generated_audi...
# 4670  /home/ubuntu/data/wavefake_data/generated_audi...
# 4684  /home/ubuntu/data/wavefake_data/generated_audi...
# 4699  /home/ubuntu/data/wavefake_data/generated_audi...
# 4706  /home/ubuntu/data/wavefake_data/generated_audi...
# 4713  /home/ubuntu/data/wavefake_data/generated_audi...
# 5163  /home/ubuntu/data/wavefake_data/generated_audi...
# 5164  /home/ubuntu/data/wavefake_data/generated_audi...
# 5165  /home/ubuntu/data/wavefake_data/generated_audi...
# 5166  /home/ubuntu/data/wavefake_data/generated_audi...
# 5167  /home/ubuntu/data/wavefake_data/generated_audi...
# 5169  /home/ubuntu/data/wavefake_data/generated_audi...
# 5172  /home/ubuntu/data/wavefake_data/generated_audi...
# 5174  /home/ubuntu/data/wavefake_data/generated_audi...
# 5182  /home/ubuntu/data/wavefake_data/generated_audi...
# 5185  /home/ubuntu/data/wavefake_data/generated_audi...
# 5532  /home/ubuntu/data/wavefake_data/generated_audi...
# 5935  /home/ubuntu/data/wavefake_data/generated_audi...
# 5964  /home/ubuntu/data/wavefake_data/generated_audi...
# 5974  /home/ubuntu/data/wavefake_data/generated_audi...
# 6039  /home/ubuntu/data/wavefake_data/generated_audi...
#
#                                            transcript_1  \
# 2965  He was summoned to the Mansion House, where he...
# 3405  an avowed "snatcher" and habitué of the Fortun...
# 4246  He had a nice taste in bric-à-brac, and was co...
# 4670  and the raison d'être of the penalty, which in...
# 4684  At Müller's execution there was great competit...
# 4699  Müller, Müller, He's the man, till a diversion...
# 4706  curse, or shout, as in this heaving and strugg...
# 4713  He, after failing once to cut the rope, made a...
# 5163  In little more than a week a cabman came forwa...
# 5164  who had been a lodger of his. Müller had given...
# 5165  A photograph of Müller shown the jeweler was i...
# 5166  Last of all, the cabman swore that he had boug...
# 5167  This fixed the crime pretty certainly upon Mül...
# 5169  Directly the foregoing facts were established,...
# 5172  The officers went on board the 'Victoria' at o...
# 5174  and Müller at the time of his capture was actu...
# 5182  Müller protested after sentence of death had b...
# 5185  Müller knew that any confession would ruin his...
# 5532  The greatest causes célèbre, however, of recen...
# 5935  Bread raised with what is known to bakers as a...
# 5964  Into the “crater” dug out in the middle, pour ...
# 5974  The phosphates which the process of “bolting” ...
# 6039  While your bread is taking a three hours’ rise...
#
#                                            transcript_2
# 2965  He was summoned to the Mansion House, where he...
# 3405  an avowed "snatcher" and habitué of the Fortun...
# 4246  He had a nice taste in bric-à-brac, and was co...
# 4670  and the raison d'être of the penalty, which in...
# 4684  At Müller's execution there was great competit...
# 4699  Müller, Müller, He's the man, till a diversion...
# 4706  curse, or shout, as in this heaving and strugg...
# 4713  He, after failing once to cut the rope, made a...
# 5163  In little more than a week a cabman came forwa...
# 5164  who had been a lodger of his. Müller had given...
# 5165  A photograph of Müller shown the jeweler was i...
# 5166  Last of all, the cabman swore that he had boug...
# 5167  This fixed the crime pretty certainly upon Mül...
# 5169  Directly the foregoing facts were established,...
# 5172  The officers went on board the 'Victoria' at o...
# 5174  and Müller at the time of his capture was actu...
# 5182  Müller protested after sentence of death had b...
# 5185  Müller knew that any confession would ruin his...
# 5532  The greatest causes célèbre, however, of recen...
# 5935  Bread raised with what is known to bakers as a...
# 5964  Into the “crater” dug out in the middle, pour ...
# 5974  The phosphates which the process of “bolting” ...
# 6039  While your bread is taking a three hours’ rise...
