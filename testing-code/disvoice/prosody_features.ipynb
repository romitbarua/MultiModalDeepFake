# %% [markdown]
# # Extraction of prosody features from audio files
#
# Compute prosody features from continuous speech.
#
# 103 features are computed:
#
# Num     Feature                                                          Description
#
# --------------------------------------------------------------------------------------------------------------------------
#                                 Features based on F0
#
# ---------------------------------------------------------------------------------------------------------------------------
# 1-6     F0-contour                                                       Avg., Std., Max., Min., Skewness, Kurtosis
#
# 7-12    Tilt of a linear estimation of F0 for each voiced segment        Avg., Std., Max., Min., Skewness, Kurtosis
#
# 13-18   MSE of a linear estimation of F0 for each voiced segment         Avg., Std., Max., Min., Skewness, Kurtosis
#
# 19-24   F0 on the first voiced segment                                   Avg., Std., Max., Min., Skewness, Kurtosis
#
# 25-30   F0 on the last voiced segment                                    Avg., Std., Max., Min., Skewness, Kurtosis
#
# --------------------------------------------------------------------------------------------------------------------------
#                                 Features based on energy
#
# ---------------------------------------------------------------------------------------------------------------------------
# 31-34   energy-contour for voiced segments                               Avg., Std., Skewness, Kurtosis
#
# 35-38   Tilt of a linear estimation of energy contour for V segments     Avg., Std., Skewness, Kurtosis
#
# 39-42   MSE of a linear estimation of energy contour for V segment       Avg., Std., Skewness, Kurtosis
#
# 43-48   energy on the first voiced segment                               Avg., Std., Max., Min., Skewness, Kurtosis
#
# 49-54   energy on the last voiced segment                                Avg., Std., Max., Min., Skewness, Kurtosis
#
# 55-58   energy-contour for unvoiced segments                             Avg., Std., Skewness, Kurtosis
#
# 59-62   Tilt of a linear estimation of energy contour for U segments     Avg., Std., Skewness, Kurtosis
#
# 63-66   MSE of a linear estimation of energy contour for U segments      Avg., Std., Skewness, Kurtosis
#
# 67-72   energy on the first unvoiced segment                             Avg., Std., Max., Min., Skewness, Kurtosis
#
# 73-78   energy on the last unvoiced segment                              Avg., Std., Max., Min., Skewness, Kurtosis
#
# --------------------------------------------------------------------------------------------------------------------------
#                                 Features based on duration
#
# ---------------------------------------------------------------------------------------------------------------------------
# 79      Voiced rate                                                      Number of voiced segments per second
#
# 80-85   Duration of Voiced                                               Avg., Std., Max., Min., Skewness, Kurtosis
#
# 86-91   Duration of Unvoiced                                             Avg., Std., Max., Min., Skewness, Kurtosis
#
# 92-97   Duration of Pauses                                               Avg., Std., Max., Min., Skewness, Kurtosis
#
# 98-103  Duration ratios                                                  Pause/(Voiced+Unvoiced), Pause/Unvoiced, Unvoiced/(Voiced+Unvoiced),
#                                                                          Voiced/(Voiced+Unvoiced), Voiced/Puase, Unvoiced/Pause
#
# ---------------------------------------------------------------------------------------------------------------------------

# %%
import sys
import pandas as pd
import os
import disvoice
from prosody.prosody import Prosody

pd.set_option('display.max_rows', None)

# %%
prosodyf = Prosody()
base_path = "/home/ubuntu/"
file_audio = base_path + "3party_code/disvoice/notebooks_examples/audios/001_ddk1_PCGITA.wav"

# %% [markdown]
# ## Extract features and return them as a numpy array

# %%
features1=prosodyf.extract_features_file(file_audio, static=True, plots=True, fmt="npy")
print(features1.shape)
# Out:
# /home/ubuntu/miniconda3/envs/deepfake-detection/lib/python3.8/site-packages/disvoice/glottal/../prosody/prosody.py:177: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k" (-> color=(0.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   ax1.plot(t, data_audio, 'k', label="speech signal",
# /home/ubuntu/.local/lib/python3.8/site-packages/matplotlib/lines.py:1157: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   neq = current != val
# /home/ubuntu/.local/lib/python3.8/site-packages/matplotlib/axis.py:124: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if labelcolor == 'inherit':
# (103,)

# %% [markdown]
# ## Extract static features and return them as a dataframe

# %%
features1=prosodyf.extract_features_file(file_audio, static=True, plots=False, fmt="csv")
print(features1.T)
# Out:
#                                 0
# F0avg                  103.519859
# F0std                   23.791952
# F0max                  173.218719
# F0min                   80.561127
# F0skew                   1.237559
# F0kurt                   0.598902
# F0tiltavg              -28.648687
# F0mseavg                71.621676
# F0tiltstd              105.563084
# F0msestd               163.103118
# F0tiltmax              307.579427
# F0msemax               610.456905
# F0tiltmin              -99.744998
# F0msemin                 4.899296
# F0tiltskw                2.615539
# F0mseskw                 2.972724
# F0tiltku                 5.626896
# F0mseku                  6.938327
# 1F0mean                 96.801537
# 1F0std                   2.823843
# 1F0max                 106.297119
# 1F0min                  94.436989
# 1F0skw                   2.612422
# 1F0ku                    6.210762
# lastF0avg              120.976585
# lastF0std               38.317226
# lastF0max              173.218719
# lastF0min               80.561127
# lastF0skw                0.242637
# lastF0ku                -1.840673
# avgEvoiced             -20.060993
# stdEvoiced               3.389881
# skwEvoiced               0.166835
# kurtosisEvoiced         -1.077313
# avgtiltEvoiced         -64.650810
# stdtiltEvoiced          30.365483
# skwtiltEvoiced          -0.703285
# kurtosistiltEvoiced     -1.140637
# avgmseEvoiced            0.795596
# stdmseEvoiced            0.634663
# skwmseEvoiced            0.927117
# kurtosismseEvoiced      -0.805091
# avg1Evoiced            -17.898698
# std1Evoiced              1.477560
# max1Evoiced            -15.736897
# min1Evoiced            -19.388852
# skw1Evoiced              0.390920
# kurtosis1Evoiced        -1.633899
# avglastEvoiced         -13.308885
# stdlastEvoiced           1.518022
# maxlastEvoiced         -10.807650
# minlastEvoiced         -15.667443
# skwlastEvoiced           0.447969
# kurtosislastEvoiced     -0.785415
# avgEunvoiced           -39.127407
# stdEunvoiced             7.096889
# skwEunvoiced             0.275178
# kurtosisEunvoiced       -0.919804
# avgtiltEunvoiced       120.108003
# stdtiltEunvoiced       605.019587
# skwtiltEunvoiced         2.604064
# kurtosistiltEunvoiced    4.917076
# avgmseEunvoiced         29.401098
# stdmseEunvoiced         19.314991
# skwmseEunvoiced         -0.381514
# kurtosismseEunvoiced    -1.679759
# avg1Eunvoiced          -35.043433
# std1Eunvoiced            7.876258
# max1Eunvoiced          -19.292661
# min1Eunvoiced          -46.865496
# skw1Eunvoiced            0.417150
# kurtosis1Eunvoiced      -0.758549
# avglastEunvoiced       -36.291275
# stdlastEunvoiced         6.850927
# maxlastEunvoiced       -25.848079
# minlastEunvoiced       -45.889954
# skwlastEunvoiced         0.022197
# kurtosislastEunvoiced   -1.423842
# Vrate                    3.099137
# avgdurvoiced             0.156364
# stddurvoiced             0.069055
# skwdurvoiced             0.935540
# kurtosisdurvoiced       -0.922768
# maxdurvoiced             0.280000
# mindurvoiced             0.100000
# avgdurunvoiced           0.103333
# stddurunvoiced           0.049385
# skwdurunvoiced          -1.046891
# kurtosisdurunvoiced     -0.726444
# maxdurunvoiced           0.140000
# mindurunvoiced           0.010000
# avgdurpause              0.000000
# stddurpause              0.000000
# skwdurpause              0.000000
# kurtosisdurpause         0.000000
# maxdurpause              0.000000
# mindurpause              0.000000
# PVU                      0.000000
# PU                       0.000000
# UVU                      0.000000
# VVU                      0.000000
# VP                       0.000000
# UP                       0.000000

# %% [markdown]
# ## Extract dynamic features and return them as a dataframe

# %%
features1=prosodyf.extract_features_file(file_audio, static=False, plots=False, fmt="csv")
print(features1)
print(features1.head())
# Out:
#         Ecoef0    Ecoef1    Ecoef2    Ecoef3    Ecoef4    Ecoef5  \
# 0   105.702776 -0.000302  0.004222  0.027340 -0.569139  1.528803
# 1   130.392459 -0.002249  0.043573 -0.343251  1.398935 -3.227125
# 2   114.251205  0.000021 -0.001472  0.037513 -0.430769  1.134978
# 3   105.637903 -0.000249  0.002923  0.038836 -0.610899  1.577689
# 4   149.150462  0.001398 -0.039493  0.360269 -1.197304  0.399711
# 5   113.908886  0.000021 -0.001443  0.036175 -0.410373  1.019496
# 6   105.632975 -0.000250  0.002927  0.038802 -0.610802  1.577603
# 7   149.150063  0.001398 -0.039489  0.360243 -1.197224  0.399601
# 8   114.367517  0.000037 -0.002326  0.052690 -0.536308  1.358722
# 9   105.640711 -0.000236  0.002534  0.042916 -0.629691  1.613324
# 10  147.851988  0.003024 -0.072634  0.599051 -1.910331  1.137942
# 11  103.886557  0.000021 -0.001446  0.036454 -0.414043  1.030153
#
#     Voiced duration  f0coef0   f0coef1   f0coef2   f0coef3    f0coef4  \
# 0        -16.680449     0.13 -0.001438  0.049014 -0.611440   3.464429
# 1        -10.421245     0.10  0.012907 -0.337269  3.014453 -10.309874
# 2        -21.534957     0.27 -0.000033  0.002589 -0.078538   1.182602
# 3        -16.693646     0.13 -0.001385  0.047502 -0.596194   3.398860
# 4        -10.789607     0.10 -0.009122  0.219152 -1.980886   8.932986
# 5        -21.462693     0.28 -0.000021  0.001794 -0.060405   1.023308
# 6        -16.693637     0.13 -0.001385  0.047508 -0.596216   3.398581
# 7        -10.789568     0.10 -0.009080  0.218246 -1.974318   8.914847
# 8        -21.614838     0.25 -0.000050  0.003533 -0.096618   1.330586
# 9        -16.707985     0.13 -0.001381  0.047351 -0.594175   3.388170
# 10       -10.783319     0.10 -0.008614  0.205249 -1.836952   8.239092
# 11       -21.436868     0.32  0.000101 -0.009262  0.278798  -2.905255
#
#       f0coef5
# 0   -9.160823
# 1    9.567197
# 2   -9.237471
# 3   -9.045794
# 4  -21.592393
# 5   -8.829779
# 6   -9.043444
# 7  -21.576670
# 8   -9.752222
# 9   -9.028888
# 10 -20.051588
# 11   6.392563
#        Ecoef0    Ecoef1    Ecoef2    Ecoef3    Ecoef4    Ecoef5  \
# 0  105.702776 -0.000302  0.004222  0.027340 -0.569139  1.528803
# 1  130.392459 -0.002249  0.043573 -0.343251  1.398935 -3.227125
# 2  114.251205  0.000021 -0.001472  0.037513 -0.430769  1.134978
# 3  105.637903 -0.000249  0.002923  0.038836 -0.610899  1.577689
# 4  149.150462  0.001398 -0.039493  0.360269 -1.197304  0.399711
#
#    Voiced duration  f0coef0   f0coef1   f0coef2   f0coef3    f0coef4  \
# 0       -16.680449     0.13 -0.001438  0.049014 -0.611440   3.464429
# 1       -10.421245     0.10  0.012907 -0.337269  3.014453 -10.309874
# 2       -21.534957     0.27 -0.000033  0.002589 -0.078538   1.182602
# 3       -16.693646     0.13 -0.001385  0.047502 -0.596194   3.398860
# 4       -10.789607     0.10 -0.009122  0.219152 -1.980886   8.932986
#
#      f0coef5
# 0  -9.160823
# 1   9.567197
# 2  -9.237471
# 3  -9.045794
# 4 -21.592393

# %% [markdown]
# ## Extract dynamic features and return them as a torch tensor

# %%
features1=prosodyf.extract_features_file(file_audio, static=False, plots=False, fmt="torch")
print(features1.dtype)
print(features1.size())
# Out:
# torch.float64
# torch.Size([12, 13])

# %% [markdown]
# ## Extract static features from a path return them as a numpy array

# %%
path_audio="../audios/"
features1=prosodyf.extract_features_path(path_audio, static=True, plots=False, fmt="npy")
print(features1.shape)
# Out:
# Processing 098_u1_PCGITA.wav: 100%|██████████| 4/4 [00:00<00:00, 19.14it/s]
# (4, 103)

# %% [markdown]
# # Extraction of prosody features from audio files
#
# Compute prosody features from continuous speech.
#
# 103 features are computed:
#
# Num     Feature                                                          Description
#
# --------------------------------------------------------------------------------------------------------------------------
#                                 Features based on F0
#
# ---------------------------------------------------------------------------------------------------------------------------
# 1-6     F0-contour                                                       Avg., Std., Max., Min., Skewness, Kurtosis
#
# 7-12    Tilt of a linear estimation of F0 for each voiced segment        Avg., Std., Max., Min., Skewness, Kurtosis
#
# 13-18   MSE of a linear estimation of F0 for each voiced segment         Avg., Std., Max., Min., Skewness, Kurtosis
#
# 19-24   F0 on the first voiced segment                                   Avg., Std., Max., Min., Skewness, Kurtosis
#
# 25-30   F0 on the last voiced segment                                    Avg., Std., Max., Min., Skewness, Kurtosis
#
# --------------------------------------------------------------------------------------------------------------------------
#                                 Features based on energy
#
# ---------------------------------------------------------------------------------------------------------------------------
# 31-34   energy-contour for voiced segments                               Avg., Std., Skewness, Kurtosis
#
# 35-38   Tilt of a linear estimation of energy contour for V segments     Avg., Std., Skewness, Kurtosis
#
# 39-42   MSE of a linear estimation of energy contour for V segment       Avg., Std., Skewness, Kurtosis
#
# 43-48   energy on the first voiced segment                               Avg., Std., Max., Min., Skewness, Kurtosis
#
# 49-54   energy on the last voiced segment                                Avg., Std., Max., Min., Skewness, Kurtosis
#
# 55-58   energy-contour for unvoiced segments                             Avg., Std., Skewness, Kurtosis
#
# 59-62   Tilt of a linear estimation of energy contour for U segments     Avg., Std., Skewness, Kurtosis
#
# 63-66   MSE of a linear estimation of energy contour for U segments      Avg., Std., Skewness, Kurtosis
#
# 67-72   energy on the first unvoiced segment                             Avg., Std., Max., Min., Skewness, Kurtosis
#
# 73-78   energy on the last unvoiced segment                              Avg., Std., Max., Min., Skewness, Kurtosis
#
# --------------------------------------------------------------------------------------------------------------------------
#                                 Features based on duration
#
# ---------------------------------------------------------------------------------------------------------------------------
# 79      Voiced rate                                                      Number of voiced segments per second
#
# 80-85   Duration of Voiced                                               Avg., Std., Max., Min., Skewness, Kurtosis
#
# 86-91   Duration of Unvoiced                                             Avg., Std., Max., Min., Skewness, Kurtosis
#
# 92-97   Duration of Pauses                                               Avg., Std., Max., Min., Skewness, Kurtosis
#
# 98-103  Duration ratios                                                  Pause/(Voiced+Unvoiced), Pause/Unvoiced, Unvoiced/(Voiced+Unvoiced),
#                                                                          Voiced/(Voiced+Unvoiced), Voiced/Puase, Unvoiced/Pause
#
# ---------------------------------------------------------------------------------------------------------------------------

# %%
import sys
import pandas as pd
import os
import disvoice
from prosody.prosody import Prosody

pd.set_option('display.max_rows', None)

# %%
prosodyf = Prosody()
base_path = "/home/ubuntu/"
file_audio = base_path + "3party_code/disvoice/notebooks_examples/audios/001_ddk1_PCGITA.wav"

# %% [markdown]
# ## Extract features and return them as a numpy array

# %%
features1=prosodyf.extract_features_file(file_audio, static=True, plots=True, fmt="npy")
print(features1.shape)
# Out:
# /home/ubuntu/miniconda3/envs/deepfake-detection/lib/python3.8/site-packages/disvoice/glottal/../prosody/prosody.py:177: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k" (-> color=(0.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   ax1.plot(t, data_audio, 'k', label="speech signal",
# /home/ubuntu/.local/lib/python3.8/site-packages/matplotlib/lines.py:1157: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   neq = current != val
# /home/ubuntu/.local/lib/python3.8/site-packages/matplotlib/axis.py:124: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if labelcolor == 'inherit':
# (103,)

# %% [markdown]
# ## Extract static features and return them as a dataframe

# %%
features1=prosodyf.extract_features_file(file_audio, static=True, plots=False, fmt="csv")
print(features1.T)
# Out:
#                                 0
# F0avg                  103.519859
# F0std                   23.791952
# F0max                  173.218719
# F0min                   80.561127
# F0skew                   1.237559
# F0kurt                   0.598902
# F0tiltavg              -28.648687
# F0mseavg                71.621676
# F0tiltstd              105.563084
# F0msestd               163.103118
# F0tiltmax              307.579427
# F0msemax               610.456905
# F0tiltmin              -99.744998
# F0msemin                 4.899296
# F0tiltskw                2.615539
# F0mseskw                 2.972724
# F0tiltku                 5.626896
# F0mseku                  6.938327
# 1F0mean                 96.801537
# 1F0std                   2.823843
# 1F0max                 106.297119
# 1F0min                  94.436989
# 1F0skw                   2.612422
# 1F0ku                    6.210762
# lastF0avg              120.976585
# lastF0std               38.317226
# lastF0max              173.218719
# lastF0min               80.561127
# lastF0skw                0.242637
# lastF0ku                -1.840673
# avgEvoiced             -20.060993
# stdEvoiced               3.389881
# skwEvoiced               0.166835
# kurtosisEvoiced         -1.077313
# avgtiltEvoiced         -64.650810
# stdtiltEvoiced          30.365483
# skwtiltEvoiced          -0.703285
# kurtosistiltEvoiced     -1.140637
# avgmseEvoiced            0.795596
# stdmseEvoiced            0.634663
# skwmseEvoiced            0.927117
# kurtosismseEvoiced      -0.805091
# avg1Evoiced            -17.898698
# std1Evoiced              1.477560
# max1Evoiced            -15.736897
# min1Evoiced            -19.388852
# skw1Evoiced              0.390920
# kurtosis1Evoiced        -1.633899
# avglastEvoiced         -13.308885
# stdlastEvoiced           1.518022
# maxlastEvoiced         -10.807650
# minlastEvoiced         -15.667443
# skwlastEvoiced           0.447969
# kurtosislastEvoiced     -0.785415
# avgEunvoiced           -39.127407
# stdEunvoiced             7.096889
# skwEunvoiced             0.275178
# kurtosisEunvoiced       -0.919804
# avgtiltEunvoiced       120.108003
# stdtiltEunvoiced       605.019587
# skwtiltEunvoiced         2.604064
# kurtosistiltEunvoiced    4.917076
# avgmseEunvoiced         29.401098
# stdmseEunvoiced         19.314991
# skwmseEunvoiced         -0.381514
# kurtosismseEunvoiced    -1.679759
# avg1Eunvoiced          -35.043433
# std1Eunvoiced            7.876258
# max1Eunvoiced          -19.292661
# min1Eunvoiced          -46.865496
# skw1Eunvoiced            0.417150
# kurtosis1Eunvoiced      -0.758549
# avglastEunvoiced       -36.291275
# stdlastEunvoiced         6.850927
# maxlastEunvoiced       -25.848079
# minlastEunvoiced       -45.889954
# skwlastEunvoiced         0.022197
# kurtosislastEunvoiced   -1.423842
# Vrate                    3.099137
# avgdurvoiced             0.156364
# stddurvoiced             0.069055
# skwdurvoiced             0.935540
# kurtosisdurvoiced       -0.922768
# maxdurvoiced             0.280000
# mindurvoiced             0.100000
# avgdurunvoiced           0.103333
# stddurunvoiced           0.049385
# skwdurunvoiced          -1.046891
# kurtosisdurunvoiced     -0.726444
# maxdurunvoiced           0.140000
# mindurunvoiced           0.010000
# avgdurpause              0.000000
# stddurpause              0.000000
# skwdurpause              0.000000
# kurtosisdurpause         0.000000
# maxdurpause              0.000000
# mindurpause              0.000000
# PVU                      0.000000
# PU                       0.000000
# UVU                      0.000000
# VVU                      0.000000
# VP                       0.000000
# UP                       0.000000

# %% [markdown]
# ## Extract dynamic features and return them as a dataframe

# %%
features1=prosodyf.extract_features_file(file_audio, static=False, plots=False, fmt="csv")
print(features1)
print(features1.head())
# Out:
#         Ecoef0    Ecoef1    Ecoef2    Ecoef3    Ecoef4    Ecoef5  \
# 0   105.702776 -0.000302  0.004222  0.027340 -0.569139  1.528803
# 1   130.392459 -0.002249  0.043573 -0.343251  1.398935 -3.227125
# 2   114.251205  0.000021 -0.001472  0.037513 -0.430769  1.134978
# 3   105.637903 -0.000249  0.002923  0.038836 -0.610899  1.577689
# 4   149.150462  0.001398 -0.039493  0.360269 -1.197304  0.399711
# 5   113.908886  0.000021 -0.001443  0.036175 -0.410373  1.019496
# 6   105.632975 -0.000250  0.002927  0.038802 -0.610802  1.577603
# 7   149.150063  0.001398 -0.039489  0.360243 -1.197224  0.399601
# 8   114.367517  0.000037 -0.002326  0.052690 -0.536308  1.358722
# 9   105.640711 -0.000236  0.002534  0.042916 -0.629691  1.613324
# 10  147.851988  0.003024 -0.072634  0.599051 -1.910331  1.137942
# 11  103.886557  0.000021 -0.001446  0.036454 -0.414043  1.030153
#
#     Voiced duration  f0coef0   f0coef1   f0coef2   f0coef3    f0coef4  \
# 0        -16.680449     0.13 -0.001438  0.049014 -0.611440   3.464429
# 1        -10.421245     0.10  0.012907 -0.337269  3.014453 -10.309874
# 2        -21.534957     0.27 -0.000033  0.002589 -0.078538   1.182602
# 3        -16.693646     0.13 -0.001385  0.047502 -0.596194   3.398860
# 4        -10.789607     0.10 -0.009122  0.219152 -1.980886   8.932986
# 5        -21.462693     0.28 -0.000021  0.001794 -0.060405   1.023308
# 6        -16.693637     0.13 -0.001385  0.047508 -0.596216   3.398581
# 7        -10.789568     0.10 -0.009080  0.218246 -1.974318   8.914847
# 8        -21.614838     0.25 -0.000050  0.003533 -0.096618   1.330586
# 9        -16.707985     0.13 -0.001381  0.047351 -0.594175   3.388170
# 10       -10.783319     0.10 -0.008614  0.205249 -1.836952   8.239092
# 11       -21.436868     0.32  0.000101 -0.009262  0.278798  -2.905255
#
#       f0coef5
# 0   -9.160823
# 1    9.567197
# 2   -9.237471
# 3   -9.045794
# 4  -21.592393
# 5   -8.829779
# 6   -9.043444
# 7  -21.576670
# 8   -9.752222
# 9   -9.028888
# 10 -20.051588
# 11   6.392563
#        Ecoef0    Ecoef1    Ecoef2    Ecoef3    Ecoef4    Ecoef5  \
# 0  105.702776 -0.000302  0.004222  0.027340 -0.569139  1.528803
# 1  130.392459 -0.002249  0.043573 -0.343251  1.398935 -3.227125
# 2  114.251205  0.000021 -0.001472  0.037513 -0.430769  1.134978
# 3  105.637903 -0.000249  0.002923  0.038836 -0.610899  1.577689
# 4  149.150462  0.001398 -0.039493  0.360269 -1.197304  0.399711
#
#    Voiced duration  f0coef0   f0coef1   f0coef2   f0coef3    f0coef4  \
# 0       -16.680449     0.13 -0.001438  0.049014 -0.611440   3.464429
# 1       -10.421245     0.10  0.012907 -0.337269  3.014453 -10.309874
# 2       -21.534957     0.27 -0.000033  0.002589 -0.078538   1.182602
# 3       -16.693646     0.13 -0.001385  0.047502 -0.596194   3.398860
# 4       -10.789607     0.10 -0.009122  0.219152 -1.980886   8.932986
#
#      f0coef5
# 0  -9.160823
# 1   9.567197
# 2  -9.237471
# 3  -9.045794
# 4 -21.592393

# %% [markdown]
# ## Extract dynamic features and return them as a torch tensor

# %%
features1=prosodyf.extract_features_file(file_audio, static=False, plots=False, fmt="torch")
print(features1.dtype)
print(features1.size())
# Out:
# torch.float64
# torch.Size([12, 13])

# %% [markdown]
# ## Extract static features from a path return them as a numpy array

# %%
path_audio="../audios/"
features1=prosodyf.extract_features_path(path_audio, static=True, plots=False, fmt="npy")
print(features1.shape)
# Out:
# Processing 098_u1_PCGITA.wav: 100%|██████████| 4/4 [00:00<00:00, 19.14it/s]
# (4, 103)

# %% [markdown]
# # Extraction of prosody features from audio files
#
# Compute prosody features from continuous speech.
#
# 103 features are computed:
#
# Num     Feature                                                          Description
#
# --------------------------------------------------------------------------------------------------------------------------
#                                 Features based on F0
#
# ---------------------------------------------------------------------------------------------------------------------------
# 1-6     F0-contour                                                       Avg., Std., Max., Min., Skewness, Kurtosis
#
# 7-12    Tilt of a linear estimation of F0 for each voiced segment        Avg., Std., Max., Min., Skewness, Kurtosis
#
# 13-18   MSE of a linear estimation of F0 for each voiced segment         Avg., Std., Max., Min., Skewness, Kurtosis
#
# 19-24   F0 on the first voiced segment                                   Avg., Std., Max., Min., Skewness, Kurtosis
#
# 25-30   F0 on the last voiced segment                                    Avg., Std., Max., Min., Skewness, Kurtosis
#
# --------------------------------------------------------------------------------------------------------------------------
#                                 Features based on energy
#
# ---------------------------------------------------------------------------------------------------------------------------
# 31-34   energy-contour for voiced segments                               Avg., Std., Skewness, Kurtosis
#
# 35-38   Tilt of a linear estimation of energy contour for V segments     Avg., Std., Skewness, Kurtosis
#
# 39-42   MSE of a linear estimation of energy contour for V segment       Avg., Std., Skewness, Kurtosis
#
# 43-48   energy on the first voiced segment                               Avg., Std., Max., Min., Skewness, Kurtosis
#
# 49-54   energy on the last voiced segment                                Avg., Std., Max., Min., Skewness, Kurtosis
#
# 55-58   energy-contour for unvoiced segments                             Avg., Std., Skewness, Kurtosis
#
# 59-62   Tilt of a linear estimation of energy contour for U segments     Avg., Std., Skewness, Kurtosis
#
# 63-66   MSE of a linear estimation of energy contour for U segments      Avg., Std., Skewness, Kurtosis
#
# 67-72   energy on the first unvoiced segment                             Avg., Std., Max., Min., Skewness, Kurtosis
#
# 73-78   energy on the last unvoiced segment                              Avg., Std., Max., Min., Skewness, Kurtosis
#
# --------------------------------------------------------------------------------------------------------------------------
#                                 Features based on duration
#
# ---------------------------------------------------------------------------------------------------------------------------
# 79      Voiced rate                                                      Number of voiced segments per second
#
# 80-85   Duration of Voiced                                               Avg., Std., Max., Min., Skewness, Kurtosis
#
# 86-91   Duration of Unvoiced                                             Avg., Std., Max., Min., Skewness, Kurtosis
#
# 92-97   Duration of Pauses                                               Avg., Std., Max., Min., Skewness, Kurtosis
#
# 98-103  Duration ratios                                                  Pause/(Voiced+Unvoiced), Pause/Unvoiced, Unvoiced/(Voiced+Unvoiced),
#                                                                          Voiced/(Voiced+Unvoiced), Voiced/Puase, Unvoiced/Pause
#
# ---------------------------------------------------------------------------------------------------------------------------

# %%
import sys
import pandas as pd
import os
import disvoice
from prosody.prosody import Prosody

pd.set_option('display.max_rows', None)

# %%
prosodyf = Prosody()
base_path = "/home/ubuntu/"
file_audio = base_path + "3party_code/disvoice/notebooks_examples/audios/001_ddk1_PCGITA.wav"

# %% [markdown]
# ## Extract features and return them as a numpy array

# %%
features1=prosodyf.extract_features_file(file_audio, static=True, plots=True, fmt="npy")
print(features1.shape)
# Out:
# /home/ubuntu/miniconda3/envs/deepfake-detection/lib/python3.8/site-packages/disvoice/glottal/../prosody/prosody.py:177: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k" (-> color=(0.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   ax1.plot(t, data_audio, 'k', label="speech signal",
# /home/ubuntu/.local/lib/python3.8/site-packages/matplotlib/lines.py:1157: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   neq = current != val
# /home/ubuntu/.local/lib/python3.8/site-packages/matplotlib/axis.py:124: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if labelcolor == 'inherit':
# (103,)

# %% [markdown]
# ## Extract static features and return them as a dataframe

# %%
features1=prosodyf.extract_features_file(file_audio, static=True, plots=False, fmt="csv")
print(features1.T)
# Out:
#                                 0
# F0avg                  103.519859
# F0std                   23.791952
# F0max                  173.218719
# F0min                   80.561127
# F0skew                   1.237559
# F0kurt                   0.598902
# F0tiltavg              -28.648687
# F0mseavg                71.621676
# F0tiltstd              105.563084
# F0msestd               163.103118
# F0tiltmax              307.579427
# F0msemax               610.456905
# F0tiltmin              -99.744998
# F0msemin                 4.899296
# F0tiltskw                2.615539
# F0mseskw                 2.972724
# F0tiltku                 5.626896
# F0mseku                  6.938327
# 1F0mean                 96.801537
# 1F0std                   2.823843
# 1F0max                 106.297119
# 1F0min                  94.436989
# 1F0skw                   2.612422
# 1F0ku                    6.210762
# lastF0avg              120.976585
# lastF0std               38.317226
# lastF0max              173.218719
# lastF0min               80.561127
# lastF0skw                0.242637
# lastF0ku                -1.840673
# avgEvoiced             -20.060993
# stdEvoiced               3.389881
# skwEvoiced               0.166835
# kurtosisEvoiced         -1.077313
# avgtiltEvoiced         -64.650810
# stdtiltEvoiced          30.365483
# skwtiltEvoiced          -0.703285
# kurtosistiltEvoiced     -1.140637
# avgmseEvoiced            0.795596
# stdmseEvoiced            0.634663
# skwmseEvoiced            0.927117
# kurtosismseEvoiced      -0.805091
# avg1Evoiced            -17.898698
# std1Evoiced              1.477560
# max1Evoiced            -15.736897
# min1Evoiced            -19.388852
# skw1Evoiced              0.390920
# kurtosis1Evoiced        -1.633899
# avglastEvoiced         -13.308885
# stdlastEvoiced           1.518022
# maxlastEvoiced         -10.807650
# minlastEvoiced         -15.667443
# skwlastEvoiced           0.447969
# kurtosislastEvoiced     -0.785415
# avgEunvoiced           -39.127407
# stdEunvoiced             7.096889
# skwEunvoiced             0.275178
# kurtosisEunvoiced       -0.919804
# avgtiltEunvoiced       120.108003
# stdtiltEunvoiced       605.019587
# skwtiltEunvoiced         2.604064
# kurtosistiltEunvoiced    4.917076
# avgmseEunvoiced         29.401098
# stdmseEunvoiced         19.314991
# skwmseEunvoiced         -0.381514
# kurtosismseEunvoiced    -1.679759
# avg1Eunvoiced          -35.043433
# std1Eunvoiced            7.876258
# max1Eunvoiced          -19.292661
# min1Eunvoiced          -46.865496
# skw1Eunvoiced            0.417150
# kurtosis1Eunvoiced      -0.758549
# avglastEunvoiced       -36.291275
# stdlastEunvoiced         6.850927
# maxlastEunvoiced       -25.848079
# minlastEunvoiced       -45.889954
# skwlastEunvoiced         0.022197
# kurtosislastEunvoiced   -1.423842
# Vrate                    3.099137
# avgdurvoiced             0.156364
# stddurvoiced             0.069055
# skwdurvoiced             0.935540
# kurtosisdurvoiced       -0.922768
# maxdurvoiced             0.280000
# mindurvoiced             0.100000
# avgdurunvoiced           0.103333
# stddurunvoiced           0.049385
# skwdurunvoiced          -1.046891
# kurtosisdurunvoiced     -0.726444
# maxdurunvoiced           0.140000
# mindurunvoiced           0.010000
# avgdurpause              0.000000
# stddurpause              0.000000
# skwdurpause              0.000000
# kurtosisdurpause         0.000000
# maxdurpause              0.000000
# mindurpause              0.000000
# PVU                      0.000000
# PU                       0.000000
# UVU                      0.000000
# VVU                      0.000000
# VP                       0.000000
# UP                       0.000000

# %% [markdown]
# ## Extract dynamic features and return them as a dataframe

# %%
features1=prosodyf.extract_features_file(file_audio, static=False, plots=False, fmt="csv")
print(features1)
print(features1.head())
# Out:
#         Ecoef0    Ecoef1    Ecoef2    Ecoef3    Ecoef4    Ecoef5  \
# 0   105.702776 -0.000302  0.004222  0.027340 -0.569139  1.528803
# 1   130.392459 -0.002249  0.043573 -0.343251  1.398935 -3.227125
# 2   114.251205  0.000021 -0.001472  0.037513 -0.430769  1.134978
# 3   105.637903 -0.000249  0.002923  0.038836 -0.610899  1.577689
# 4   149.150462  0.001398 -0.039493  0.360269 -1.197304  0.399711
# 5   113.908886  0.000021 -0.001443  0.036175 -0.410373  1.019496
# 6   105.632975 -0.000250  0.002927  0.038802 -0.610802  1.577603
# 7   149.150063  0.001398 -0.039489  0.360243 -1.197224  0.399601
# 8   114.367517  0.000037 -0.002326  0.052690 -0.536308  1.358722
# 9   105.640711 -0.000236  0.002534  0.042916 -0.629691  1.613324
# 10  147.851988  0.003024 -0.072634  0.599051 -1.910331  1.137942
# 11  103.886557  0.000021 -0.001446  0.036454 -0.414043  1.030153
#
#     Voiced duration  f0coef0   f0coef1   f0coef2   f0coef3    f0coef4  \
# 0        -16.680449     0.13 -0.001438  0.049014 -0.611440   3.464429
# 1        -10.421245     0.10  0.012907 -0.337269  3.014453 -10.309874
# 2        -21.534957     0.27 -0.000033  0.002589 -0.078538   1.182602
# 3        -16.693646     0.13 -0.001385  0.047502 -0.596194   3.398860
# 4        -10.789607     0.10 -0.009122  0.219152 -1.980886   8.932986
# 5        -21.462693     0.28 -0.000021  0.001794 -0.060405   1.023308
# 6        -16.693637     0.13 -0.001385  0.047508 -0.596216   3.398581
# 7        -10.789568     0.10 -0.009080  0.218246 -1.974318   8.914847
# 8        -21.614838     0.25 -0.000050  0.003533 -0.096618   1.330586
# 9        -16.707985     0.13 -0.001381  0.047351 -0.594175   3.388170
# 10       -10.783319     0.10 -0.008614  0.205249 -1.836952   8.239092
# 11       -21.436868     0.32  0.000101 -0.009262  0.278798  -2.905255
#
#       f0coef5
# 0   -9.160823
# 1    9.567197
# 2   -9.237471
# 3   -9.045794
# 4  -21.592393
# 5   -8.829779
# 6   -9.043444
# 7  -21.576670
# 8   -9.752222
# 9   -9.028888
# 10 -20.051588
# 11   6.392563
#        Ecoef0    Ecoef1    Ecoef2    Ecoef3    Ecoef4    Ecoef5  \
# 0  105.702776 -0.000302  0.004222  0.027340 -0.569139  1.528803
# 1  130.392459 -0.002249  0.043573 -0.343251  1.398935 -3.227125
# 2  114.251205  0.000021 -0.001472  0.037513 -0.430769  1.134978
# 3  105.637903 -0.000249  0.002923  0.038836 -0.610899  1.577689
# 4  149.150462  0.001398 -0.039493  0.360269 -1.197304  0.399711
#
#    Voiced duration  f0coef0   f0coef1   f0coef2   f0coef3    f0coef4  \
# 0       -16.680449     0.13 -0.001438  0.049014 -0.611440   3.464429
# 1       -10.421245     0.10  0.012907 -0.337269  3.014453 -10.309874
# 2       -21.534957     0.27 -0.000033  0.002589 -0.078538   1.182602
# 3       -16.693646     0.13 -0.001385  0.047502 -0.596194   3.398860
# 4       -10.789607     0.10 -0.009122  0.219152 -1.980886   8.932986
#
#      f0coef5
# 0  -9.160823
# 1   9.567197
# 2  -9.237471
# 3  -9.045794
# 4 -21.592393

# %% [markdown]
# ## Extract dynamic features and return them as a torch tensor

# %%
features1=prosodyf.extract_features_file(file_audio, static=False, plots=False, fmt="torch")
print(features1.dtype)
print(features1.size())
# Out:
# torch.float64
# torch.Size([12, 13])

# %% [markdown]
# ## Extract static features from a path return them as a numpy array

# %%
path_audio="../audios/"
features1=prosodyf.extract_features_path(path_audio, static=True, plots=False, fmt="npy")
print(features1.shape)
# Out:
# Processing 098_u1_PCGITA.wav: 100%|██████████| 4/4 [00:00<00:00, 19.14it/s]
# (4, 103)

# %% [markdown]
# # Extraction of prosody features from audio files
#
# Compute prosody features from continuous speech.
#
# 103 features are computed:
#
# Num     Feature                                                          Description
#
# --------------------------------------------------------------------------------------------------------------------------
#                                 Features based on F0
#
# ---------------------------------------------------------------------------------------------------------------------------
# 1-6     F0-contour                                                       Avg., Std., Max., Min., Skewness, Kurtosis
#
# 7-12    Tilt of a linear estimation of F0 for each voiced segment        Avg., Std., Max., Min., Skewness, Kurtosis
#
# 13-18   MSE of a linear estimation of F0 for each voiced segment         Avg., Std., Max., Min., Skewness, Kurtosis
#
# 19-24   F0 on the first voiced segment                                   Avg., Std., Max., Min., Skewness, Kurtosis
#
# 25-30   F0 on the last voiced segment                                    Avg., Std., Max., Min., Skewness, Kurtosis
#
# --------------------------------------------------------------------------------------------------------------------------
#                                 Features based on energy
#
# ---------------------------------------------------------------------------------------------------------------------------
# 31-34   energy-contour for voiced segments                               Avg., Std., Skewness, Kurtosis
#
# 35-38   Tilt of a linear estimation of energy contour for V segments     Avg., Std., Skewness, Kurtosis
#
# 39-42   MSE of a linear estimation of energy contour for V segment       Avg., Std., Skewness, Kurtosis
#
# 43-48   energy on the first voiced segment                               Avg., Std., Max., Min., Skewness, Kurtosis
#
# 49-54   energy on the last voiced segment                                Avg., Std., Max., Min., Skewness, Kurtosis
#
# 55-58   energy-contour for unvoiced segments                             Avg., Std., Skewness, Kurtosis
#
# 59-62   Tilt of a linear estimation of energy contour for U segments     Avg., Std., Skewness, Kurtosis
#
# 63-66   MSE of a linear estimation of energy contour for U segments      Avg., Std., Skewness, Kurtosis
#
# 67-72   energy on the first unvoiced segment                             Avg., Std., Max., Min., Skewness, Kurtosis
#
# 73-78   energy on the last unvoiced segment                              Avg., Std., Max., Min., Skewness, Kurtosis
#
# --------------------------------------------------------------------------------------------------------------------------
#                                 Features based on duration
#
# ---------------------------------------------------------------------------------------------------------------------------
# 79      Voiced rate                                                      Number of voiced segments per second
#
# 80-85   Duration of Voiced                                               Avg., Std., Max., Min., Skewness, Kurtosis
#
# 86-91   Duration of Unvoiced                                             Avg., Std., Max., Min., Skewness, Kurtosis
#
# 92-97   Duration of Pauses                                               Avg., Std., Max., Min., Skewness, Kurtosis
#
# 98-103  Duration ratios                                                  Pause/(Voiced+Unvoiced), Pause/Unvoiced, Unvoiced/(Voiced+Unvoiced),
#                                                                          Voiced/(Voiced+Unvoiced), Voiced/Puase, Unvoiced/Pause
#
# ---------------------------------------------------------------------------------------------------------------------------

# %%
import sys
import pandas as pd
import os
import disvoice
from prosody.prosody import Prosody

pd.set_option('display.max_rows', None)

# %%
prosodyf = Prosody()
base_path = "/home/ubuntu/"
file_audio = base_path + "3party_code/disvoice/notebooks_examples/audios/001_ddk1_PCGITA.wav"

# %% [markdown]
# ## Extract features and return them as a numpy array

# %%
features1=prosodyf.extract_features_file(file_audio, static=True, plots=True, fmt="npy")
print(features1.shape)
# Out:
# /home/ubuntu/miniconda3/envs/deepfake-detection/lib/python3.8/site-packages/disvoice/glottal/../prosody/prosody.py:177: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k" (-> color=(0.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   ax1.plot(t, data_audio, 'k', label="speech signal",
# /home/ubuntu/.local/lib/python3.8/site-packages/matplotlib/lines.py:1157: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   neq = current != val
# /home/ubuntu/.local/lib/python3.8/site-packages/matplotlib/axis.py:124: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if labelcolor == 'inherit':
# (103,)

# %% [markdown]
# ## Extract static features and return them as a dataframe

# %%
features1=prosodyf.extract_features_file(file_audio, static=True, plots=False, fmt="csv")
print(features1.T)
# Out:
#                                 0
# F0avg                  103.519859
# F0std                   23.791952
# F0max                  173.218719
# F0min                   80.561127
# F0skew                   1.237559
# F0kurt                   0.598902
# F0tiltavg              -28.648687
# F0mseavg                71.621676
# F0tiltstd              105.563084
# F0msestd               163.103118
# F0tiltmax              307.579427
# F0msemax               610.456905
# F0tiltmin              -99.744998
# F0msemin                 4.899296
# F0tiltskw                2.615539
# F0mseskw                 2.972724
# F0tiltku                 5.626896
# F0mseku                  6.938327
# 1F0mean                 96.801537
# 1F0std                   2.823843
# 1F0max                 106.297119
# 1F0min                  94.436989
# 1F0skw                   2.612422
# 1F0ku                    6.210762
# lastF0avg              120.976585
# lastF0std               38.317226
# lastF0max              173.218719
# lastF0min               80.561127
# lastF0skw                0.242637
# lastF0ku                -1.840673
# avgEvoiced             -20.060993
# stdEvoiced               3.389881
# skwEvoiced               0.166835
# kurtosisEvoiced         -1.077313
# avgtiltEvoiced         -64.650810
# stdtiltEvoiced          30.365483
# skwtiltEvoiced          -0.703285
# kurtosistiltEvoiced     -1.140637
# avgmseEvoiced            0.795596
# stdmseEvoiced            0.634663
# skwmseEvoiced            0.927117
# kurtosismseEvoiced      -0.805091
# avg1Evoiced            -17.898698
# std1Evoiced              1.477560
# max1Evoiced            -15.736897
# min1Evoiced            -19.388852
# skw1Evoiced              0.390920
# kurtosis1Evoiced        -1.633899
# avglastEvoiced         -13.308885
# stdlastEvoiced           1.518022
# maxlastEvoiced         -10.807650
# minlastEvoiced         -15.667443
# skwlastEvoiced           0.447969
# kurtosislastEvoiced     -0.785415
# avgEunvoiced           -39.127407
# stdEunvoiced             7.096889
# skwEunvoiced             0.275178
# kurtosisEunvoiced       -0.919804
# avgtiltEunvoiced       120.108003
# stdtiltEunvoiced       605.019587
# skwtiltEunvoiced         2.604064
# kurtosistiltEunvoiced    4.917076
# avgmseEunvoiced         29.401098
# stdmseEunvoiced         19.314991
# skwmseEunvoiced         -0.381514
# kurtosismseEunvoiced    -1.679759
# avg1Eunvoiced          -35.043433
# std1Eunvoiced            7.876258
# max1Eunvoiced          -19.292661
# min1Eunvoiced          -46.865496
# skw1Eunvoiced            0.417150
# kurtosis1Eunvoiced      -0.758549
# avglastEunvoiced       -36.291275
# stdlastEunvoiced         6.850927
# maxlastEunvoiced       -25.848079
# minlastEunvoiced       -45.889954
# skwlastEunvoiced         0.022197
# kurtosislastEunvoiced   -1.423842
# Vrate                    3.099137
# avgdurvoiced             0.156364
# stddurvoiced             0.069055
# skwdurvoiced             0.935540
# kurtosisdurvoiced       -0.922768
# maxdurvoiced             0.280000
# mindurvoiced             0.100000
# avgdurunvoiced           0.103333
# stddurunvoiced           0.049385
# skwdurunvoiced          -1.046891
# kurtosisdurunvoiced     -0.726444
# maxdurunvoiced           0.140000
# mindurunvoiced           0.010000
# avgdurpause              0.000000
# stddurpause              0.000000
# skwdurpause              0.000000
# kurtosisdurpause         0.000000
# maxdurpause              0.000000
# mindurpause              0.000000
# PVU                      0.000000
# PU                       0.000000
# UVU                      0.000000
# VVU                      0.000000
# VP                       0.000000
# UP                       0.000000

# %% [markdown]
# ## Extract dynamic features and return them as a dataframe

# %%
features1=prosodyf.extract_features_file(file_audio, static=False, plots=False, fmt="csv")
print(features1)
print(features1.head())
# Out:
#         Ecoef0    Ecoef1    Ecoef2    Ecoef3    Ecoef4    Ecoef5  \
# 0   105.702776 -0.000302  0.004222  0.027340 -0.569139  1.528803
# 1   130.392459 -0.002249  0.043573 -0.343251  1.398935 -3.227125
# 2   114.251205  0.000021 -0.001472  0.037513 -0.430769  1.134978
# 3   105.637903 -0.000249  0.002923  0.038836 -0.610899  1.577689
# 4   149.150462  0.001398 -0.039493  0.360269 -1.197304  0.399711
# 5   113.908886  0.000021 -0.001443  0.036175 -0.410373  1.019496
# 6   105.632975 -0.000250  0.002927  0.038802 -0.610802  1.577603
# 7   149.150063  0.001398 -0.039489  0.360243 -1.197224  0.399601
# 8   114.367517  0.000037 -0.002326  0.052690 -0.536308  1.358722
# 9   105.640711 -0.000236  0.002534  0.042916 -0.629691  1.613324
# 10  147.851988  0.003024 -0.072634  0.599051 -1.910331  1.137942
# 11  103.886557  0.000021 -0.001446  0.036454 -0.414043  1.030153
#
#     Voiced duration  f0coef0   f0coef1   f0coef2   f0coef3    f0coef4  \
# 0        -16.680449     0.13 -0.001438  0.049014 -0.611440   3.464429
# 1        -10.421245     0.10  0.012907 -0.337269  3.014453 -10.309874
# 2        -21.534957     0.27 -0.000033  0.002589 -0.078538   1.182602
# 3        -16.693646     0.13 -0.001385  0.047502 -0.596194   3.398860
# 4        -10.789607     0.10 -0.009122  0.219152 -1.980886   8.932986
# 5        -21.462693     0.28 -0.000021  0.001794 -0.060405   1.023308
# 6        -16.693637     0.13 -0.001385  0.047508 -0.596216   3.398581
# 7        -10.789568     0.10 -0.009080  0.218246 -1.974318   8.914847
# 8        -21.614838     0.25 -0.000050  0.003533 -0.096618   1.330586
# 9        -16.707985     0.13 -0.001381  0.047351 -0.594175   3.388170
# 10       -10.783319     0.10 -0.008614  0.205249 -1.836952   8.239092
# 11       -21.436868     0.32  0.000101 -0.009262  0.278798  -2.905255
#
#       f0coef5
# 0   -9.160823
# 1    9.567197
# 2   -9.237471
# 3   -9.045794
# 4  -21.592393
# 5   -8.829779
# 6   -9.043444
# 7  -21.576670
# 8   -9.752222
# 9   -9.028888
# 10 -20.051588
# 11   6.392563
#        Ecoef0    Ecoef1    Ecoef2    Ecoef3    Ecoef4    Ecoef5  \
# 0  105.702776 -0.000302  0.004222  0.027340 -0.569139  1.528803
# 1  130.392459 -0.002249  0.043573 -0.343251  1.398935 -3.227125
# 2  114.251205  0.000021 -0.001472  0.037513 -0.430769  1.134978
# 3  105.637903 -0.000249  0.002923  0.038836 -0.610899  1.577689
# 4  149.150462  0.001398 -0.039493  0.360269 -1.197304  0.399711
#
#    Voiced duration  f0coef0   f0coef1   f0coef2   f0coef3    f0coef4  \
# 0       -16.680449     0.13 -0.001438  0.049014 -0.611440   3.464429
# 1       -10.421245     0.10  0.012907 -0.337269  3.014453 -10.309874
# 2       -21.534957     0.27 -0.000033  0.002589 -0.078538   1.182602
# 3       -16.693646     0.13 -0.001385  0.047502 -0.596194   3.398860
# 4       -10.789607     0.10 -0.009122  0.219152 -1.980886   8.932986
#
#      f0coef5
# 0  -9.160823
# 1   9.567197
# 2  -9.237471
# 3  -9.045794
# 4 -21.592393

# %% [markdown]
# ## Extract dynamic features and return them as a torch tensor

# %%
features1=prosodyf.extract_features_file(file_audio, static=False, plots=False, fmt="torch")
print(features1.dtype)
print(features1.size())
# Out:
# torch.float64
# torch.Size([12, 13])

# %% [markdown]
# ## Extract static features from a path return them as a numpy array

# %%
path_audio="../audios/"
features1=prosodyf.extract_features_path(path_audio, static=True, plots=False, fmt="npy")
print(features1.shape)
# Out:
# Processing 098_u1_PCGITA.wav: 100%|██████████| 4/4 [00:00<00:00, 19.14it/s]
# (4, 103)
