# %% [markdown]
# <a href="https://colab.research.google.com/github/romitbarua/MultiModalDeepFake/blob/main/TestingNotebooks/metadata_update_audio_length.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import fnmatch
import os
import numpy as np
import librosa
import matplotlib.pyplot as plt
import librosa.display
from sklearn.manifold import TSNE
import json
# Importing library 
import csv 
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import IPython.display as ipd
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
filename = '/content/drive/MyDrive/FakeAVCeleb/FakeAVCeleb_v1.2/wav2lip_metadata_updated.csv'
metadata_df = pd.read_csv(filename)

# %%
all_uniq_ids = metadata_df.source.unique()
#select 20
analysis_ids = all_uniq_ids[:20]
#list for filepaths
wav_filepaths = []
sources = []
color = []
targets = []
category = []
#get data
col = 1
for id in analysis_ids:
  temp_df = metadata_df[metadata_df.source==id]
  wav_filepaths.extend(temp_df.wav_filepath.to_list())
  sources.extend(temp_df.source.to_list())
  targets.extend(temp_df.target1.to_list())
  category.extend(temp_df.category.to_list())
  color.extend(len(temp_df.source.to_list())*[col])
  col += 1

# %%
y,sr = librosa.load(wav_filepaths[0])

# %%
y.shape, sr
# Out:
# ((222705,), 22050)

# %%
librosa.get_duration(y,sr)
# Out:
# 10.1

# %%
ipd.Audio(data=y, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
metadata_df.columns
# Out:
# Index(['Unnamed: 0', 'source', 'target1', 'target2', 'method', 'category',
#        'type', 'race', 'gender', 'filename', 'directory_path', 'mp4_filepath',
#        'utterance_file', 'wav_filepath'],
#       dtype='object')

# %%
def get_audio_length(wav_file):
  file_items = wav_file.split('/')
  print("handling file {}".format(file_items[-1]))
  try:
    y,sr = librosa.load(wav_file)
    return librosa.get_duration(y,sr)
  except:
    return np.nan

# %%
print(get_audio_length(wav_filepaths[0]))
# Out:
# handling file 00109.wav
# 10.1

# %%
metadata_df.head()
# Out:
#    Unnamed: 0   source target1 target2 method category                 type  \
# 0           0  id00076       -       -   real        A  RealVideo-RealAudio
# 1           1  id00166       -       -   real        A  RealVideo-RealAudio
# 2           2  id00173       -       -   real        A  RealVideo-RealAudio
# 3           3  id00366       -       -   real        A  RealVideo-RealAudio
# 4           4  id00391       -       -   real        A  RealVideo-RealAudio
#
#       race gender   filename  \
# 0  African    men  00109.mp4
# 1  African    men  00010.mp4
# 2  African    men  00118.mp4
# 3  African    men  00118.mp4
# 4  African    men  00052.mp4
#
#                                       directory_path  \
# 0  FakeAVCeleb/RealVideo-RealAudio/African/men/id...
# 1  FakeAVCeleb/RealVideo-RealAudio/African/men/id...
# 2  FakeAVCeleb/RealVideo-RealAudio/African/men/id...
# 3  FakeAVCeleb/RealVideo-RealAudio/African/men/id...
# 4  FakeAVCeleb/RealVideo-RealAudio/African/men/id...
#
#                                         mp4_filepath utterance_file  \
# 0  /content/drive/MyDrive/FakeAVCeleb/FakeAVCeleb...            NaN
# 1  /content/drive/MyDrive/FakeAVCeleb/FakeAVCeleb...            NaN
# 2  /content/drive/MyDrive/FakeAVCeleb/FakeAVCeleb...            NaN
# 3  /content/drive/MyDrive/FakeAVCeleb/FakeAVCeleb...            NaN
# 4  /content/drive/MyDrive/FakeAVCeleb/FakeAVCeleb...            NaN
#
#                                         wav_filepath
# 0  /content/drive/MyDrive/FakeAVCeleb/FakeAVCeleb...
# 1  /content/drive/MyDrive/FakeAVCeleb/FakeAVCeleb...
# 2  /content/drive/MyDrive/FakeAVCeleb/FakeAVCeleb...
# 3  /content/drive/MyDrive/FakeAVCeleb/FakeAVCeleb...
# 4  /content/drive/MyDrive/FakeAVCeleb/FakeAVCeleb...

# %%
metadata_df['audio_length'] = metadata_df.wav_filepath.apply(get_audio_length)
# Out:
# Streaming output truncated to the last 5000 lines.
# handling file 00053_id06254_wavtolip.wav
# handling file 00053_id06343_wavtolip.wav
# handling file 00053_id06428_wavtolip.wav
# handling file 00083_id00080_wavtolip.wav
# handling file 00083_id02089_wavtolip.wav
# handling file 00083_id03897_wavtolip.wav
# handling file 00083_id04070_wavtolip.wav
# handling file 00083_id04583_wavtolip.wav
# handling file 00083_id05845_wavtolip.wav
# handling file 00083_id05920_wavtolip.wav
# handling file 00083_id06268_wavtolip.wav
# handling file 00083_id06438_wavtolip.wav
# handling file 00083_id06445_wavtolip.wav
# handling file 00092_id02310_wavtolip.wav
# handling file 00092_id03985_wavtolip.wav
# handling file 00092_id04582_wavtolip.wav
# handling file 00092_id05478_wavtolip.wav
# handling file 00092_id05845_wavtolip.wav
# handling file 00092_id06254_wavtolip.wav
# handling file 00092_id06343_wavtolip.wav
# handling file 00092_id06752_wavtolip.wav
# handling file 00092_id07377_wavtolip.wav
# handling file 00092_id07686_wavtolip.wav
# handling file 00139_id00417_wavtolip.wav
# handling file 00139_id00461_wavtolip.wav
# handling file 00139_id02619_wavtolip.wav
# handling file 00139_id03985_wavtolip.wav
# handling file 00139_id05435_wavtolip.wav
# handling file 00139_id05920_wavtolip.wav
# handling file 00139_id05931_wavtolip.wav
# handling file 00139_id06445_wavtolip.wav
# handling file 00139_id07008_wavtolip.wav
# handling file 00139_id07051_wavtolip.wav
# handling file 00015_id00043_wavtolip.wav
# handling file 00015_id00149_wavtolip.wav
# handling file 00015_id00235_wavtolip.wav
# handling file 00015_id03559_wavtolip.wav
# handling file 00015_id04490_wavtolip.wav
# handling file 00015_id04564_wavtolip.wav
# handling file 00015_id04927_wavtolip.wav
# handling file 00015_id06232_wavtolip.wav
# handling file 00015_id06268_wavtolip.wav
# handling file 00015_id07008_wavtolip.wav
# handling file 00023_id00043_wavtolip.wav
# handling file 00023_id00149_wavtolip.wav
# handling file 00023_id02619_wavtolip.wav
# handling file 00023_id03815_wavtolip.wav
# handling file 00023_id04070_wavtolip.wav
# handling file 00023_id04564_wavtolip.wav
# handling file 00023_id04583_wavtolip.wav
# handling file 00023_id06428_wavtolip.wav
# handling file 00023_id06439_wavtolip.wav
# handling file 00023_id07008_wavtolip.wav
# handling file 00118_id00747_wavtolip.wav
# handling file 00118_id02310_wavtolip.wav
# handling file 00118_id02619_wavtolip.wav
# handling file 00118_id04530_wavtolip.wav
# handling file 00118_id05435_wavtolip.wav
# handling file 00118_id06428_wavtolip.wav
# handling file 00118_id06438_wavtolip.wav
# handling file 00118_id06439_wavtolip.wav
# handling file 00118_id07051_wavtolip.wav
# handling file 00118_id07236_wavtolip.wav
# handling file 00021_id00043_wavtolip.wav
# handling file 00021_id03559_wavtolip.wav
# handling file 00021_id04070_wavtolip.wav
# handling file 00021_id04529_wavtolip.wav
# handling file 00021_id04530_wavtolip.wav
# handling file 00021_id05931_wavtolip.wav
# handling file 00021_id06268_wavtolip.wav
# handling file 00021_id06343_wavtolip.wav
# handling file 00021_id07236_wavtolip.wav
# handling file 00021_id07689_wavtolip.wav
# handling file 00005_id00149_wavtolip.wav
# handling file 00005_id01026_wavtolip.wav
# handling file 00005_id02619_wavtolip.wav
# handling file 00005_id04564_wavtolip.wav
# handling file 00005_id06268_wavtolip.wav
# handling file 00005_id06438_wavtolip.wav
# handling file 00005_id06445_wavtolip.wav
# handling file 00005_id07051_wavtolip.wav
# handling file 00005_id07686_wavtolip.wav
# handling file 00005_id07689_wavtolip.wav
# handling file 00072_id00043_wavtolip.wav
# handling file 00072_id00739_wavtolip.wav
# handling file 00072_id02089_wavtolip.wav
# handling file 00072_id02619_wavtolip.wav
# handling file 00072_id04490_wavtolip.wav
# handling file 00072_id04530_wavtolip.wav
# handling file 00072_id04583_wavtolip.wav
# handling file 00072_id04927_wavtolip.wav
# handling file 00072_id05435_wavtolip.wav
# handling file 00072_id06254_wavtolip.wav
# handling file 00054_id00080_wavtolip.wav
# handling file 00054_id04530_wavtolip.wav
# handling file 00054_id04582_wavtolip.wav
# handling file 00054_id05920_wavtolip.wav
# handling file 00054_id06343_wavtolip.wav
# handling file 00054_id06438_wavtolip.wav
# handling file 00054_id07008_wavtolip.wav
# handling file 00054_id07136_wavtolip.wav
# handling file 00054_id07377_wavtolip.wav
# handling file 00054_id07689_wavtolip.wav
# handling file 00186_id00149_wavtolip.wav
# handling file 00186_id03897_wavtolip.wav
# handling file 00186_id04490_wavtolip.wav
# handling file 00186_id04530_wavtolip.wav
# handling file 00186_id04927_wavtolip.wav
# handling file 00186_id06232_wavtolip.wav
# handling file 00186_id07049_wavtolip.wav
# handling file 00186_id07136_wavtolip.wav
# handling file 00186_id07236_wavtolip.wav
# handling file 00186_id07377_wavtolip.wav
# handling file 00231_id00043_wavtolip.wav
# handling file 00231_id00417_wavtolip.wav
# handling file 00231_id00747_wavtolip.wav
# handling file 00231_id01026_wavtolip.wav
# handling file 00231_id03897_wavtolip.wav
# handling file 00231_id05434_wavtolip.wav
# handling file 00231_id05435_wavtolip.wav
# handling file 00231_id06343_wavtolip.wav
# handling file 00231_id06439_wavtolip.wav
# handling file 00231_id07689_wavtolip.wav
# handling file 00417_id00488_wavtolip.wav
# handling file 00417_id00739_wavtolip.wav
# handling file 00417_id01026_wavtolip.wav
# handling file 00417_id02089_wavtolip.wav
# handling file 00417_id04490_wavtolip.wav
# handling file 00417_id04530_wavtolip.wav
# handling file 00417_id06268_wavtolip.wav
# handling file 00417_id07051_wavtolip.wav
# handling file 00417_id07377_wavtolip.wav
# handling file 00417_id07686_wavtolip.wav
# handling file 00180_id00149_wavtolip.wav
# handling file 00180_id00461_wavtolip.wav
# handling file 00180_id00747_wavtolip.wav
# handling file 00180_id04529_wavtolip.wav
# handling file 00180_id04564_wavtolip.wav
# handling file 00180_id04927_wavtolip.wav
# handling file 00180_id06268_wavtolip.wav
# handling file 00180_id06439_wavtolip.wav
# handling file 00180_id07051_wavtolip.wav
# handling file 00180_id07689_wavtolip.wav
# handling file 00077_id00043_wavtolip.wav
# handling file 00077_id00080_wavtolip.wav
# handling file 00077_id00149_wavtolip.wav
# handling file 00077_id01026_wavtolip.wav
# handling file 00077_id03815_wavtolip.wav
# handling file 00077_id04529_wavtolip.wav
# handling file 00077_id06343_wavtolip.wav
# handling file 00077_id06439_wavtolip.wav
# handling file 00077_id07008_wavtolip.wav
# handling file 00077_id07377_wavtolip.wav
# handling file 00013_id00417_wavtolip.wav
# handling file 00013_id00747_wavtolip.wav
# handling file 00013_id04070_wavtolip.wav
# handling file 00013_id04490_wavtolip.wav
# handling file 00013_id04529_wavtolip.wav
# handling file 00013_id06437_wavtolip.wav
# handling file 00013_id06445_wavtolip.wav
# handling file 00013_id07008_wavtolip.wav
# handling file 00013_id07377_wavtolip.wav
# handling file 00013_id07689_wavtolip.wav
# handling file 00052_id00149_wavtolip.wav
# handling file 00052_id00461_wavtolip.wav
# handling file 00052_id00488_wavtolip.wav
# handling file 00052_id03559_wavtolip.wav
# handling file 00052_id03897_wavtolip.wav
# handling file 00052_id04490_wavtolip.wav
# handling file 00052_id04927_wavtolip.wav
# handling file 00052_id05920_wavtolip.wav
# handling file 00052_id06428_wavtolip.wav
# handling file 00052_id06439_wavtolip.wav
# handling file 00107_id00149_wavtolip.wav
# handling file 00107_id00235_wavtolip.wav
# handling file 00107_id04070_wavtolip.wav
# handling file 00107_id04530_wavtolip.wav
# handling file 00107_id04564_wavtolip.wav
# handling file 00107_id05845_wavtolip.wav
# handling file 00107_id05931_wavtolip.wav
# handling file 00107_id06437_wavtolip.wav
# handling file 00107_id07377_wavtolip.wav
# handling file 00107_id07689_wavtolip.wav
# handling file 00135_id00043_wavtolip.wav
# handling file 00135_id00461_wavtolip.wav
# handling file 00135_id02619_wavtolip.wav
# handling file 00135_id05920_wavtolip.wav
# handling file 00135_id06232_wavtolip.wav
# handling file 00135_id06268_wavtolip.wav
# handling file 00135_id06439_wavtolip.wav
# handling file 00135_id06752_wavtolip.wav
# handling file 00135_id07051_wavtolip.wav
# handling file 00135_id07377_wavtolip.wav
# handling file 00027_id00080_wavtolip.wav
# handling file 00027_id00739_wavtolip.wav
# handling file 00027_id02310_wavtolip.wav
# handling file 00027_id04490_wavtolip.wav
# handling file 00027_id04564_wavtolip.wav
# handling file 00027_id05845_wavtolip.wav
# handling file 00027_id05931_wavtolip.wav
# handling file 00027_id06254_wavtolip.wav
# handling file 00027_id06438_wavtolip.wav
# handling file 00027_id06445_wavtolip.wav
# handling file 00161_id00235_wavtolip.wav
# handling file 00161_id00488_wavtolip.wav
# handling file 00161_id04070_wavtolip.wav
# handling file 00161_id05434_wavtolip.wav
# handling file 00161_id05845_wavtolip.wav
# handling file 00161_id05931_wavtolip.wav
# handling file 00161_id06437_wavtolip.wav
# handling file 00161_id07008_wavtolip.wav
# handling file 00161_id07051_wavtolip.wav
# handling file 00161_id07377_wavtolip.wav
# handling file 00013_id00149_wavtolip.wav
# handling file 00013_id00235_wavtolip.wav
# handling file 00013_id02089_wavtolip.wav
# handling file 00013_id03559_wavtolip.wav
# handling file 00013_id04070_wavtolip.wav
# handling file 00013_id04583_wavtolip.wav
# handling file 00013_id05435_wavtolip.wav
# handling file 00013_id06268_wavtolip.wav
# handling file 00013_id07236_wavtolip.wav
# handling file 00013_id07689_wavtolip.wav
# handling file 00025_id00488_wavtolip.wav
# handling file 00025_id02310_wavtolip.wav
# handling file 00025_id03985_wavtolip.wav
# handling file 00025_id05435_wavtolip.wav
# handling file 00025_id05478_wavtolip.wav
# handling file 00025_id06438_wavtolip.wav
# handling file 00025_id06439_wavtolip.wav
# handling file 00025_id07078_wavtolip.wav
# handling file 00025_id07236_wavtolip.wav
# handling file 00025_id07377_wavtolip.wav
# handling file 00043_id00417_wavtolip.wav
# handling file 00043_id02619_wavtolip.wav
# handling file 00043_id03559_wavtolip.wav
# handling file 00043_id04564_wavtolip.wav
# handling file 00043_id06343_wavtolip.wav
# handling file 00043_id06437_wavtolip.wav
# handling file 00043_id06445_wavtolip.wav
# handling file 00043_id07008_wavtolip.wav
# handling file 00043_id07049_wavtolip.wav
# handling file 00043_id07051_wavtolip.wav
# handling file 00159_id00149_wavtolip.wav
# handling file 00159_id01026_wavtolip.wav
# handling file 00159_id02310_wavtolip.wav
# handling file 00159_id04070_wavtolip.wav
# handling file 00159_id04564_wavtolip.wav
# handling file 00159_id05434_wavtolip.wav
# handling file 00159_id05845_wavtolip.wav
# handling file 00159_id06439_wavtolip.wav
# handling file 00159_id06445_wavtolip.wav
# handling file 00159_id07051_wavtolip.wav
# handling file 00023_id00149_wavtolip.wav
# handling file 00023_id00461_wavtolip.wav
# handling file 00023_id00488_wavtolip.wav
# handling file 00023_id00739_wavtolip.wav
# handling file 00023_id01026_wavtolip.wav
# handling file 00023_id02089_wavtolip.wav
# handling file 00023_id03559_wavtolip.wav
# handling file 00023_id05931_wavtolip.wav
# handling file 00023_id06254_wavtolip.wav
# handling file 00023_id07051_wavtolip.wav
# handling file 00043_id00043_wavtolip.wav
# handling file 00043_id02310_wavtolip.wav
# handling file 00043_id03815_wavtolip.wav
# handling file 00043_id04927_wavtolip.wav
# handling file 00043_id05845_wavtolip.wav
# handling file 00043_id06232_wavtolip.wav
# handling file 00043_id06268_wavtolip.wav
# handling file 00043_id06343_wavtolip.wav
# handling file 00043_id06437_wavtolip.wav
# handling file 00043_id07686_wavtolip.wav
# handling file 00028_id02619_wavtolip.wav
# handling file 00028_id03815_wavtolip.wav
# handling file 00028_id03897_wavtolip.wav
# handling file 00028_id04070_wavtolip.wav
# handling file 00028_id04582_wavtolip.wav
# handling file 00028_id04583_wavtolip.wav
# handling file 00028_id06232_wavtolip.wav
# handling file 00028_id06268_wavtolip.wav
# handling file 00028_id07008_wavtolip.wav
# handling file 00028_id07689_wavtolip.wav
# handling file 00110_id00235_wavtolip.wav
# handling file 00110_id00417_wavtolip.wav
# handling file 00110_id00488_wavtolip.wav
# handling file 00110_id04582_wavtolip.wav
# handling file 00110_id05435_wavtolip.wav
# handling file 00110_id05845_wavtolip.wav
# handling file 00110_id05920_wavtolip.wav
# handling file 00110_id05931_wavtolip.wav
# handling file 00110_id06438_wavtolip.wav
# handling file 00110_id06752_wavtolip.wav
# handling file 00118_id00043_wavtolip.wav
# handling file 00118_id00739_wavtolip.wav
# handling file 00118_id02310_wavtolip.wav
# handling file 00118_id02619_wavtolip.wav
# handling file 00118_id04529_wavtolip.wav
# handling file 00118_id05435_wavtolip.wav
# handling file 00118_id06232_wavtolip.wav
# handling file 00118_id06428_wavtolip.wav
# handling file 00118_id06437_wavtolip.wav
# handling file 00118_id06752_wavtolip.wav
# handling file 00150_id00080_wavtolip.wav
# handling file 00150_id02089_wavtolip.wav
# handling file 00150_id02310_wavtolip.wav
# handling file 00150_id03815_wavtolip.wav
# handling file 00150_id04070_wavtolip.wav
# handling file 00150_id04530_wavtolip.wav
# handling file 00150_id05845_wavtolip.wav
# handling file 00150_id06428_wavtolip.wav
# handling file 00150_id06445_wavtolip.wav
# handling file 00150_id07236_wavtolip.wav
# handling file 00221_id00080_wavtolip.wav
# handling file 00221_id00488_wavtolip.wav
# handling file 00221_id04530_wavtolip.wav
# handling file 00221_id06232_wavtolip.wav
# handling file 00221_id06428_wavtolip.wav
# handling file 00221_id06439_wavtolip.wav
# handling file 00221_id06445_wavtolip.wav
# handling file 00221_id07051_wavtolip.wav
# handling file 00221_id07377_wavtolip.wav
# handling file 00221_id07686_wavtolip.wav
# handling file 00175_id00080_wavtolip.wav
# handling file 00175_id03559_wavtolip.wav
# handling file 00175_id03815_wavtolip.wav
# handling file 00175_id04564_wavtolip.wav
# handling file 00175_id04927_wavtolip.wav
# handling file 00175_id05435_wavtolip.wav
# handling file 00175_id06343_wavtolip.wav
# handling file 00175_id07051_wavtolip.wav
# handling file 00175_id07236_wavtolip.wav
# handling file 00175_id07686_wavtolip.wav
# handling file 00043_id00080_wavtolip.wav
# handling file 00043_id00417_wavtolip.wav
# handling file 00043_id02089_wavtolip.wav
# handling file 00043_id03815_wavtolip.wav
# handling file 00043_id04070_wavtolip.wav
# handling file 00043_id04530_wavtolip.wav
# handling file 00043_id05920_wavtolip.wav
# handling file 00043_id06268_wavtolip.wav
# handling file 00043_id06438_wavtolip.wav
# handling file 00043_id06439_wavtolip.wav
# handling file 00083_id00461_wavtolip.wav
# handling file 00083_id00739_wavtolip.wav
# handling file 00083_id01026_wavtolip.wav
# handling file 00083_id02310_wavtolip.wav
# handling file 00083_id03559_wavtolip.wav
# handling file 00083_id04582_wavtolip.wav
# handling file 00083_id05434_wavtolip.wav
# handling file 00083_id05478_wavtolip.wav
# handling file 00083_id06438_wavtolip.wav
# handling file 00083_id07377_wavtolip.wav
# handling file 00405_id00043_wavtolip.wav
# handling file 00405_id00488_wavtolip.wav
# handling file 00405_id00747_wavtolip.wav
# handling file 00405_id03815_wavtolip.wav
# handling file 00405_id04070_wavtolip.wav
# handling file 00405_id04529_wavtolip.wav
# handling file 00405_id04564_wavtolip.wav
# handling file 00405_id05435_wavtolip.wav
# handling file 00405_id07236_wavtolip.wav
# handling file 00405_id07686_wavtolip.wav
# handling file 00052_id00043_wavtolip.wav
# handling file 00052_id02310_wavtolip.wav
# handling file 00052_id03985_wavtolip.wav
# handling file 00052_id04583_wavtolip.wav
# handling file 00052_id05435_wavtolip.wav
# handling file 00052_id05920_wavtolip.wav
# handling file 00052_id06268_wavtolip.wav
# handling file 00052_id07008_wavtolip.wav
# handling file 00052_id07049_wavtolip.wav
# handling file 00052_id07051_wavtolip.wav
# handling file 00143_id00080_wavtolip.wav
# handling file 00143_id00149_wavtolip.wav
# handling file 00143_id00747_wavtolip.wav
# handling file 00143_id03815_wavtolip.wav
# handling file 00143_id04490_wavtolip.wav
# handling file 00143_id06254_wavtolip.wav
# handling file 00143_id06268_wavtolip.wav
# handling file 00143_id06438_wavtolip.wav
# handling file 00143_id07051_wavtolip.wav
# handling file 00143_id07377_wavtolip.wav
# handling file 00025_id00043_wavtolip.wav
# handling file 00025_id00739_wavtolip.wav
# handling file 00025_id02310_wavtolip.wav
# handling file 00025_id03559_wavtolip.wav
# handling file 00025_id03897_wavtolip.wav
# handling file 00025_id04530_wavtolip.wav
# handling file 00025_id05434_wavtolip.wav
# handling file 00025_id06752_wavtolip.wav
# handling file 00025_id07008_wavtolip.wav
# handling file 00025_id07051_wavtolip.wav
# handling file 00254_id00043_wavtolip.wav
# handling file 00254_id00080_wavtolip.wav
# handling file 00254_id02089_wavtolip.wav
# handling file 00254_id02310_wavtolip.wav
# handling file 00254_id04583_wavtolip.wav
# handling file 00254_id06254_wavtolip.wav
# handling file 00254_id06343_wavtolip.wav
# handling file 00254_id06439_wavtolip.wav
# handling file 00254_id06445_wavtolip.wav
# handling file 00254_id07008_wavtolip.wav
# handling file 00028_id00080_wavtolip.wav
# handling file 00028_id00488_wavtolip.wav
# handling file 00028_id01026_wavtolip.wav
# handling file 00028_id03985_wavtolip.wav
# handling file 00028_id04070_wavtolip.wav
# handling file 00028_id05434_wavtolip.wav
# handling file 00028_id06254_wavtolip.wav
# handling file 00028_id06428_wavtolip.wav
# handling file 00028_id06438_wavtolip.wav
# handling file 00028_id06752_wavtolip.wav
# handling file 00109_id00391_wavtolip.wav
# handling file 00109_id00475_wavtolip.wav
# handling file 00109_id00476_wavtolip.wav
# handling file 00109_id00701_wavtolip.wav
# handling file 00109_id01207_wavtolip.wav
# handling file 00109_id01637_wavtolip.wav
# handling file 00109_id01691_wavtolip.wav
# handling file 00109_id01920_wavtolip.wav
# handling file 00109_id02005_wavtolip.wav
# handling file 00109_id02316_wavtolip.wav
# handling file 00010_id00366_wavtolip.wav
# handling file 00010_id00476_wavtolip.wav
# handling file 00010_id00478_wavtolip.wav
# handling file 00010_id00761_wavtolip.wav
# handling file 00010_id01076_wavtolip.wav
# handling file 00010_id01179_wavtolip.wav
# handling file 00010_id01392_wavtolip.wav
# handling file 00010_id01528_wavtolip.wav
# handling file 00010_id01995_wavtolip.wav
# handling file 00010_id02040_wavtolip.wav
# handling file 00118_id00987_wavtolip.wav
# handling file 00118_id01170_wavtolip.wav
# handling file 00118_id01171_wavtolip.wav
# handling file 00118_id01207_wavtolip.wav
# handling file 00118_id01597_wavtolip.wav
# handling file 00118_id01691_wavtolip.wav
# handling file 00118_id01717_wavtolip.wav
# handling file 00118_id02040_wavtolip.wav
# handling file 00118_id02316_wavtolip.wav
# handling file 00118_id02494_wavtolip.wav
# handling file 00118_id00781_wavtolip.wav
# handling file 00118_id01170_wavtolip.wav
# handling file 00118_id01236_wavtolip.wav
# handling file 00118_id01528_wavtolip.wav
# handling file 00118_id01598_wavtolip.wav
# handling file 00118_id01717_wavtolip.wav
# handling file 00118_id01835_wavtolip.wav
# handling file 00118_id01856_wavtolip.wav
# handling file 00118_id02005_wavtolip.wav
# handling file 00118_id02268_wavtolip.wav
# handling file 00052_id00166_wavtolip.wav
# handling file 00052_id00173_wavtolip.wav
# handling file 00052_id00366_wavtolip.wav
# handling file 00052_id01530_wavtolip.wav
# handling file 00052_id01598_wavtolip.wav
# handling file 00052_id01779_wavtolip.wav
# handling file 00052_id01995_wavtolip.wav
# handling file 00052_id02296_wavtolip.wav
# handling file 00052_id02494_wavtolip.wav
# handling file 00052_id04727_wavtolip.wav
# handling file 00099_id00076_wavtolip.wav
# handling file 00099_id00701_wavtolip.wav
# handling file 00099_id01076_wavtolip.wav
# handling file 00099_id01170_wavtolip.wav
# handling file 00099_id01179_wavtolip.wav
# handling file 00099_id01521_wavtolip.wav
# handling file 00099_id01637_wavtolip.wav
# handling file 00099_id01779_wavtolip.wav
# handling file 00099_id02040_wavtolip.wav
# handling file 00099_id02296_wavtolip.wav
# handling file 00109_id00076_wavtolip.wav
# handling file 00109_id00173_wavtolip.wav
# handling file 00109_id00944_wavtolip.wav
# handling file 00109_id01521_wavtolip.wav
# handling file 00109_id01835_wavtolip.wav
# handling file 00109_id02005_wavtolip.wav
# handling file 00109_id02296_wavtolip.wav
# handling file 00109_id02316_wavtolip.wav
# handling file 00109_id02494_wavtolip.wav
# handling file 00109_id04727_wavtolip.wav
# handling file 00206_id00166_wavtolip.wav
# handling file 00206_id00478_wavtolip.wav
# handling file 00206_id00944_wavtolip.wav
# handling file 00206_id01171_wavtolip.wav
# handling file 00206_id01179_wavtolip.wav
# handling file 00206_id01528_wavtolip.wav
# handling file 00206_id01544_wavtolip.wav
# handling file 00206_id01972_wavtolip.wav
# handling file 00206_id02051_wavtolip.wav
# handling file 00206_id04727_wavtolip.wav
# handling file 00031_id00701_wavtolip.wav
# handling file 00031_id00781_wavtolip.wav
# handling file 00031_id01036_wavtolip.wav
# handling file 00031_id01179_wavtolip.wav
# handling file 00031_id01528_wavtolip.wav
# handling file 00031_id01972_wavtolip.wav
# handling file 00031_id01995_wavtolip.wav
# handling file 00031_id02040_wavtolip.wav
# handling file 00031_id02268_wavtolip.wav
# handling file 00092_id00076_wavtolip.wav
# handling file 00092_id00391_wavtolip.wav
# handling file 00092_id00830_wavtolip.wav
# handling file 00092_id00987_wavtolip.wav
# handling file 00092_id01179_wavtolip.wav
# handling file 00092_id01392_wavtolip.wav
# handling file 00092_id01597_wavtolip.wav
# handling file 00092_id01779_wavtolip.wav
# handling file 00092_id01920_wavtolip.wav
# handling file 00092_id02316_wavtolip.wav
# handling file 00072_id00475_wavtolip.wav
# handling file 00072_id00781_wavtolip.wav
# handling file 00072_id00944_wavtolip.wav
# handling file 00072_id01171_wavtolip.wav
# handling file 00072_id01452_wavtolip.wav
# handling file 00072_id01598_wavtolip.wav
# handling file 00072_id01717_wavtolip.wav
# handling file 00072_id01856_wavtolip.wav
# handling file 00072_id01972_wavtolip.wav
# handling file 00072_id02342_wavtolip.wav
# handling file 00092_id00478_wavtolip.wav
# handling file 00092_id00701_wavtolip.wav
# handling file 00092_id00781_wavtolip.wav
# handling file 00092_id01171_wavtolip.wav
# handling file 00092_id01236_wavtolip.wav
# handling file 00092_id01392_wavtolip.wav
# handling file 00092_id01610_wavtolip.wav
# handling file 00092_id02316_wavtolip.wav
# handling file 00092_id02342_wavtolip.wav
# handling file 00143_id00173_wavtolip.wav
# handling file 00143_id00761_wavtolip.wav
# handling file 00143_id01452_wavtolip.wav
# handling file 00143_id01530_wavtolip.wav
# handling file 00143_id01856_wavtolip.wav
# handling file 00143_id02040_wavtolip.wav
# handling file 00143_id02051_wavtolip.wav
# handling file 00143_id02342_wavtolip.wav
# handling file 00143_id02494_wavtolip.wav
# handling file 00143_id04727_wavtolip.wav
# handling file 00135_id00391_wavtolip.wav
# handling file 00135_id00781_wavtolip.wav
# handling file 00135_id00987_wavtolip.wav
# handling file 00135_id01528_wavtolip.wav
# handling file 00135_id01691_wavtolip.wav
# handling file 00135_id01856_wavtolip.wav
# handling file 00135_id01995_wavtolip.wav
# handling file 00135_id02494_wavtolip.wav
# handling file 00135_id04727_wavtolip.wav
# handling file 00160_id00166_wavtolip.wav
# handling file 00160_id00476_wavtolip.wav
# handling file 00160_id00761_wavtolip.wav
# handling file 00160_id01207_wavtolip.wav
# handling file 00160_id01637_wavtolip.wav
# handling file 00160_id01717_wavtolip.wav
# handling file 00160_id01920_wavtolip.wav
# handling file 00160_id02268_wavtolip.wav
# handling file 00160_id02342_wavtolip.wav
# handling file 00160_id04727_wavtolip.wav
# handling file 00010_id00366_wavtolip.wav
# handling file 00010_id00475_wavtolip.wav
# handling file 00010_id01207_wavtolip.wav
# handling file 00010_id01236_wavtolip.wav
# handling file 00010_id01392_wavtolip.wav
# handling file 00010_id01521_wavtolip.wav
# handling file 00010_id01610_wavtolip.wav
# handling file 00010_id01637_wavtolip.wav
# handling file 00010_id01691_wavtolip.wav
# handling file 00010_id02040_wavtolip.wav
# handling file 00005_id00076_wavtolip.wav
# handling file 00005_id00366_wavtolip.wav
# handling file 00005_id00476_wavtolip.wav
# handling file 00005_id00987_wavtolip.wav
# handling file 00005_id01171_wavtolip.wav
# handling file 00005_id01207_wavtolip.wav
# handling file 00005_id01236_wavtolip.wav
# handling file 00005_id01530_wavtolip.wav
# handling file 00005_id01637_wavtolip.wav
# handling file 00005_id04727_wavtolip.wav
# handling file 00021_id00166_wavtolip.wav
# handling file 00021_id00761_wavtolip.wav
# handling file 00021_id01076_wavtolip.wav
# handling file 00021_id01170_wavtolip.wav
# handling file 00021_id01392_wavtolip.wav
# handling file 00021_id01452_wavtolip.wav
# handling file 00021_id01544_wavtolip.wav
# handling file 00021_id01691_wavtolip.wav
# handling file 00021_id01779_wavtolip.wav
# handling file 00021_id01920_wavtolip.wav
# handling file 00053_id00166_wavtolip.wav
# handling file 00053_id00761_wavtolip.wav
# handling file 00053_id01076_wavtolip.wav
# handling file 00053_id01521_wavtolip.wav
# handling file 00053_id01691_wavtolip.wav
# handling file 00053_id01717_wavtolip.wav
# handling file 00053_id01995_wavtolip.wav
# handling file 00053_id02005_wavtolip.wav
# handling file 00053_id02296_wavtolip.wav
# handling file 00053_id02342_wavtolip.wav
# handling file 00160_id00173_wavtolip.wav
# handling file 00160_id00518_wavtolip.wav
# handling file 00160_id01171_wavtolip.wav
# handling file 00160_id01207_wavtolip.wav
# handling file 00160_id01392_wavtolip.wav
# handling file 00160_id01544_wavtolip.wav
# handling file 00160_id01598_wavtolip.wav
# handling file 00160_id01691_wavtolip.wav
# handling file 00160_id01717_wavtolip.wav
# handling file 00160_id02342_wavtolip.wav
# handling file 00320_id00478_wavtolip.wav
# handling file 00320_id00781_wavtolip.wav
# handling file 00320_id01179_wavtolip.wav
# handling file 00320_id01521_wavtolip.wav
# handling file 00320_id01530_wavtolip.wav
# handling file 00320_id01544_wavtolip.wav
# handling file 00320_id01598_wavtolip.wav
# handling file 00320_id01779_wavtolip.wav
# handling file 00320_id02316_wavtolip.wav
# handling file 00320_id04727_wavtolip.wav
# handling file 00005_id00830_wavtolip.wav
# handling file 00005_id00987_wavtolip.wav
# handling file 00005_id01236_wavtolip.wav
# handling file 00005_id01528_wavtolip.wav
# handling file 00005_id01691_wavtolip.wav
# handling file 00005_id01856_wavtolip.wav
# handling file 00005_id01920_wavtolip.wav
# handling file 00005_id02268_wavtolip.wav
# handling file 00005_id02296_wavtolip.wav
# handling file 00005_id02494_wavtolip.wav
# handling file 00167_id00366_wavtolip.wav
# handling file 00167_id00475_wavtolip.wav
# handling file 00167_id00701_wavtolip.wav
# handling file 00167_id00761_wavtolip.wav
# handling file 00167_id01207_wavtolip.wav
# handling file 00167_id01521_wavtolip.wav
# handling file 00167_id01610_wavtolip.wav
# handling file 00167_id01972_wavtolip.wav
# handling file 00167_id02005_wavtolip.wav
# handling file 00167_id02494_wavtolip.wav
# handling file 00001_id00166_wavtolip.wav
# handling file 00001_id00476_wavtolip.wav
# handling file 00001_id00478_wavtolip.wav
# handling file 00001_id00518_wavtolip.wav
# handling file 00001_id00701_wavtolip.wav
# handling file 00001_id01528_wavtolip.wav
# handling file 00001_id01610_wavtolip.wav
# handling file 00001_id01779_wavtolip.wav
# handling file 00001_id02005_wavtolip.wav
# handling file 00109_id00781_wavtolip.wav
# handling file 00109_id00830_wavtolip.wav
# handling file 00109_id00987_wavtolip.wav
# handling file 00109_id01236_wavtolip.wav
# handling file 00109_id01528_wavtolip.wav
# handling file 00109_id01530_wavtolip.wav
# handling file 00109_id01856_wavtolip.wav
# handling file 00109_id01995_wavtolip.wav
# handling file 00109_id02005_wavtolip.wav
# handling file 00109_id02051_wavtolip.wav
# handling file 00017_id00173_wavtolip.wav
# handling file 00017_id00944_wavtolip.wav
# handling file 00017_id00987_wavtolip.wav
# handling file 00017_id01076_wavtolip.wav
# handling file 00017_id01171_wavtolip.wav
# handling file 00017_id01236_wavtolip.wav
# handling file 00017_id01598_wavtolip.wav
# handling file 00017_id02005_wavtolip.wav
# handling file 00017_id02040_wavtolip.wav
# handling file 00017_id02296_wavtolip.wav
# handling file 00002_id00076_wavtolip.wav
# handling file 00002_id00173_wavtolip.wav
# handling file 00002_id00476_wavtolip.wav
# handling file 00002_id01207_wavtolip.wav
# handling file 00002_id01392_wavtolip.wav
# handling file 00002_id01452_wavtolip.wav
# handling file 00002_id01544_wavtolip.wav
# handling file 00002_id02005_wavtolip.wav
# handling file 00002_id02051_wavtolip.wav
# handling file 00002_id02316_wavtolip.wav
# handling file 00044_id00166_wavtolip.wav
# handling file 00044_id00761_wavtolip.wav
# handling file 00044_id01452_wavtolip.wav
# handling file 00044_id01521_wavtolip.wav
# handling file 00044_id01597_wavtolip.wav
# handling file 00044_id01598_wavtolip.wav
# handling file 00044_id01637_wavtolip.wav
# handling file 00044_id01779_wavtolip.wav
# handling file 00044_id01920_wavtolip.wav
# handling file 00044_id02316_wavtolip.wav
# handling file 00005_id00173_wavtolip.wav
# handling file 00005_id00476_wavtolip.wav
# handling file 00005_id00944_wavtolip.wav
# handling file 00005_id01171_wavtolip.wav
# handling file 00005_id01392_wavtolip.wav
# handling file 00005_id01452_wavtolip.wav
# handling file 00005_id01637_wavtolip.wav
# handling file 00005_id01920_wavtolip.wav
# handling file 00005_id02040_wavtolip.wav
# handling file 00005_id02296_wavtolip.wav
# handling file 00044_id00076_wavtolip.wav
# handling file 00044_id00476_wavtolip.wav
# handling file 00044_id00987_wavtolip.wav
# handling file 00044_id01076_wavtolip.wav
# handling file 00044_id01179_wavtolip.wav
# handling file 00044_id01452_wavtolip.wav
# handling file 00044_id01717_wavtolip.wav
# handling file 00044_id01779_wavtolip.wav
# handling file 00044_id02005_wavtolip.wav
# handling file 00044_id02342_wavtolip.wav
# handling file 00090_id00173_wavtolip.wav
# handling file 00090_id00478_wavtolip.wav
# handling file 00090_id00944_wavtolip.wav
# handling file 00090_id01076_wavtolip.wav
# handling file 00090_id01691_wavtolip.wav
# handling file 00090_id01717_wavtolip.wav
# handling file 00090_id01856_wavtolip.wav
# handling file 00090_id02040_wavtolip.wav
# handling file 00090_id02268_wavtolip.wav
# handling file 00090_id02296_wavtolip.wav
# handling file 00002_id00076_wavtolip.wav
# handling file 00002_id00391_wavtolip.wav
# handling file 00002_id00761_wavtolip.wav
# handling file 00002_id01170_wavtolip.wav
# handling file 00002_id01171_wavtolip.wav
# handling file 00002_id01236_wavtolip.wav
# handling file 00002_id01392_wavtolip.wav
# handling file 00002_id01691_wavtolip.wav
# handling file 00002_id02051_wavtolip.wav
# handling file 00002_id02316_wavtolip.wav
# handling file 00045_id00391_wavtolip.wav
# handling file 00045_id00781_wavtolip.wav
# handling file 00045_id00944_wavtolip.wav
# handling file 00045_id01170_wavtolip.wav
# handling file 00045_id01171_wavtolip.wav
# handling file 00045_id01598_wavtolip.wav
# handling file 00045_id01610_wavtolip.wav
# handling file 00045_id01691_wavtolip.wav
# handling file 00045_id01920_wavtolip.wav
# handling file 00045_id02296_wavtolip.wav
# handling file 00005_id00166_wavtolip.wav
# handling file 00005_id00366_wavtolip.wav
# handling file 00005_id00518_wavtolip.wav
# handling file 00005_id00761_wavtolip.wav
# handling file 00005_id00781_wavtolip.wav
# handling file 00005_id00987_wavtolip.wav
# handling file 00005_id01171_wavtolip.wav
# handling file 00005_id01392_wavtolip.wav
# handling file 00005_id01544_wavtolip.wav
# handling file 00005_id04727_wavtolip.wav
# handling file 00010_id00475_wavtolip.wav
# handling file 00010_id00518_wavtolip.wav
# handling file 00010_id00781_wavtolip.wav
# handling file 00010_id01036_wavtolip.wav
# handling file 00010_id01076_wavtolip.wav
# handling file 00010_id01528_wavtolip.wav
# handling file 00010_id01530_wavtolip.wav
# handling file 00010_id01544_wavtolip.wav
# handling file 00010_id01779_wavtolip.wav
# handling file 00010_id02268_wavtolip.wav
# handling file 00130_id00173_wavtolip.wav
# handling file 00130_id00761_wavtolip.wav
# handling file 00130_id00781_wavtolip.wav
# handling file 00130_id01036_wavtolip.wav
# handling file 00130_id01076_wavtolip.wav
# handling file 00130_id01236_wavtolip.wav
# handling file 00130_id01528_wavtolip.wav
# handling file 00130_id02296_wavtolip.wav
# handling file 00130_id04727_wavtolip.wav
# handling file 00006_id00076_wavtolip.wav
# handling file 00006_id00366_wavtolip.wav
# handling file 00006_id00476_wavtolip.wav
# handling file 00006_id00518_wavtolip.wav
# handling file 00006_id00781_wavtolip.wav
# handling file 00006_id00944_wavtolip.wav
# handling file 00006_id00987_wavtolip.wav
# handling file 00006_id01076_wavtolip.wav
# handling file 00006_id01170_wavtolip.wav
# handling file 00006_id02316_wavtolip.wav
# handling file 00099_id00478_wavtolip.wav
# handling file 00099_id00761_wavtolip.wav
# handling file 00099_id00830_wavtolip.wav
# handling file 00099_id00944_wavtolip.wav
# handling file 00099_id00987_wavtolip.wav
# handling file 00099_id01544_wavtolip.wav
# handling file 00099_id01920_wavtolip.wav
# handling file 00099_id01972_wavtolip.wav
# handling file 00099_id01995_wavtolip.wav
# handling file 00028_id00166_wavtolip.wav
# handling file 00028_id00173_wavtolip.wav
# handling file 00028_id00366_wavtolip.wav
# handling file 00028_id00476_wavtolip.wav
# handling file 00028_id00987_wavtolip.wav
# handling file 00028_id01036_wavtolip.wav
# handling file 00028_id01236_wavtolip.wav
# handling file 00028_id01392_wavtolip.wav
# handling file 00028_id01856_wavtolip.wav
# handling file 00028_id01995_wavtolip.wav
# handling file 00078_id00173_wavtolip.wav
# handling file 00078_id00701_wavtolip.wav
# handling file 00078_id00761_wavtolip.wav
# handling file 00078_id00781_wavtolip.wav
# handling file 00078_id01392_wavtolip.wav
# handling file 00078_id01597_wavtolip.wav
# handling file 00078_id01637_wavtolip.wav
# handling file 00078_id01972_wavtolip.wav
# handling file 00078_id04727_wavtolip.wav
# handling file 00071_id00166_wavtolip.wav
# handling file 00071_id00173_wavtolip.wav
# handling file 00071_id00391_wavtolip.wav
# handling file 00071_id00475_wavtolip.wav
# handling file 00071_id01171_wavtolip.wav
# handling file 00071_id01835_wavtolip.wav
# handling file 00071_id01995_wavtolip.wav
# handling file 00071_id02268_wavtolip.wav
# handling file 00071_id02296_wavtolip.wav
# handling file 00071_id04727_wavtolip.wav
# handling file 00052_id00173_wavtolip.wav
# handling file 00052_id00475_wavtolip.wav
# handling file 00052_id00761_wavtolip.wav
# handling file 00052_id00830_wavtolip.wav
# handling file 00052_id00944_wavtolip.wav
# handling file 00052_id01597_wavtolip.wav
# handling file 00052_id01835_wavtolip.wav
# handling file 00052_id01995_wavtolip.wav
# handling file 00052_id02296_wavtolip.wav
# handling file 00052_id04727_wavtolip.wav
# handling file 00476_id00476_wavtolip.wav
# handling file 00476_id00761_wavtolip.wav
# handling file 00476_id00944_wavtolip.wav
# handling file 00476_id01392_wavtolip.wav
# handling file 00476_id01452_wavtolip.wav
# handling file 00476_id01528_wavtolip.wav
# handling file 00476_id01530_wavtolip.wav
# handling file 00476_id01717_wavtolip.wav
# handling file 00476_id01995_wavtolip.wav
# handling file 00476_id02051_wavtolip.wav
# handling file 00015_id00076_wavtolip.wav
# handling file 00015_id00166_wavtolip.wav
# handling file 00015_id00173_wavtolip.wav
# handling file 00015_id00987_wavtolip.wav
# handling file 00015_id01236_wavtolip.wav
# handling file 00015_id01530_wavtolip.wav
# handling file 00015_id01691_wavtolip.wav
# handling file 00015_id01835_wavtolip.wav
# handling file 00015_id02316_wavtolip.wav
# handling file 00015_id02342_wavtolip.wav
# handling file 00036_id00076_wavtolip.wav
# handling file 00036_id00166_wavtolip.wav
# handling file 00036_id00173_wavtolip.wav
# handling file 00036_id00781_wavtolip.wav
# handling file 00036_id01530_wavtolip.wav
# handling file 00036_id01717_wavtolip.wav
# handling file 00036_id01920_wavtolip.wav
# handling file 00036_id02040_wavtolip.wav
# handling file 00036_id02268_wavtolip.wav
# handling file 00036_id02316_wavtolip.wav
# handling file 00019_id00366_wavtolip.wav
# handling file 00019_id00781_wavtolip.wav
# handling file 00019_id01036_wavtolip.wav
# handling file 00019_id01171_wavtolip.wav
# handling file 00019_id01207_wavtolip.wav
# handling file 00019_id01392_wavtolip.wav
# handling file 00019_id01717_wavtolip.wav
# handling file 00019_id01835_wavtolip.wav
# handling file 00019_id02005_wavtolip.wav
# handling file 00094_id00830_wavtolip.wav
# handling file 00094_id00944_wavtolip.wav
# handling file 00094_id00987_wavtolip.wav
# handling file 00094_id01171_wavtolip.wav
# handling file 00094_id01179_wavtolip.wav
# handling file 00094_id01392_wavtolip.wav
# handling file 00094_id01528_wavtolip.wav
# handling file 00094_id01530_wavtolip.wav
# handling file 00094_id01920_wavtolip.wav
# handling file 00094_id04727_wavtolip.wav
# handling file 00191_id00076_wavtolip.wav
# handling file 00191_id00476_wavtolip.wav
# handling file 00191_id00781_wavtolip.wav
# handling file 00191_id01171_wavtolip.wav
# handling file 00191_id01207_wavtolip.wav
# handling file 00191_id01521_wavtolip.wav
# handling file 00191_id01610_wavtolip.wav
# handling file 00191_id01717_wavtolip.wav
# handling file 00191_id01995_wavtolip.wav
# handling file 00191_id02051_wavtolip.wav
# handling file 00050_id00166_wavtolip.wav
# handling file 00050_id00173_wavtolip.wav
# handling file 00050_id00944_wavtolip.wav
# handling file 00050_id01036_wavtolip.wav
# handling file 00050_id01179_wavtolip.wav
# handling file 00050_id01530_wavtolip.wav
# handling file 00050_id01717_wavtolip.wav
# handling file 00050_id01856_wavtolip.wav
# handling file 00050_id02005_wavtolip.wav
# handling file 00050_id02051_wavtolip.wav
# handling file 00007_id00518_wavtolip.wav
# handling file 00007_id00987_wavtolip.wav
# handling file 00007_id01036_wavtolip.wav
# handling file 00007_id01236_wavtolip.wav
# handling file 00007_id01637_wavtolip.wav
# handling file 00007_id01920_wavtolip.wav
# handling file 00007_id01972_wavtolip.wav
# handling file 00007_id02040_wavtolip.wav
# handling file 00007_id02342_wavtolip.wav
# handling file 00007_id04727_wavtolip.wav
# handling file 00027_id00220_wavtolip.wav
# handling file 00027_id00707_wavtolip.wav
# handling file 00027_id02617_wavtolip.wav
# handling file 00027_id02838_wavtolip.wav
# handling file 00027_id02948_wavtolip.wav
# handling file 00027_id03658_wavtolip.wav
# handling file 00027_id05252_wavtolip.wav
# handling file 00053_id00460_wavtolip.wav
# handling file 00053_id01178_wavtolip.wav
# handling file 00053_id01838_wavtolip.wav
# handling file 00053_id02508_wavtolip.wav
# handling file 00053_id02721_wavtolip.wav
# handling file 00053_id02948_wavtolip.wav
# handling file 00053_id04376_wavtolip.wav
# handling file 00053_id04437_wavtolip.wav
# handling file 00053_id04736_wavtolip.wav
# handling file 00053_id05980_wavtolip.wav
# handling file 00099_id00220_wavtolip.wav
# handling file 00099_id00371_wavtolip.wav
# handling file 00099_id00460_wavtolip.wav
# handling file 00099_id00832_wavtolip.wav
# handling file 00099_id02301_wavtolip.wav
# handling file 00099_id02586_wavtolip.wav
# handling file 00099_id02617_wavtolip.wav
# handling file 00099_id04055_wavtolip.wav
# handling file 00099_id04705_wavtolip.wav
# handling file 00099_id05106_wavtolip.wav
# handling file 00005_id00220_wavtolip.wav
# handling file 00005_id00460_wavtolip.wav
# handling file 00005_id00577_wavtolip.wav
# handling file 00005_id01783_wavtolip.wav
# handling file 00005_id02301_wavtolip.wav
# handling file 00005_id02824_wavtolip.wav
# handling file 00005_id04376_wavtolip.wav
# handling file 00005_id04705_wavtolip.wav
# handling file 00005_id05252_wavtolip.wav
# handling file 00384_id00371_wavtolip.wav
# handling file 00384_id00460_wavtolip.wav
# handling file 00384_id00829_wavtolip.wav
# handling file 00384_id00832_wavtolip.wav
# handling file 00384_id01178_wavtolip.wav
# handling file 00384_id02301_wavtolip.wav
# handling file 00384_id03569_wavtolip.wav
# handling file 00384_id03656_wavtolip.wav
# handling file 00384_id04376_wavtolip.wav
# handling file 00384_id04820_wavtolip.wav
# handling file 00010_id00220_wavtolip.wav
# handling file 00010_id00592_wavtolip.wav
# handling file 00010_id00707_wavtolip.wav
# handling file 00010_id00829_wavtolip.wav
# handling file 00010_id01661_wavtolip.wav
# handling file 00010_id01838_wavtolip.wav
# handling file 00010_id02301_wavtolip.wav
# handling file 00010_id03658_wavtolip.wav
# handling file 00010_id05251_wavtolip.wav
# handling file 00010_id05252_wavtolip.wav
# handling file 00017_id00568_wavtolip.wav
# handling file 00017_id00592_wavtolip.wav
# handling file 00017_id00707_wavtolip.wav
# handling file 00017_id01661_wavtolip.wav
# handling file 00017_id02301_wavtolip.wav
# handling file 00017_id02824_wavtolip.wav
# handling file 00017_id02948_wavtolip.wav
# handling file 00017_id03656_wavtolip.wav
# handling file 00017_id05251_wavtolip.wav
# handling file 00052_id00220_wavtolip.wav
# handling file 00052_id00568_wavtolip.wav
# handling file 00052_id00829_wavtolip.wav
# handling file 00052_id01907_wavtolip.wav
# handling file 00052_id02508_wavtolip.wav
# handling file 00052_id02824_wavtolip.wav
# handling file 00052_id04820_wavtolip.wav
# handling file 00052_id05235_wavtolip.wav
# handling file 00271_id00371_wavtolip.wav
# handling file 00271_id01838_wavtolip.wav
# handling file 00271_id02586_wavtolip.wav
# handling file 00271_id02721_wavtolip.wav
# handling file 00271_id03713_wavtolip.wav
# handling file 00271_id03747_wavtolip.wav
# handling file 00271_id05235_wavtolip.wav
# handling file 00271_id05252_wavtolip.wav
# handling file 00078_id00707_wavtolip.wav
# handling file 00078_id01783_wavtolip.wav
# handling file 00078_id01907_wavtolip.wav
# handling file 00078_id02301_wavtolip.wav
# handling file 00078_id03656_wavtolip.wav
# handling file 00078_id04540_wavtolip.wav
# handling file 00078_id04689_wavtolip.wav
# handling file 00078_id04705_wavtolip.wav
# handling file 00078_id05980_wavtolip.wav
# handling file 00028_id00220_wavtolip.wav
# handling file 00028_id00577_wavtolip.wav
# handling file 00028_id00829_wavtolip.wav
# handling file 00028_id00832_wavtolip.wav
# handling file 00028_id01178_wavtolip.wav
# handling file 00028_id01783_wavtolip.wav
# handling file 00028_id04705_wavtolip.wav
# handling file 00028_id05252_wavtolip.wav
# handling file 00065_id00359_wavtolip.wav
# handling file 00065_id00568_wavtolip.wav
# handling file 00065_id00707_wavtolip.wav
# handling file 00065_id00832_wavtolip.wav
# handling file 00065_id02721_wavtolip.wav
# handling file 00065_id02824_wavtolip.wav
# handling file 00065_id02948_wavtolip.wav
# handling file 00065_id03713_wavtolip.wav
# handling file 00065_id04736_wavtolip.wav
# handling file 00065_id04820_wavtolip.wav
# handling file 00059_id00371_wavtolip.wav
# handling file 00059_id00577_wavtolip.wav
# handling file 00059_id00592_wavtolip.wav
# handling file 00059_id01661_wavtolip.wav
# handling file 00059_id01838_wavtolip.wav
# handling file 00059_id02071_wavtolip.wav
# handling file 00059_id02508_wavtolip.wav
# handling file 00059_id03656_wavtolip.wav
# handling file 00059_id03713_wavtolip.wav
# handling file 00059_id04055_wavtolip.wav
# handling file 00015_id00829_wavtolip.wav
# handling file 00015_id01178_wavtolip.wav
# handling file 00015_id01783_wavtolip.wav
# handling file 00015_id02508_wavtolip.wav
# handling file 00015_id02824_wavtolip.wav
# handling file 00015_id03569_wavtolip.wav
# handling file 00015_id04376_wavtolip.wav
# handling file 00015_id04736_wavtolip.wav
# handling file 00015_id04939_wavtolip.wav
# handling file 00126_id00460_wavtolip.wav
# handling file 00126_id00707_wavtolip.wav
# handling file 00126_id01661_wavtolip.wav
# handling file 00126_id01838_wavtolip.wav
# handling file 00126_id02508_wavtolip.wav
# handling file 00126_id03713_wavtolip.wav
# handling file 00126_id03747_wavtolip.wav
# handling file 00126_id05251_wavtolip.wav
# handling file 00148_id01838_wavtolip.wav
# handling file 00148_id02586_wavtolip.wav
# handling file 00148_id03569_wavtolip.wav
# handling file 00148_id03747_wavtolip.wav
# handling file 00148_id04055_wavtolip.wav
# handling file 00148_id04705_wavtolip.wav
# handling file 00148_id04736_wavtolip.wav
# handling file 00148_id04820_wavtolip.wav
# handling file 00148_id04939_wavtolip.wav
# handling file 00195_id00359_wavtolip.wav
# handling file 00195_id00460_wavtolip.wav
# handling file 00195_id01661_wavtolip.wav
# handling file 00195_id01907_wavtolip.wav
# handling file 00195_id02721_wavtolip.wav
# handling file 00195_id02838_wavtolip.wav
# handling file 00195_id03747_wavtolip.wav
# handling file 00195_id04689_wavtolip.wav
# handling file 00195_id04939_wavtolip.wav
# handling file 00195_id05252_wavtolip.wav
# handling file 00092_id00577_wavtolip.wav
# handling file 00092_id00829_wavtolip.wav
# handling file 00092_id02586_wavtolip.wav
# handling file 00092_id02721_wavtolip.wav
# handling file 00092_id02838_wavtolip.wav
# handling file 00092_id04736_wavtolip.wav
# handling file 00092_id05235_wavtolip.wav
# handling file 00092_id05252_wavtolip.wav
# handling file 00092_id05980_wavtolip.wav
# handling file 00083_id00460_wavtolip.wav
# handling file 00083_id00592_wavtolip.wav
# handling file 00083_id01783_wavtolip.wav
# handling file 00083_id03656_wavtolip.wav
# handling file 00083_id04437_wavtolip.wav
# handling file 00083_id04540_wavtolip.wav
# handling file 00083_id04689_wavtolip.wav
# handling file 00083_id04736_wavtolip.wav
# handling file 00083_id05252_wavtolip.wav
# handling file 00042_id01532_wavtolip.wav
# handling file 00042_id01838_wavtolip.wav
# handling file 00042_id02071_wavtolip.wav
# handling file 00042_id02586_wavtolip.wav
# handling file 00042_id02824_wavtolip.wav
# handling file 00042_id03747_wavtolip.wav
# handling file 00042_id04820_wavtolip.wav
# handling file 00042_id05980_wavtolip.wav
# handling file 00028_id00371_wavtolip.wav
# handling file 00028_id00592_wavtolip.wav
# handling file 00028_id00829_wavtolip.wav
# handling file 00028_id01178_wavtolip.wav
# handling file 00028_id01532_wavtolip.wav
# handling file 00028_id02721_wavtolip.wav
# handling file 00028_id03656_wavtolip.wav
# handling file 00028_id03658_wavtolip.wav
# handling file 00028_id05231_wavtolip.wav
# handling file 00424_id00359_wavtolip.wav
# handling file 00424_id00707_wavtolip.wav
# handling file 00424_id01178_wavtolip.wav
# handling file 00424_id01661_wavtolip.wav
# handling file 00424_id01783_wavtolip.wav
# handling file 00424_id02071_wavtolip.wav
# handling file 00424_id02617_wavtolip.wav
# handling file 00424_id02721_wavtolip.wav
# handling file 00424_id02824_wavtolip.wav
# handling file 00424_id03658_wavtolip.wav
# handling file 00056_id00359_wavtolip.wav
# handling file 00056_id00371_wavtolip.wav
# handling file 00056_id00592_wavtolip.wav
# handling file 00056_id00707_wavtolip.wav
# handling file 00056_id00829_wavtolip.wav
# handling file 00056_id01532_wavtolip.wav
# handling file 00056_id05231_wavtolip.wav
# handling file 00056_id05252_wavtolip.wav
# handling file 00130_id00359_wavtolip.wav
# handling file 00130_id00568_wavtolip.wav
# handling file 00130_id00829_wavtolip.wav
# handling file 00130_id00832_wavtolip.wav
# handling file 00130_id01532_wavtolip.wav
# handling file 00130_id02301_wavtolip.wav
# handling file 00130_id02824_wavtolip.wav
# handling file 00130_id04437_wavtolip.wav
# handling file 00130_id05106_wavtolip.wav
# handling file 00130_id05252_wavtolip.wav
# handling file 00080_id00568_wavtolip.wav
# handling file 00080_id01532_wavtolip.wav
# handling file 00080_id02617_wavtolip.wav
# handling file 00080_id02948_wavtolip.wav
# handling file 00080_id03569_wavtolip.wav
# handling file 00080_id03713_wavtolip.wav
# handling file 00080_id04705_wavtolip.wav
# handling file 00080_id04820_wavtolip.wav
# handling file 00080_id05251_wavtolip.wav
# handling file 00298_id00371_wavtolip.wav
# handling file 00298_id00707_wavtolip.wav
# handling file 00298_id00832_wavtolip.wav
# handling file 00298_id02586_wavtolip.wav
# handling file 00298_id03713_wavtolip.wav
# handling file 00298_id03747_wavtolip.wav
# handling file 00298_id04055_wavtolip.wav
# handling file 00298_id04939_wavtolip.wav
# handling file 00298_id05106_wavtolip.wav
# handling file 00130_id00371_wavtolip.wav
# handling file 00130_id01532_wavtolip.wav
# handling file 00130_id01907_wavtolip.wav
# handling file 00130_id02721_wavtolip.wav
# handling file 00130_id02838_wavtolip.wav
# handling file 00130_id02948_wavtolip.wav
# handling file 00130_id05231_wavtolip.wav
# handling file 00130_id05235_wavtolip.wav
# handling file 00130_id05252_wavtolip.wav
# handling file 00130_id05980_wavtolip.wav
# handling file 00065_id00371_wavtolip.wav
# handling file 00065_id00460_wavtolip.wav
# handling file 00065_id01838_wavtolip.wav
# handling file 00065_id02586_wavtolip.wav
# handling file 00065_id02721_wavtolip.wav
# handling file 00065_id02808_wavtolip.wav
# handling file 00065_id04437_wavtolip.wav
# handling file 00065_id04689_wavtolip.wav
# handling file 00065_id04820_wavtolip.wav
# handling file 00052_id00220_wavtolip.wav
# handling file 00052_id00359_wavtolip.wav
# handling file 00052_id00707_wavtolip.wav
# handling file 00052_id02508_wavtolip.wav
# handling file 00052_id02721_wavtolip.wav
# handling file 00052_id02838_wavtolip.wav
# handling file 00052_id03658_wavtolip.wav
# handling file 00052_id04376_wavtolip.wav
# handling file 00052_id04689_wavtolip.wav
# handling file 00077_id00592_wavtolip.wav
# ...
# handling file 00083_id00149_wavtolip.wav
# handling file 00083_id00235_wavtolip.wav
# handling file 00083_id00488_wavtolip.wav
# handling file 00083_id02089_wavtolip.wav
# handling file 00083_id03897_wavtolip.wav
# handling file 00083_id05931_wavtolip.wav
# handling file 00083_id06268_wavtolip.wav
# handling file 00083_id06437_wavtolip.wav
# handling file 00083_id06439_wavtolip.wav
# handling file 00083_id07686_wavtolip.wav
# handling file 00092_id00739_wavtolip.wav
# handling file 00092_id01026_wavtolip.wav
# handling file 00092_id02310_wavtolip.wav
# handling file 00092_id03897_wavtolip.wav
# handling file 00092_id04529_wavtolip.wav
# handling file 00092_id04927_wavtolip.wav
# handling file 00092_id06428_wavtolip.wav
# handling file 00092_id07051_wavtolip.wav
# handling file 00092_id07686_wavtolip.wav
# handling file 00139_id03815_wavtolip.wav
# handling file 00139_id04070_wavtolip.wav
# handling file 00139_id04530_wavtolip.wav
# handling file 00139_id05434_wavtolip.wav
# handling file 00139_id05435_wavtolip.wav
# handling file 00139_id05931_wavtolip.wav
# handling file 00139_id06752_wavtolip.wav
# handling file 00139_id07049_wavtolip.wav
# handling file 00139_id07689_wavtolip.wav
# handling file 00015_id00739_wavtolip.wav
# handling file 00015_id04490_wavtolip.wav
# handling file 00015_id04583_wavtolip.wav
# handling file 00015_id04927_wavtolip.wav
# handling file 00015_id05434_wavtolip.wav
# handling file 00015_id05931_wavtolip.wav
# handling file 00015_id06438_wavtolip.wav
# handling file 00015_id06439_wavtolip.wav
# handling file 00015_id07236_wavtolip.wav
# handling file 00015_id07377_wavtolip.wav
# handling file 00023_id00043_wavtolip.wav
# handling file 00023_id00461_wavtolip.wav
# handling file 00023_id02619_wavtolip.wav
# handling file 00023_id04070_wavtolip.wav
# handling file 00023_id04530_wavtolip.wav
# handling file 00023_id05478_wavtolip.wav
# handling file 00023_id06437_wavtolip.wav
# handling file 00023_id07051_wavtolip.wav
# handling file 00023_id07689_wavtolip.wav
# handling file 00118_id00149_wavtolip.wav
# handling file 00118_id00747_wavtolip.wav
# handling file 00118_id01026_wavtolip.wav
# handling file 00118_id03985_wavtolip.wav
# handling file 00118_id04070_wavtolip.wav
# handling file 00118_id04529_wavtolip.wav
# handling file 00118_id04564_wavtolip.wav
# handling file 00118_id05434_wavtolip.wav
# handling file 00118_id06752_wavtolip.wav
# handling file 00118_id07689_wavtolip.wav
# handling file 00021_id00080_wavtolip.wav
# handling file 00021_id02619_wavtolip.wav
# handling file 00021_id03815_wavtolip.wav
# handling file 00021_id03897_wavtolip.wav
# handling file 00021_id04070_wavtolip.wav
# handling file 00021_id04564_wavtolip.wav
# handling file 00021_id04582_wavtolip.wav
# handling file 00021_id06254_wavtolip.wav
# handling file 00021_id06428_wavtolip.wav
# handling file 00021_id07051_wavtolip.wav
# handling file 00005_id00080_wavtolip.wav
# handling file 00005_id02619_wavtolip.wav
# handling file 00005_id04070_wavtolip.wav
# handling file 00005_id04490_wavtolip.wav
# handling file 00005_id04564_wavtolip.wav
# handling file 00005_id04583_wavtolip.wav
# handling file 00005_id04927_wavtolip.wav
# handling file 00005_id05845_wavtolip.wav
# handling file 00005_id06438_wavtolip.wav
# handling file 00005_id07051_wavtolip.wav
# handling file 00072_id01026_wavtolip.wav
# handling file 00072_id02310_wavtolip.wav
# handling file 00072_id03559_wavtolip.wav
# handling file 00072_id03897_wavtolip.wav
# handling file 00072_id04070_wavtolip.wav
# handling file 00072_id04927_wavtolip.wav
# handling file 00072_id05931_wavtolip.wav
# handling file 00072_id07008_wavtolip.wav
# handling file 00072_id07051_wavtolip.wav
# handling file 00072_id07236_wavtolip.wav
# handling file 00054_id00149_wavtolip.wav
# handling file 00054_id02089_wavtolip.wav
# handling file 00054_id02619_wavtolip.wav
# handling file 00054_id03985_wavtolip.wav
# handling file 00054_id04582_wavtolip.wav
# handling file 00054_id04583_wavtolip.wav
# handling file 00054_id06232_wavtolip.wav
# handling file 00054_id06254_wavtolip.wav
# handling file 00054_id06438_wavtolip.wav
# handling file 00054_id07049_wavtolip.wav
# handling file 00186_id02089_wavtolip.wav
# handling file 00186_id02310_wavtolip.wav
# handling file 00186_id02619_wavtolip.wav
# handling file 00186_id03815_wavtolip.wav
# handling file 00186_id04070_wavtolip.wav
# handling file 00186_id04529_wavtolip.wav
# handling file 00186_id04582_wavtolip.wav
# handling file 00186_id05434_wavtolip.wav
# handling file 00186_id06428_wavtolip.wav
# handling file 00186_id07236_wavtolip.wav
# handling file 00231_id00235_wavtolip.wav
# handling file 00231_id02619_wavtolip.wav
# handling file 00231_id03985_wavtolip.wav
# handling file 00231_id04070_wavtolip.wav
# handling file 00231_id04582_wavtolip.wav
# handling file 00231_id05434_wavtolip.wav
# handling file 00231_id06428_wavtolip.wav
# handling file 00231_id07008_wavtolip.wav
# handling file 00231_id07689_wavtolip.wav
# handling file 00417_id02089_wavtolip.wav
# handling file 00417_id04070_wavtolip.wav
# handling file 00417_id04530_wavtolip.wav
# handling file 00417_id05845_wavtolip.wav
# handling file 00417_id06232_wavtolip.wav
# handling file 00417_id06437_wavtolip.wav
# handling file 00417_id06752_wavtolip.wav
# handling file 00417_id07049_wavtolip.wav
# handling file 00417_id07689_wavtolip.wav
# handling file 00180_id00417_wavtolip.wav
# handling file 00180_id00739_wavtolip.wav
# handling file 00180_id01026_wavtolip.wav
# handling file 00180_id03559_wavtolip.wav
# handling file 00180_id04583_wavtolip.wav
# handling file 00180_id05931_wavtolip.wav
# handling file 00180_id06268_wavtolip.wav
# handling file 00180_id06428_wavtolip.wav
# handling file 00180_id07689_wavtolip.wav
# handling file 00077_id01026_wavtolip.wav
# handling file 00077_id02089_wavtolip.wav
# handling file 00077_id03897_wavtolip.wav
# handling file 00077_id03985_wavtolip.wav
# handling file 00077_id04530_wavtolip.wav
# handling file 00077_id04583_wavtolip.wav
# handling file 00077_id05435_wavtolip.wav
# handling file 00077_id05845_wavtolip.wav
# handling file 00077_id06232_wavtolip.wav
# handling file 00077_id07236_wavtolip.wav
# handling file 00013_id00235_wavtolip.wav
# handling file 00013_id02089_wavtolip.wav
# handling file 00013_id03985_wavtolip.wav
# handling file 00013_id04927_wavtolip.wav
# handling file 00013_id05920_wavtolip.wav
# handling file 00013_id06232_wavtolip.wav
# handling file 00013_id06437_wavtolip.wav
# handling file 00013_id06438_wavtolip.wav
# handling file 00013_id06439_wavtolip.wav
# handling file 00013_id06752_wavtolip.wav
# handling file 00052_id00149_wavtolip.wav
# handling file 00052_id00488_wavtolip.wav
# handling file 00052_id04490_wavtolip.wav
# handling file 00052_id04564_wavtolip.wav
# handling file 00052_id04582_wavtolip.wav
# handling file 00052_id04583_wavtolip.wav
# handling file 00052_id06232_wavtolip.wav
# handling file 00052_id06254_wavtolip.wav
# handling file 00052_id07008_wavtolip.wav
# handling file 00107_id00043_wavtolip.wav
# handling file 00107_id00417_wavtolip.wav
# handling file 00107_id03815_wavtolip.wav
# handling file 00107_id03897_wavtolip.wav
# handling file 00107_id03985_wavtolip.wav
# handling file 00107_id04529_wavtolip.wav
# handling file 00107_id04564_wavtolip.wav
# handling file 00107_id06439_wavtolip.wav
# handling file 00107_id07689_wavtolip.wav
# handling file 00135_id00080_wavtolip.wav
# handling file 00135_id00149_wavtolip.wav
# handling file 00135_id02089_wavtolip.wav
# handling file 00135_id03559_wavtolip.wav
# handling file 00135_id04070_wavtolip.wav
# handling file 00135_id06268_wavtolip.wav
# handling file 00135_id06437_wavtolip.wav
# handling file 00135_id07377_wavtolip.wav
# handling file 00027_id00043_wavtolip.wav
# handling file 00027_id00417_wavtolip.wav
# handling file 00027_id01026_wavtolip.wav
# handling file 00027_id02310_wavtolip.wav
# handling file 00027_id04564_wavtolip.wav
# handling file 00027_id05434_wavtolip.wav
# handling file 00027_id05478_wavtolip.wav
# handling file 00027_id06428_wavtolip.wav
# handling file 00027_id06438_wavtolip.wav
# handling file 00027_id07008_wavtolip.wav
# handling file 00161_id00461_wavtolip.wav
# handling file 00161_id00488_wavtolip.wav
# handling file 00161_id02089_wavtolip.wav
# handling file 00161_id03559_wavtolip.wav
# handling file 00161_id05478_wavtolip.wav
# handling file 00161_id06437_wavtolip.wav
# handling file 00161_id06438_wavtolip.wav
# handling file 00161_id07008_wavtolip.wav
# handling file 00161_id07049_wavtolip.wav
# handling file 00013_id00488_wavtolip.wav
# handling file 00013_id00747_wavtolip.wav
# handling file 00013_id02089_wavtolip.wav
# handling file 00013_id02619_wavtolip.wav
# handling file 00013_id03815_wavtolip.wav
# handling file 00013_id03985_wavtolip.wav
# handling file 00013_id05478_wavtolip.wav
# handling file 00013_id06438_wavtolip.wav
# handling file 00013_id07049_wavtolip.wav
# handling file 00013_id07236_wavtolip.wav
# handling file 00025_id00235_wavtolip.wav
# handling file 00025_id01026_wavtolip.wav
# handling file 00025_id02089_wavtolip.wav
# handling file 00025_id04583_wavtolip.wav
# handling file 00025_id05435_wavtolip.wav
# handling file 00025_id05478_wavtolip.wav
# handling file 00025_id05845_wavtolip.wav
# handling file 00025_id06268_wavtolip.wav
# handling file 00025_id06428_wavtolip.wav
# handling file 00025_id06752_wavtolip.wav
# handling file 00043_id00488_wavtolip.wav
# handling file 00043_id00747_wavtolip.wav
# handling file 00043_id02310_wavtolip.wav
# handling file 00043_id03559_wavtolip.wav
# handling file 00043_id04529_wavtolip.wav
# handling file 00043_id04530_wavtolip.wav
# handling file 00043_id04927_wavtolip.wav
# handling file 00043_id06343_wavtolip.wav
# handling file 00043_id06428_wavtolip.wav
# handling file 00043_id06439_wavtolip.wav
# handling file 00159_id00488_wavtolip.wav
# handling file 00159_id00739_wavtolip.wav
# handling file 00159_id02310_wavtolip.wav
# handling file 00159_id02619_wavtolip.wav
# handling file 00159_id03897_wavtolip.wav
# handling file 00159_id04490_wavtolip.wav
# handling file 00159_id05434_wavtolip.wav
# handling file 00159_id05845_wavtolip.wav
# handling file 00159_id06254_wavtolip.wav
# handling file 00159_id06752_wavtolip.wav
# handling file 00023_id00739_wavtolip.wav
# handling file 00023_id01026_wavtolip.wav
# handling file 00023_id02310_wavtolip.wav
# handling file 00023_id02619_wavtolip.wav
# handling file 00023_id04564_wavtolip.wav
# handling file 00023_id05845_wavtolip.wav
# handling file 00023_id05931_wavtolip.wav
# handling file 00023_id07049_wavtolip.wav
# handling file 00023_id07689_wavtolip.wav
# handling file 00043_id00235_wavtolip.wav
# handling file 00043_id00747_wavtolip.wav
# handling file 00043_id02089_wavtolip.wav
# handling file 00043_id05845_wavtolip.wav
# handling file 00043_id06232_wavtolip.wav
# handling file 00043_id06428_wavtolip.wav
# handling file 00043_id06438_wavtolip.wav
# handling file 00043_id06752_wavtolip.wav
# handling file 00043_id07008_wavtolip.wav
# handling file 00043_id07051_wavtolip.wav
# handling file 00028_id00080_wavtolip.wav
# handling file 00028_id01026_wavtolip.wav
# handling file 00028_id02089_wavtolip.wav
# handling file 00028_id03985_wavtolip.wav
# handling file 00028_id04529_wavtolip.wav
# handling file 00028_id04530_wavtolip.wav
# handling file 00028_id05435_wavtolip.wav
# handling file 00028_id06232_wavtolip.wav
# handling file 00028_id07686_wavtolip.wav
# handling file 00110_id00235_wavtolip.wav
# handling file 00110_id04564_wavtolip.wav
# handling file 00110_id05435_wavtolip.wav
# handling file 00110_id05845_wavtolip.wav
# handling file 00110_id06232_wavtolip.wav
# handling file 00110_id06343_wavtolip.wav
# handling file 00110_id06428_wavtolip.wav
# handling file 00110_id06437_wavtolip.wav
# handling file 00110_id06438_wavtolip.wav
# handling file 00110_id07686_wavtolip.wav
# handling file 00118_id01026_wavtolip.wav
# handling file 00118_id03897_wavtolip.wav
# handling file 00118_id04070_wavtolip.wav
# handling file 00118_id04529_wavtolip.wav
# handling file 00118_id04583_wavtolip.wav
# handling file 00118_id04927_wavtolip.wav
# handling file 00118_id05478_wavtolip.wav
# handling file 00118_id06254_wavtolip.wav
# handling file 00118_id06438_wavtolip.wav
# handling file 00118_id07049_wavtolip.wav
# handling file 00150_id00080_wavtolip.wav
# handling file 00150_id00235_wavtolip.wav
# handling file 00150_id00417_wavtolip.wav
# handling file 00150_id00461_wavtolip.wav
# handling file 00150_id03897_wavtolip.wav
# handling file 00150_id04530_wavtolip.wav
# handling file 00150_id05435_wavtolip.wav
# handling file 00150_id06343_wavtolip.wav
# handling file 00150_id07008_wavtolip.wav
# handling file 00221_id00043_wavtolip.wav
# handling file 00221_id00149_wavtolip.wav
# handling file 00221_id00747_wavtolip.wav
# handling file 00221_id04070_wavtolip.wav
# handling file 00221_id04490_wavtolip.wav
# handling file 00221_id04583_wavtolip.wav
# handling file 00221_id05435_wavtolip.wav
# handling file 00221_id06268_wavtolip.wav
# handling file 00221_id06437_wavtolip.wav
# handling file 00175_id00080_wavtolip.wav
# handling file 00175_id01026_wavtolip.wav
# handling file 00175_id02310_wavtolip.wav
# handling file 00175_id02619_wavtolip.wav
# handling file 00175_id03815_wavtolip.wav
# handling file 00175_id04070_wavtolip.wav
# handling file 00175_id04490_wavtolip.wav
# handling file 00175_id04530_wavtolip.wav
# handling file 00175_id06268_wavtolip.wav
# handling file 00175_id06439_wavtolip.wav
# handling file 00043_id00080_wavtolip.wav
# handling file 00043_id00149_wavtolip.wav
# handling file 00043_id00417_wavtolip.wav
# handling file 00043_id02310_wavtolip.wav
# handling file 00043_id03815_wavtolip.wav
# handling file 00043_id05435_wavtolip.wav
# handling file 00043_id06254_wavtolip.wav
# handling file 00043_id06438_wavtolip.wav
# handling file 00043_id06752_wavtolip.wav
# handling file 00083_id00461_wavtolip.wav
# handling file 00083_id02089_wavtolip.wav
# handling file 00083_id03815_wavtolip.wav
# handling file 00083_id04529_wavtolip.wav
# handling file 00083_id04530_wavtolip.wav
# handling file 00083_id06254_wavtolip.wav
# handling file 00083_id06428_wavtolip.wav
# handling file 00083_id07008_wavtolip.wav
# handling file 00083_id07236_wavtolip.wav
# handling file 00405_id00235_wavtolip.wav
# handling file 00405_id00417_wavtolip.wav
# handling file 00405_id02089_wavtolip.wav
# handling file 00405_id03559_wavtolip.wav
# handling file 00405_id04529_wavtolip.wav
# handling file 00405_id05435_wavtolip.wav
# handling file 00405_id05931_wavtolip.wav
# handling file 00405_id06439_wavtolip.wav
# handling file 00405_id07236_wavtolip.wav
# handling file 00405_id07377_wavtolip.wav
# handling file 00052_id00739_wavtolip.wav
# handling file 00052_id04070_wavtolip.wav
# handling file 00052_id04582_wavtolip.wav
# handling file 00052_id06232_wavtolip.wav
# handling file 00052_id06439_wavtolip.wav
# handling file 00052_id06752_wavtolip.wav
# handling file 00052_id07008_wavtolip.wav
# handling file 00052_id07051_wavtolip.wav
# handling file 00052_id07377_wavtolip.wav
# handling file 00052_id07689_wavtolip.wav
# handling file 00143_id04529_wavtolip.wav
# handling file 00143_id04530_wavtolip.wav
# handling file 00143_id04582_wavtolip.wav
# handling file 00143_id05478_wavtolip.wav
# handling file 00143_id06268_wavtolip.wav
# handling file 00143_id06439_wavtolip.wav
# handling file 00143_id07008_wavtolip.wav
# handling file 00143_id07689_wavtolip.wav
# handling file 00025_id01026_wavtolip.wav
# handling file 00025_id02310_wavtolip.wav
# handling file 00025_id03897_wavtolip.wav
# handling file 00025_id04490_wavtolip.wav
# handling file 00025_id06254_wavtolip.wav
# handling file 00025_id06437_wavtolip.wav
# handling file 00025_id06438_wavtolip.wav
# handling file 00025_id07051_wavtolip.wav
# handling file 00025_id07236_wavtolip.wav
# handling file 00025_id07686_wavtolip.wav
# handling file 00254_id00417_wavtolip.wav
# handling file 00254_id02310_wavtolip.wav
# handling file 00254_id03897_wavtolip.wav
# handling file 00254_id05434_wavtolip.wav
# handling file 00254_id05478_wavtolip.wav
# handling file 00254_id06232_wavtolip.wav
# handling file 00254_id06254_wavtolip.wav
# handling file 00254_id06268_wavtolip.wav
# handling file 00254_id06437_wavtolip.wav
# handling file 00254_id06439_wavtolip.wav
# handling file 00028_id00747_wavtolip.wav
# handling file 00028_id02310_wavtolip.wav
# handling file 00028_id04070_wavtolip.wav
# handling file 00028_id04530_wavtolip.wav
# handling file 00028_id06254_wavtolip.wav
# handling file 00028_id06343_wavtolip.wav
# handling file 00028_id07008_wavtolip.wav
# handling file 00028_id07377_wavtolip.wav
# handling file 00028_id07686_wavtolip.wav

# %%
filename = '/content/drive/MyDrive/FakeAVCeleb/FakeAVCeleb_v1.2/wav2lip_metadata_updated.csv'
metadata_df.to_csv(filename)

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(20,20)})
sns.displot(data=metadata_df, x="audio_length")
