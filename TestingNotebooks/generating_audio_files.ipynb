# %% [markdown]
# <a href="https://colab.research.google.com/github/romitbarua/MultiModalDeepFake/blob/main/TestingNotebooks/generating_audio_files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install moviepy
# !pip3 install imageio==2.4.1
# !pip install --upgrade imageio-ffmpeg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os
import pandas as pd
import numpy as np
import scipy
from scipy.io import wavfile
import scipy.fftpack as fft
from scipy.signal import get_window
import IPython.display as ipd
import matplotlib.pyplot as plt
import moviepy.editor as mp
from pathlib import Path
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
metadata_file = '/content/drive/MyDrive/FakeAVCeleb/FakeAVCeleb_v1.2/wav2lip_metadata.csv'
metadata_df = pd.read_csv(metadata_file)
metadata_df = metadata_df.drop(['Unnamed: 0'], axis=1)

# %%
metadata_df.columns
# Out:
# Index(['source', 'target1', 'target2', 'method', 'category', 'type', 'race',
#        'gender', 'filename', 'directory_path', 'mp4_filepath',
#        'utterance_file', 'wav_filepath'],
#       dtype='object')

# %%
mp4_filepaths = metadata_df.mp4_filepath
wav_filepaths = metadata_df.wav_filepath

# %%
def extract_wav(mp4_filepath, wav_filepath):

  #check if file exists (conversion crashes)
  wav_file = Path(wav_filepath)
  if wav_file.exists():
    print("File exists for id {}".format(mp4_filepath.split('/')[-2]))
  else:
    print("Generating file for id {}".format(mp4_filepath.split('/')[-2]))
    #do video to wav conversion
    video = mp.VideoFileClip(mp4_filepath)
    try:
      video.audio.write_audiofile(wav_filepath, ffmpeg_params=["-ac", "1"])
    except:
      print("Failed for id {}".format(mp4_filepath.split('/')[-2]))

# %%
for mp4, wav in zip(mp4_filepaths, wav_filepaths):
  extract_wav(mp4,wav)
# Out:
# Streaming output truncated to the last 5000 lines.
# File exists for id id00747
# File exists for id id00747
# File exists for id id00747
# File exists for id id01026
# File exists for id id01026
# File exists for id id01026
# File exists for id id01026
# File exists for id id01026
# File exists for id id01026
# File exists for id id01026
# File exists for id id01026
# File exists for id id01026
# File exists for id id01026
# File exists for id id02089
# File exists for id id02089
# File exists for id id02089
# File exists for id id02089
# File exists for id id02089
# File exists for id id02089
# File exists for id id02089
# File exists for id id02089
# File exists for id id02089
# File exists for id id02089
# File exists for id id02310
# File exists for id id02310
# File exists for id id02310
# File exists for id id02310
# File exists for id id02310
# File exists for id id02310
# File exists for id id02310
# File exists for id id02310
# File exists for id id02310
# ...
