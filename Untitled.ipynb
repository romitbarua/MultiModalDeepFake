# %%
import pandas as pd
# Out:
# /home/ubuntu/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
data = pd.read_csv('/home/ubuntu/data/wavefake_data/LJ_metadata.csv')

# %%
sample = data[data.ElevenLabs.isna()].sample(1500)

# %%
sample.to_csv('/home/ubuntu/sample.csv')

# %%
testing = pd.read_csv('/home/ubuntu/sample.csv')

# %%
testing.loc[929]

# %%
import os, shutil
output_path = '/home/ubuntu/data/wavefake_data/generated_audio/ljspeech_elevenlabs/Original'
input_path = '/home/ubuntu/data/wavefake_data/generated_audio/11LabsDeepFakes'

# %%
for file in os.listdir(input_path):
    if '.wav' in file:
        print(file)
        src_path = os.path.join(input_path, file)
        dst_path = os.path.join(output_path, file)
        shutil.move(src_path, dst_path)
# Out:
# LJ002-0126.wav
# LJ012-0097.wav
# LJ019-0184.wav
# LJ017-0111.wav
# LJ014-0282.wav
# LJ012-0150.wav
# LJ015-0253.wav
# LJ002-0127.wav
# LJ006-0122.wav
# LJ019-0218.wav
# LJ014-0272.wav
# LJ010-0068.wav
# LJ015-0292.wav
# LJ011-0005.wav
# LJ015-0254.wav
# LJ011-0019.wav
# LJ011-0245.wav
# LJ014-0315.wav
# LJ015-0008.wav
# LJ018-0222.wav
# LJ013-0142.wav
# LJ018-0317.wav
# LJ013-0013.wav
# LJ012-0139.wav
# LJ018-0158.wav
# LJ038-0175.wav
# LJ018-0117.wav
# LJ002-0270.wav
# LJ002-0267.wav
# LJ013-0012.wav
# LJ015-0006.wav
# LJ011-0278.wav
# LJ018-0252.wav
# LJ019-0038.wav
# LJ008-0198.wav
# LJ014-0313.wav
# LJ018-0115.wav
# LJ010-0313.wav
# LJ018-0290.wav
# LJ015-0052.wav
# LJ011-0177.wav
# LJ038-0006.wav
# LJ002-0129.wav
# LJ018-0141.wav
# LJ015-0084.wav
# LJ009-0300.wav
# LJ010-0307.wav
# LJ016-0205.wav
# LJ010-0306.wav
# LJ018-0392.wav
# LJ015-0134.wav
# LJ012-0008.wav
# LJ011-0022.wav
# LJ044-0026.wav
# LJ015-0029.wav
# LJ002-0264.wav
# LJ018-0224.wav
# LJ008-0196.wav
# ...

# %%
df = pd.read_csv('/home/ubuntu/data/wavefake_data/LJ_metadata_Original.csv')

# %%
df
# Out:
#        Unnamed: 0          id Main_ID  Secondary_ID  \
# 0               0  LJ001-0001   LJ001             1
# 1               1  LJ001-0002   LJ001             2
# 2               2  LJ001-0003   LJ001             3
# 3               3  LJ001-0004   LJ001             4
# 4               4  LJ001-0005   LJ001             5
# ...           ...         ...     ...           ...
# 13095       13095  LJ050-0274   LJ050           274
# 13096       13096  LJ050-0275   LJ050           275
# 13097       13097  LJ050-0276   LJ050           276
# 13098       13098  LJ050-0277   LJ050           277
# 13099       13099  LJ050-0278   LJ050           278
#
#                                                     Real  \
# 0      /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 1      /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 2      /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 3      /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# ...

# %%
test_df = df[df.ElevenLabs.isna()]

# %%
test_df
# Out:
#        Unnamed: 0          id Main_ID  Secondary_ID  \
# 304           304  LJ002-0120   LJ002           120
# 308           308  LJ002-0124   LJ002           124
# 310           310  LJ002-0126   LJ002           126
# 311           311  LJ002-0127   LJ002           127
# 313           313  LJ002-0129   LJ002           129
# ...           ...         ...     ...           ...
# 5974         5974  LJ020-0041   LJ020            41
# 6039         6039  LJ020-0106   LJ020           106
# 9887         9887  LJ038-0006   LJ038             6
# 10056       10056  LJ038-0175   LJ038           175
# 11339       11339  LJ044-0026   LJ044            26
#
#                                                     Real  \
# 304    /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 308    /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 310    /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# 311    /home/ubuntu/data/wavefake_data/LJSpeech_1.1/w...
# ...

# %%
test_df.to_csv('/home/ubuntu/sample.csv')
